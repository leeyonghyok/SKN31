# %% [markdown]
# # Agent 개요
#
# ## AI Agent란?
#
# - **AI Agent는 사용자의 목표를 달성하기 위해 대형 언어 모델(LLM)을 추론과 의사결정의 중심으로 사용하여 작업 계획 수립, 실행, 관찰, 판단 과정을 반복하며 자율적으로 작업을 수행하는 인공지능 시스템이다.**.**
# - 일반적인 LLM 사용 방식은 다음과 같이 한 번의 질문에 대해 답변을 생성하는 구조이다.
#
#     ```text
#     사용자 질문 → LLM → 답변
#     ```
# - AI Agent는 단순히 답변만 생성하지 않는다. **사용자의 목표를 이해한 뒤, 목표를 달성하기 위해 필요한 작업을 스스로 판단하고 실행**한다.
#
#     ```text
#     목표 이해 → 계획 수립 → 도구 실행 → 결과 관찰 → 다음 행동 결정
#     ```
#     - **목표 이해.**
#         - Agent는 사용자의 요청을 단순한 문장으로만 처리하지 않고, 사용자가 실제로 달성하려는 목표가 무엇인지 파악한다.
#     - **작업 계획.**
#         - 목표를 달성하기 위해 어떤 순서로 작업해야 하는지 판단하고, 필요한 단계를 나눈다.
#     - **외부 도구 사용**
#         - Agent는 필요에 따라 검색 도구, API, 데이터베이스, 파일 시스템, 계산기, 코드 실행 환경 등 외부 도구를 호출할 수 있다.
#     - **실행 결과를 관찰하고 다음 행동을 결정.**
#         - 도구 실행 결과가 충분한지, 추가 작업이 필요한지 판단한 뒤 다음 단계를 결정한다.
#     - **반복 실행**
#         - 목표가 달성될 때까지 필요한 과정을 반복한다.
#     - 모든 단계를 사람이 직접 지시하지 않아도, Agent는 주어진 목표를 기준으로 스스로 판단하며 작업을 이어갈 수 있다.
#
#
# - 예를 들어 사용자가 “최근 AI 반도체 시장 동향을 조사해서 요약해줘”라고 요청했다고 하자.
#
#     ```text
#     1. 목표 파악: AI 반도체 시장 동향 조사
#     2. 계획 수립: 주요 기업, 시장 규모, 최근 이슈, 전망을 조사
#     3. 도구 사용: 웹 검색, 데이터베이스 조회
#     4. 결과 관찰: 수집한 자료가 충분한지 판단
#     5. 추가 실행: 부족한 정보가 있으면 추가 검색
#     6. 최종 답변: 조사 결과를 정리해 사용자에게 제공
#     ```
#
# 이처럼 Agent는 단순 응답 생성이 아니라 **목표 달성을 위한 일련의 작업 과정**을 수행한다.
#
# ## Workflow와 Agent
#
# - AI 시스템을 구현할 때 자주 비교되는 방식이 **Workflow**와 **Agent**이다.
# -   **Workflow**
#     - 미리 정해진 절차에 따라 실행되는 방식이다.
#     - 실행 순서와 작업 단계가 사전에 고정되어 있으며, 입력이 들어오면 정해진 흐름대로 처리된다.
#     - 반복적이고 정형화된 작업에 적합하다.
# - **Agent**
#     - 주어진 목표를 달성하기 위해 스스로 판단하면서 행동을 결정하는 방식이다.
#     - 처음부터 모든 실행 단계가 고정되어 있지 않고, 상황에 따라 필요한 작업과 도구를 선택하여 실행한다.
#     - Agent는 작업 과정이 고정되어 있지 않거나, 중간 결과에 따라 다음 행동이 달라지는 문제에 적합하다.

# %% [markdown]
# ## Agent의 주요 특징
#
# 1. **자율성** (Autonomy)
#    - Agent는 **사전 정의된 규칙**(Rule-based)에 의존하지 않고, LLM을 통해 현재 상황을 인지하고 추론하여 스스로 결정을 내리고 다음 행동을 계획할 수 있다.
#    - 즉, 사용자가 일일이 수행 단계를 지시하지 않아도, Agent는 **현재 상황을 해석하고 다음 행동을 동적으로 결정한다.**
#
# 2. **목표 지향성** (Goal-Oriented)
#     - Agent는 단순히 질문에 답변하는 **단순한 대화 상대가 아니라, 특정 목표와 복잡한 작업을 달성하기 위해 설계된 시스템**으로 최종 목표에 도달할 때 까지 반복적으로 행동한다.
#     - Agent는 어떤 처리를 할 때 항상 **"이 행동이 목표 달성에 도움이 되는가"를 기준**으로 판단한다.
#
# 3. **도구 활용** (Tool Utilization)
#     - Agent는 대형 언어 모델의 언어 이해 능력, 사전 학습 정보에만 의존하지 않고, 다양한 **외부 도구와 API를 함께 활용하여 실제 작업을 수행**한다.
#     - 이를 통해 LLM이 처리할 수없는 **최신 정보 검색, 복잡한 계산, 외부 시스템 제어**등과 같은 작업이 가능하다. 이를 통해 Agent는 **"말만 하는 AI"가 아니라 "실제로 일을 처리하는 AI"로 기능한다.**
#
# 4. **인간 개입 최소화** (Human-in-the-loop 최소화)
#     - Agent는 **문제 분석, 의사 결정, 행동 실행의 대부분을 스스로 결정하고 수행하도록 설계된다.**
#     - 사람은 **초기 목표 제시, 결과 확인 및 실행 최종 승인** 정도에 만 개입한다.

# %% [markdown]
# # 싱글에이전트(Single-Agent)와 멀티에이전트(Multi-Agent)
#
# ## 싱글에이전트(Single-Agent)
# - **하나의 에이전트가 작업의 처음부터 끝까지 전 과정을 책임지는 구조**로 구성된 Agent.
# - 싱글에이전트는 **"인식 → 추론 → 행동(도구 호출) → 결과 관찰"** 흐름의 모든 판단이 **하나의 추론 컨텍스트(context) 안**에서 이루어진다. 즉, 도구(검색, 코드 실행, 파일 읽기 등)와 메모리를 모두 한 에이전트가 쥐고 있으며, 작업 전체의 맥락이 단일한 의사결정자 안에 통합되어 있다.
#     - 예를 들어 "이 코드의 버그를 찾아 고쳐줘"라는 요청에서, 하나의 에이전트가 코드를 읽고, 원인을 추론하고, 수정안을 실행하고, 테스트 결과를 확인하는 일을 혼자 모두 처리한다.
# - **장점:** 구조가 단순해 응답이 빠르고(저지연), 토큰 소비가 적어 비용이 낮으며, 동작이 한 곳에서 일어나기 때문에 디버깅과 추적이 쉽다.
# - **한계:** 단일한 컨텍스트 윈도우에 작업 전체가 담겨야 하므로 정보량이 많아지면 한계에 부딪히고, 단계들을 순차적으로 처리하기 때문에 여러 갈래를 동시에 진행하는 **병렬 처리가 불가능**하다. 작업 규모가 커질수록 이 두 가지(컨텍스트 한계·순차 병목)가 성능의 제약이 된다.
#
# ## 멀티에이전트 (Multi-Agent)
#
# - **역할이 나뉜 여러 에이전트들이 협력하여 하나의 작업을 처리하는 구조**이다.
# - 보통 **오케스트레이터(orchestrator) 혹은 슈퍼바이저(supervisor)** 라 불리는 상위 에이전트가 큰 작업을 작은 하위 작업으로 분해하고, 각 분야에 특화된 **워커(worker) 에이전트**들에게 위임한다. 각 워커는 자신만의 독립된 컨텍스트와 도구, 역할(role)을 가지며, 작업을 마치면 결과를 상위 에이전트(슈퍼바이저)에게 보고한다. 상위 에이전트는 이 결과들을 종합해 최종 산출물(응답)을 만든다.
# - 멀티에이전트 구성 패턴으로는 상위가 하위를 지휘하는 **슈퍼바이저/오케스트레이터-워커 패턴**, 단계별로 결과를 넘겨주는 **순차 파이프라인 패턴**, 에이전트들이 서로 동등하게 의견을 주고받는 **수평적 협업 패턴** 등이 있다.
#
# ### 멀티에이전트가 효과적인 이유
#
# - Anthropic이 공개한 멀티에이전트 리서치 시스템 자료에 따르면, 리드 에이전트(Opus)와 서브에이전트(Sonnet)로 구성한 멀티에이전트가 단일 에이전트(Opus) 대비 내부 평가에서 **약 90% 이상 높은 성능**을 보였다.
# - 이 성능 향상은 주로 **토큰 사용량**, 그리고 추론을 여러 개의 독립된 컨텍스트 윈도우로 분산시킨 능력과 강하게 연결되어 있었다. 실제로 성능 변동의 약 80%가 토큰 사용량에 영향을 받았고, 그 외에는 도구 호출 수와 모델 선택 등이 영향을 주었다.
# - 토큰 사용량이란 하나의 작업을 끝낼 때 까지 모델이 읽고 쓴 토큰의 총합이다. 여기에는 입력받은 토큰들(검색결과, 도구 반환값, 읽어들인 문서, 이전 대화맥락등등)과 출력토큰들(모델이 생성한 추론, 도구 호출명령, 최종 답변등등)들이 있다.
# - 토큰 사용량이 만다는 것은 그 만큼 **모델이 많은 정보를 들여다 보고, 많이 생락을 했다**는 것을 뜻한다.
# - 즉 **멀티에이전트가 강한 이유는 결국 문제를 해결하는데 "더 많은 사고량(토큰)"을 병렬로 효율적으로 투입할 수 있기 때문**이다.
#
# ### 멀티에이전트의 비용과 위험
#
# - **조율 비용(coordination overhead):** 에이전트 간 작업을 나누고 결과를 주고받는 데 추가 비용이 든다.
# - **토큰·비용 급증:** 여러 에이전트가 각자 추론하므로 토큰 사용량이 크게 늘어난다. Anthropic 자료 기준으로 **일반 채팅 대비** 단일 에이전트는 약 4배, 멀티에이전트 리서치 시스템은 약 15배(십수 배)까지 토큰을 소비한다. (싱글에이전트를 기준으로  비교해 보면 멀티에이전트는 대략 4배 수준이다.)
# - **오류 전파(error propagation):** 한 에이전트의 오류가 다음 단계로 쉽게 번진다.
# - **디버깅 난이도:** 여러 주체의 비결정적(non-deterministic) 상호작용을 추적해야 하므로 재현과 디버깅이 까다롭다.
# - **맥락 단절 위험:** 서브에이전트들이 맥락을 충분히 공유하지 못하면 서로 모순되거나 일관성 없는 결과를 산출하고, 이를 합치는 과정에서 오히려 품질이 떨어질 수 있다. 즉 멀티에이전트는 만능이 아니며, 작업들이 서로 긴밀하게 의존해 **맥락 공유가 필수적인 경우**라면 무리하게 쪼개기보다 싱글에이전트로 두는 편이 오히려 안정적이다.
#
# ## 어떤 에이전트를 언제 사용해야 하는가
#
# - 가장 중요한 원칙은 **"싱글에이전트로 단순하게 시작하고, 한계에 부딪히면 멀티에이전트로 확장한다"** 이다.
# - 멀티에이전트는  **비용과 복잡도가 크기 때문**에 처음부터 **멀티에이전트를 선택하는 것은 과잉설계**(**over-engineering**)가 될 수 있다.
#
# ### 싱글/멀티 에이전트 트레이드오프
#
# | 기준 | 싱글에이전트 우위 | 멀티에이전트 우위 |
# | --- | --- | --- |
# | 지연시간(응답 속도) | ✅ 빠름 | 느림 |
# | 비용(토큰) | ✅ 낮음 | 높음(채팅 대비 ~15배) |
# | 디버깅·추적 | ✅ 쉬움 | 어려움 |
# | 병렬 처리 | 불가 | ✅ 가능 |
# | 전문 영역 분담 | 어려움 | ✅ 가능 |
# | 대용량 컨텍스트 처리 | 한계 있음 | ✅ 분산 처리 가능 |
# | 긴밀한 맥락 의존 작업 | ✅ 안정적 | 부적합 |
#
# ### 싱글에이전트가 적합한 경우
#
# - 대부분의 실무 작업은 사실 싱글에이전트로 충분하다.
# - 작업의 전체 맥락이 하나의 컨텍스트 윈도우 안에 들어가고, 단계들이 순차적으로 이어져 이전 단계의 결과가 다음 판단에 곧바로 영향을 줄 때 싱글에이전트가 유리하다.
#
# ### 멀티에이전트가 적합한 경우
#
# - 작업을 여러 갈래로 **병렬 처리**할 수 있을 때.
# - 서로 다른 **전문 영역**이 필요할 때(예: 검색 전담, 코드 작성 전담, 검증 전담).
# - 정보량이 너무 많아 하나의 컨텍스트 윈도우로는 감당이 안 될 때.

# %% [markdown]
# # ReAct 패턴
# - Agent 구현의 바탕이 되는 이론.
#
# ## 개요
#
# ReAct는 **Reasoning**(추론)과 **Acting**(행동)을 결합한 AI Agent의 프롬프팅 패턴이다. 대형 언어 모델(LLM)이 단순히 답변을 생성하는 것이 아니라, 문제를 분석하고(Reasoning)하고 그에 따라 필요한 도구를 선택하여 실행하며(Acting), 결과를 관찰하고(Observation) 다음 추론에 반영하는 과정을 반복하면서 문제를 해결하는  Agent 설계 방식이다.
#
# ### ReAct의 핵심 개념
#
# 전통적인 프롬프팅 방식은 질문에 대해 즉시 답변을 생성한다. 하지만 **ReAct 패턴**은 다음과 같은 순환 구조를 따른다:
#
# ```
# 질문 → 생각(Thought) → 행동(Action) → (결과)관찰(Observation) → 생각 → 행동 →  관찰 → ... → 답변
# ```
#
# - 예)
#   - 질문: "현재 서울의 날씨와 미세먼지 농도를 알려줘":
#
#     - **Thought(생각)**: 날씨 정보를 얻기 위해 날씨 API를 호출해야겠다
#     - **Action(행동)**: WeatherAPI.get_weather("서울")
#     - **Observation(관찰)**: 기온 15도, 맑음
#     - **Thought(생각)**: 이제 미세먼지 정보도 필요하다
#     - **Action(행동)**: AirQualityAPI.get_pm("서울")
#     - **Observation(관찰)**: PM10 농도 20㎍/㎥, 좋음
#     - **Answer(답변)**: 서울의 현재 날씨는 기온 15도로 맑고, 미세먼지 농도는 30㎍/㎥로 좋은 상태이다
#
# 이처럼 ReAct는 Agent가 **사고 과정을 명시적으로 드러내면서** 외부 도구를 활용하여 복잡한 문제를 해결할 수 있도록 한다.
#
# ### ReAct의 장점
#
# 1. **투명성**: Agent의 사고 과정을 추적할 수 있어 디버깅이 용이하다
# 2. **정확성**: 외부 지식과 도구를 활용하여 환각(hallucination)을 줄인다
# 3. **유연성**: 다양한 도구를 조합하여 복잡한 작업을 수행할 수 있다
# 4. **해석 가능성**: 각 단계의 추론 과정을 이해할 수 있다

# %% [markdown]
# ## 동작 단계
# ReAct 패턴은 크게 **5단계**의 순환 구조로 동작한다.
#
# 1. **질문 입력** (Question)
#      - 사용자로부터 해결해야 할 질문이나 작업을 입력받는다.
#      - 예시
#     ```bash
#      User Input: "2024년 노벨 물리학상 수상자는 누구이고, 그들의 주요 업적은 무엇인가?"
#     ```
#
# 2. **사고 단계** (Thought)
#      - 언어 모델이 사용자의 질문(요청)을 분석하고, 문제 해결을 위해 다음에 무엇을 해야 할지 추론한다.(계획을 세운다.)
#      - 이 단계에서 Agent는:
#          - 문제를 이해하고 분해한다
#          - 필요한 정보가 무엇인지 파악한다
#          - 어떤 도구를 사용해야 할지 결정한다
#          - 충분한 정보가 모였는지 판단한다
#
#        ```bash
#        Thought: 2024년 노벨 물리학상 정보는 내 학습 데이터에 없을 수 있다. 최신 정보를 검색해야 한다.
#        ```
#
# 3. **행동 단계** (Action)
#      - 사고 단계에서 결정된 계획을 바탕으로 실제 행동을 실행한다. 행동은 일반적으로 외부 도구(Tool) 호출한다.
#
#         ```bash
#         Action: 검색엔진.검색("2024 노벨 물리학상 수상자")
#         ```
#
# 4. **관찰 단계** (Observation)
#      - 행동(Acttion)의 결과를 관찰하고 얻은 정보를 확인한다.
#
#        ```bash
#        Observation: 2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다.
#        ```
#
#  5. **반복 또는 종료**
#        - 관찰한 정보가 사용자 질문에 대한 답변을 하는데 충분하지 않다면 2번의 사고 단계로 돌아가 추가 행동을 계획한다.(사고→행동→관찰 반복)
#        - 충분한 정보가 모였다면 그 정보를 바탕으로 최종 답변을 생성한다.
#
#           ```bash
#           Thought: 수상자 이름은 알았지만 구체적인 업적 내용이 필요하다.
#
#           Action: 정보검색.Search("John Hopfield Geoffrey Hinton 노벨상 업적")
#
#           Observation: Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신을 연구했다.
#
#           Thought: 이제 질문에 답할 충분한 정보가 모였다. 답변을 생성한다.
#
#           Action: Finish("2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다. Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신 연구로 인공신경망 발전에 기여했다.")
#           ```
#
# ### 동작 흐름도
# ![ReAct](figures/agent-ReAct.png)

# %% [markdown]
# # Tool과 Tool Calling
#
# ## Tool
#
# ### Tool이란
#
# - **Tool은 하나의 기능을 처리하는 함수이다.**
#     - Tool은 하나의 명확한 기능을 수행하도록 정의된 함수(Function) 형태의 외부 실행 수단이다.
#     - 대형 언어 모델(LLM)은 본래 텍스트를 생성하는 모델이므로, 실제 계산, 검색, 파일 처리, 데이터베이스 조회와 같은 현실 세계의 작업을 직접 수행할 수 없다. 이런 실제 작업을 대신 수행하는 단위가 Tool이다.
# - AI Agent는 내부적으로 **LLM을 추론 엔진으로 사용해 판단하고 Tool을 호출해서 실행**한다.
#
# ### Tool이 필요한 이유 — LLM의 두 가지 본질적 한계
#
# LLM은 강력한 추론(reasoning) 능력을 갖추고 있지만, 두 가지 본질적인 한계를 가진다. Tool은 이 한계를 보완한다.
#
# #### 한계 1 — **외부 세계를 읽지 못한다** (Read 제약)
#
# LLM은 학습 시점에 고정된 내부 지식만 갖고 있으며, 실행 시점의 외부 정보에 스스로 접근할 수 없다.
#
# - **Knowledge Cutoff:** 학습 데이터가 마지막으로 업데이트된 시점 이후에 발생한 사건이나 정보를 알지 못한다.
# - **실시간 데이터 미접근:** 현재 주가, 날씨, 데이터베이스 레코드처럼 매 순간 바뀌는 데이터는 학습 데이터 자체가 존재하지 않는다.
# - **개인·조직 데이터 미접근:** 사용자의 파일, 이메일, 사내 문서 등 공개되지 않은 데이터는 LLM이 본래 알 수 없다.
#
# Tool은 Web Search, DB 조회, File Reader 등을 통해 이 Read 제약을 해소한다.
#
# #### 한계 2 — **외부 세계에 영향을 줄 수 없다** (Write/Execute 제약)
#
# LLM은 텍스트를 생성할 뿐, 그 결과를 실제 세계에 반영하거나 실행할 수 없다.
#
# - **연산 부정확:** 복잡한 수치 계산은 LLM의 언어 생성 방식으로는 신뢰하기 어렵다.
# - **코드 실행 불가:** 코드를 작성할 수는 있지만, 직접 실행해 결과를 얻지는 못한다.
# - **시스템 연동 불가:** 이메일 전송, 예약, 결제, 코드 배포처럼 실제 세계에 변화를 일으키는 액션(action)을 수행할 수 없다.
#
# Tool은 Code Executor, API 호출, 메시지 전송 함수 등을 통해 이 Execute 제약을 해소한다.
#
# #### **LLM의 한계와 Tool의 대응 관계**
#
# | LLM의 한계 | 분류 | Tool의 대응 | 예시 |
# |---|---|---|---|
# | Knowledge Cutoff | Read | 최신 정보 조회 | Web Search, News API |
# | 실시간 데이터 미접근 | Read | 현재 데이터 조회 | DB Query, Weather API |
# | 개인·조직 데이터 미접근 | Read | 파일·문서 접근 | File Reader, Email Reader |
# | 연산 부정확 | Execute | 정확한 계산 위임 | Calculator, Spreadsheet |
# | 코드 실행 불가 | Execute | 코드 실행 | Python REPL, Shell |
# | 시스템 연동 불가 | Execute | 외부 시스템 액션 | REST API, 메시지 전송 |
# | 상태(state) 비저장 | Read/Write | 영속적 저장소 활용 | Memory Tool, Vector DB |
#
# ## Tool Calling 개요
# **도구 호출**(Tool Calling)은 LLM이 자체적으로 수행할 수 없는 작업을 외부 도구나 API를 활용하여 처리할 수 있게 하는 핵심 기능이다.
# 이를 통해 **LLM은 자체 지식의 한계를 넘어서는 최신 정보, 정확한 계산, 외부 시스템 제어 등의 능력을 확보**할 수 있다.
#
# - **도구 호출(Tool Calling)의 3단계**
#     1. 도구 바인딩 (Tool Binding): **LLM에 사용가능한 tool들을 등록한다.**
#         - LLM에게 사용 가능한 도구 목록과 각 도구의 기능(설명) 및 필요한 입력 매개변수를 미리 정의하여 제공한다.
#             - Tool 함수
#             - Tool 이름
#             - Tool이 수행하는 기능 설명
#             - 입력 파라미터 type과 설명
#     2. **사용자 질의가 들어오면 LLM이 도구 사용 여부를 판단**한다.
#         - LLM 자체 추론으로 해결가능한 문제인지 Tool을 호출해야 처리할 수있는 문제 인지를 확인한다.
#         - **Tool 사용이 필요한 문제** 라고 판단하면
#           - 도구를 호출 하는 것이 아니라 어떻게 호출해야 하는지 요청정보를 생성한다.
#             - 어떤 Tool을 사용해야 하는지, 그 Tool에 어떤 값을 전달해야하는지를 응답으로 생성한다.
#     3.  **시스템이 Tool 호출 요청정보에 따라 Tool을 실행하고 그 결과를 LLM 에게 전달**한다.
#
#      ![toolcalling_concept](figures/toolcalling_concept.png)
#
# - **TOOL Calling 예**
#     - LLM이 수학 계산을 수행해야 할 때, 직접 계산하는 대신 미리 정의된 '계산' 도구를 호출하여 정확한 결과를 얻을 수 있다.
#   	- LLM에 최신 정보를 요청하는 질문이 들어왔을 때 '검색' 도구나 'Database 연동' 도구를 사용해 최신 뉴스를 검색하거나, 특정 데이터베이스에서 정보를 조회하는 등의 작업을 수행할 수 있다.
#   	- LLM 이 작성한 결과를 google docs와 같은 문서도구나 SNS에 등록한다.
#
# ## Langchain 과 Tool calling
# - Tool calling은 대부분의 LLM 서비스가 지원한다.
#   - [Tool Calling을 지원하는 LLM 모델](https://docs.langchain.com/oss/python/integrations/chat)만 사용할 수 있다.
# - LangChain은 다양한 모델들의 도구 호출 방식을 표준화하여 일관된 인터페이스로 제공한다. 이를 통해 개발자들은 다양한 모델과 도구들을 쉽게 통합할 수있다.
#   - [Langchain Tool Calling Concept](https://docs.langchain.com/oss/python/langchain/tools)
# - Langchain 제공 Built-in tools
#     -  https://docs.langchain.com/oss/python/integrations/tools

# %% [markdown]
# # LangChain Built-in Tools 사용으로 Tool Calling 이해
#
# - Langchain은 다양한 도구들을 미리 구현해서 제공하고 있다. 이것들을 builtin tool이라고 한다.
#   - [Langchain 지원 Built tools](https://docs.langchain.com/oss/python/integrations/tools)
# - Built-In tool 뿐만 아니라 사용자 정의 Tool들을 직접 구현할 수있는 방법도 제공한다.
#
# ## Tavily API 검색 Tool
# > Tavily 웹 검색 도구 사용해 Tool calling을 이해한다.
# - **Tavily** Service: AI을 위한 웹 검색 API Service.
# - https://tavily.com/
# -  LLM과 RAG 시스템에 최적화된 검색 엔진.
#    -  기존의 일반 검색 엔진들과 달리, Tavily는 AI 애플리케이션의 요구사항에 맞춰 설계되었다.
#    -  Tavily는 최대 20개 이상의 신뢰도 높은 웹사이트에서 관련정보를 수집한다.
#    -  수집된 데이터는 AI가 관련성, 신뢰도, 최신성 등을 기준으로 평가해 가장 적합한 정보만 선별해서 요약한다.
#    -  최종적으로 이 정보는 LLM이 바로 활용할 수있도록 컨텐츠 스티펫, 요약, 출처 등의 구조화된 형태로 반환한다.
#    -  월 1000회 무료 사용 가능.
# - **Tavily API Key 받기**
#   - 회원가입 후 로그인 한다.
#   - Overview 화면에서 API Key 생성
#     - default API key 사용할 수있다.
#   - 환경변수에 등록한다.
#       - 변수이름: `TAVILY_API_KEY`
#
# ### TavilySearch
# - Langchain에서 제공하는 tool로 Tavily 의 검색 엔진 API를 사용해 검색을 수행한다.
# - 설치
#   - `pip install langchain-tavily`
# - https://docs.langchain.com/oss/python/integrations/tools/tavily_search

# %% [markdown]
# ### Exa API 검색 Tool
#
# - **Exa** Service: AI(에이전트)를 위한 검색 API Service.
# - https://exa.ai/
# - AI를 위해 웹에서 실시간 최적의 데이터를 검색해 가져오는 검색 API.
#    - 기존의 키워드 기반 검색과 달리, Exa는 **임베딩(neural) 기반 의미 검색**을 중심으로 설계되었다.
#    - 검색 시 `type` 옵션으로 "neural", "keyword", "auto" 중 검색 방식을 선택할 수 있다.
#    - `livecrawl` 옵션("always", "fallback", "never")으로 실시간 크롤링 여부를 제어할 수 있고, `text_contents_options`로 반환되는 본문 텍스트 길이도 조절할 수 있다.
#    - 단순 키워드 매칭으로는 찾기 어려운, 의미적으로 관련된 페이지를 찾는 데 강점이 있다.
#    - 회원가입 시 **$10 무료 크레딧** 제공 (첫 검색 등 특정 액션 완료 시 추가 크레딧 지급).
# - **Exa API Key 받기**
#   - 회원가입 후 로그인한다.
#   - Dashboard에서 API Key를 생성한다.
#     - default API key를 사용할 수 있다.
#   - 환경변수에 등록한다.
#       - 변수이름: `EXA_API_KEY`
#
# #### ExaSearchResults / ExaFindSimilarResults
# - Langchain에서 제공하는 tool로 Exa 의 검색 엔진 API를 사용해 검색을 수행한다.
# - `ExaSearchResults`는 LangChain 에이전트와 함께 사용해 Exa 검색을 수행할 수 있는 tool이다.
# - `ExaFindSimilarResults`는 특정 URL을 기준으로 유사한 페이지를 찾아주는 tool이다.
# - (참고) `ExaSearchRetriever`는 tool이 아닌 retriever 형태로, RAG 체인에 바로 연결해 사용할 수 있다.
# - 설치
#   - `pip install -U langchain-exa`
# - https://docs.langchain.com/oss/python/integrations/tools/exa_search
#
# > Tavily는 "키워드/출처 우선" 성격이 강해 답변에 인용을 붙이기 좋은 반면, Exa는 "의미 기반 유사도 검색"이 강점이라 애매한 자연어 설명만으로도 관련 페이지를 잘 찾아준다.

# %%
# ! uv pip install langchain-tavily
# Out:
# Resolved 45 packages in 1.36s
# Prepared 1 package in 47ms
# Installed 1 package in 50ms
#  + langchain-tavily==0.2.18

# %%
# ! uv pip install -U langchain-exa
# Out:
# Resolved 37 packages in 381ms
# Downloading openai (1.3MiB)
#  Downloaded openai
# Prepared 9 packages in 2.09s
# Uninstalled 7 packages in 611ms
# Installed 9 packages in 902ms
#  - charset-normalizer==3.4.7
#  + charset-normalizer==3.4.8
#  + exa-py==1.16.2
#  - jiter==0.14.0
#  + jiter==0.16.0
#  + langchain-exa==1.1.0
#  - langsmith==0.9.2
#  + langsmith==0.9.8
#  - openai==2.43.0
#  + openai==2.44.0
#  - typing-extensions==4.15.0
#  + typing-extensions==4.16.0
#  - websockets==15.0.1
#  + websockets==16.0
#  - xxhash==3.7.1
#  + xxhash==3.8.1

# %%
from langchain_tavily import TavilySearch
from langchain_exa import ExaSearchResults
from pprint import pprint
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
query= "2026년 북중미 월드컵에서 한국팀 성적은?"
tavily_search = TavilySearch(
    max_results=5 # 검색결과수
) # Runnable
result = tavily_search.invoke(query)
pprint(result)
# Out:
# {'answer': None,
#  'follow_up_questions': None,
#  'images': [],
#  'query': '2026년 북중미 월드컵에서 한국팀 성적은?',
#  'request_id': 'c514c1ba-1a4d-4571-a06f-90e6ce07b94b',
#  'response_time': 1.36,
#  'results': [{'content': '# 한국 32강 진출 좌절... 한국 축구대표팀이 결국 2026 북중미 월드컵에서 조별리그 '
#                          '탈락의 고배를 마셨다. 홍명보 감독이 이끄는 한국 대표팀은 28일(한국시간) 조별리그 K조 '
#                          '일정이 모두 마무리된 뒤 각 조 3위 팀 가운데 성적 상위 8개 팀에게 주어지는 32강 진출 '
#                          '경쟁에서 밀리며 탈락이 확정됐다. 이에 따라 J조 잔여 경기 결과와 관계없이 한국의 32강 '
#                          '진출 가능성은 사라졌다. 이번 탈락으로 한국은 1954년 스위스, 1986년 멕시코, '
#                          '1990년 이탈리아, 1994년 미국, 1998년 프랑스, 2006년 독일, 2014년 '
#                          '브라질, 2018년 러시아 대회에 이어 월드컵 본선에서 역대 아홉 번째 조별리그 탈락을 '
#                          '기록하게 됐다. 한국 축구대표팀은 25일 오전 10시(한국시간) 멕시코 누에보레온주 몬테레이 '
#                          '스타디움에서 열린 조별리그 A조 최종전에서 남아프리카공화국에 0-1로 패배했다. 앞서 한국 '
#                          '축구대표팀은 조별리그 A조 첫 경기인 체코전에서 2-1로 승리를 거뒀으나, 멕시코전에서 '
#                          '1-0으로 패배했다. 한국은 1승 2패로 승점 3점, 골득실차 -1, 그리고 2골을 기록했다. '
#                          '한국의 32강 진출 여부는 크로아티아(L조), 알제리(J조), 그리고 콩고민주공화국(K조)의 '
#                          '남은 경기 결과에 달려 있다. 세 팀이 한국보다 높은 승점을 얻지 못하거나, 승점이 같을 경우 '
#                          '골득실에서 한국에 밀려야 한국의 32강 진출 가능성이 살아날 수 있다.',
#               'raw_content': None,
#               'score': 0.76659125,
#               'title': '한국 32강 진출 결국 좌절... 역대 9번째 조별리그 탈락 - BBC News 코리아',
#               'url': 'https://www.bbc.com/korean/articles/c1ky034l732o'},
#              {'content': '2026 북중미 월드컵 한국 대표팀의 성적은? | 페노 vs 박문성은 생각이 달라 EP. '
#                          '41\n'
#                          '장르가 머니\n'
#                          '149000 subscribers\n'
#                          '641 likes\n'
#                          '109444 views\n'
#                          '4 Jun 2026\n'
#                          '대한민국 축구 대표팀의 운명을 두고, 말빨 좋은 두 해설가가 역대급 끝장 토론을 펼쳤습니다!\n'
#                          '\n'
#                          '과연 여러분은 어느 쪽 의견에 더 공감하시나요? 영상을 통해 두 해설가의 짜릿한 티키타카를 '
#                          '확인해 보세요!\n'
#                          '#월드컵 #북중미월드컵 #대한민국\n'
#                          '281 comments\n',
#               'raw_content': None,
#               'score': 0.7163977,
#               'title': '2026 북중미 월드컵 한국 대표팀의 성적은? | 페노 vs 박문성은 생각이 달라 EP. 41',
#               'url': 'https://www.youtube.com/watch?v=q4hb1bVMMOM'},
#              {'content': '25일(한국시각) 멕시코 몬테레이 인근 과달루페의 에스타디오 몬테레이에서 열린 2026 북중미 '
#                          '월드컵 대한민국과 남아공의 경기. 과달루페(멕시코)=허상욱 '
#                          '기자wook@sportschosun.com/2026.06.25/. 지난 25일 멕시코 '
#                          '몬테레이에서 열린 한국과 남아공의 북중미 월드컵 A조 조별리그 3차전 전반 하이드레이션 '
#                          '브레이크 시간에 홍명보(왼쪽) 감독이 이태석에게 이야기를 하고 있다. 손흥민(가운데)은 다른 '
#                          '쪽을 쳐다보고 있다./허상욱 스포츠조선 기자. 이집트가 27일 북중미 월드컵 조별리그 G조 '
#                          '최종전에서 이란과 1대1로 비겼다. A조 3위 한국은 이집트가 이란을 이겼어야만 G조 3위를 '
#                          '앞설 수 있었다. 한국은 28일 남은 세 가지 경우의 수 중에 두 가지가 충족돼야 극적으로 '
#                          '32강에 합류한다. G조 1위였던 이집트는 이란과 1대1로 비겨 조 2위로 밀려났다. 27일 '
#                          '미국 워싱턴주 시애틀 스타디움에서 열린 이집트와 이란의 경기. 27일 북중미 월드컵 G조 '
#                          '조별리그 3차전 이란-이집트 경기에서 이란 메흐디 타레미(9번)의 헤더가 골대를 맞는 순간 '
#                          '양팀 선수들이 공을 바라보고 있다. 이집트 에이스 모하메드 살라(왼쪽)가 27일 북중미 월드컵 '
#                          '조별리그 3차전 이란전에서 공을 차지하기 위해 상대를 뿌리치고 달려가고 있다. 결국 경기는 '
#                          '1대1로 종료됐고, 이집트는 한 계단 내린 조 2위로 밀려났다. 벨기에 레안드로 트로사르가 '
#                          '27일 뉴질랜드와의 북중미 월드컵 G조 조별리그 3차전에서 두 번째 골을 넣고 기뻐하고 있다.',
#               'raw_content': None,
#               'score': 0.6954834,
#               'title': '결국 8위까지 떨어진 한국… 한칸 밀리면 32강 못 간다',
#               'url': 'https://www.chosun.com/sports/sports_special/2026/06/27/7ZDUQEGKO5C45IEDEZRLDSKSRI'},
#              {'content': "By continuing, you agree to Instagram's Terms of Use "
#                          'and Privacy Policy. May be an image of poster, '
#                          'magazine and text. 🇰🇷 vs 🇨🇿 체코 📆 6월 12일(금) 오전 11시. '
#                          '🇲🇽 멕시코 vs 🇰🇷 📆 6월 19일(금) 오전 10시. 🥉 조 3위 ➡️ 상위 8개 조 '
#                          '3위 안에 들면 32강 진출 가능 ➡️ 강팀과 맞대결 가능성 증가. 한국 월드컵 첫 경기 — '
#                          '체코 2대1 역전승. 후반 22분 이강인 도움 — 황인범 동점골. Video by 진주픽tv '
#                          'on July 02, 2026. May be an image of radar and text. '
#                          'May be an image of top and text. Photo by 진주픽tv on '
#                          'May 28, 2026. Photo by 진주픽tv on July 06, 2026. May '
#                          'be a doodle of poster, magazine and text. May be an '
#                          "image of \u200etext that says '\u200eوتففاء 향공우주산업 "
#                          '진주· 진주·사천, 사천, 312조 프로젝트 수혜지 맞을까? May be an image of '
#                          'video games, Sonic the Hedgehog, poster and text '
#                          "that says '코스피 8000선 공방·삼전실직이분수령 진주픽 반도체 급락·반등, 이번 주 "
#                          '핵심은 결국 실적!',
#               'raw_content': None,
#               'score': 0.6501347,
#               'title': 'Instagram',
#               'url': 'https://www.instagram.com/reel/DZcqskmNWXK'},
#              {'content': "thingthing.kr's profile picture. By continuing, you "
#                          "agree to Instagram's Terms of Use and Privacy "
#                          'Policy. Video by 띵띵 on July 01, 2026. May be an '
#                          "image of \u200etext that says '\u200ething talk 역대 "
#                          "한국 월드컵 조별 리그 성적 모음 kUD #의 لن\u200e'\u200e. 역대 한국 월드컵 "
#                          "조별 리그 성적은?⚽. #월드컵 #한국 #축구 #피파 #FIFA. 3seogiii._.19's "
#                          "profile picture. kuro._.lieblich's profile picture. "
#                          "May be an image of poster and text that says '[저 "
#                          '[짜령] 샤아아!!!!! Photo by 띵띵 on July 02, 2026. May be '
#                          "an image of chicken and text that says '1년동안취두부 1년 "
#                          '동안 취두부 먹방싹기능 먹방 사기는 thing talk talk 한가지 음식만 1년 먹고 돈을 '
#                          "받을 수 있다면?'. May be an image of ice cream and text "
#                          "that says '뜯는곳 기격도 2,900원ㄷㄷ 리포 무려 thing pick 어떤 과자든 "
#                          "들고가면 아이스크림 올려주는 곳'. May be an image of costume and "
#                          "text that says '공주의규칙쇼 공주의 규칙수 thing thingtalk talk "
#                          "나는 는공주일까노비일까 공주일까 노비일까 공주가 많이 태어난 날'.",
#               'raw_content': None,
#               'score': 0.61363083,
#               'title': 'Instagram',
#               'url': 'https://www.instagram.com/reel/DaPe_-thybN'}]}

# %%
query= "2026년 북중미 월드컵에서 한국팀 성적은?"
exa_search = ExaSearchResults(
    max_results=5 # 검색결과수
) # Runnable
result2 = exa_search.invoke(query)
pprint(result2)
# Out:
# SearchResponse(results=[Result(url='https://www.yna.co.kr/view/AKR20260628020651007',
#                                id='https://www.yna.co.kr/view/AKR20260628020651007',
#                                title="[월드컵] 홍명보호, 하늘도 버렸다…사흘 '희망 고문' 끝에 32강행 "
#                                      '좌절(종합) | 연합뉴스',
#                                score=None,
#                                published_date='2026-06-28T01:48:49.000Z',
#                                author='오명언',
#                                image='https://img6.yna.co.kr/photo/yna/YH/2026/06/25/PYH2026062523480001300_P4.jpg',
#                                favicon=None,
#                                subpages=None,
#                                extras=None,
#                                text="[월드컵] 홍명보호, 하늘도 버렸다…사흘 '희망 고문' 끝에 32강행 "
#                                     '좌절(종합) | 연합뉴스\n'
#                                     '\n'
#                                     '연합뉴스본문 바로가기 메뉴 바로가기\n'
#                                     '\n'
#                                     '국가기간뉴스 통신사 연합뉴스국가기간뉴스 통신사 연합뉴스\n'
#                                     '\n'
#                                     '마이페이지로그인검색창 열기 메뉴 열기\n'
#                                     '\n'
#                                     '국가기간뉴스 통신사 연합뉴스국가기간뉴스 통신사 연합뉴스\n'
#                                     '\n'
#                                     "[월드컵] 홍명보호, 하늘도 버렸다…사흘 '희망 고문' 끝에 32강행 "
#                                     '좌절(종합)\n'
#                                     '\n'
#                                     '북마크 공유 댓글 글자크기 프린트제보\n'
#                                     '\n'
#                                     '마이페이지로그인검색창 열기 메뉴 열기\n'
#                                     '\n'
#                                     '오명언기자 구독 구독중\n'
#                                     '\n'
#                                     '이전 다음\n'
#                                     '\n'
#                                     '## 통산 3번째 원정 16강 도전 일찌감치 실패, 역대 9번째 조별리그 '
#                                     '탈락 고배\n'
#                                     '\n'
#                                     '## 최종 성적 33위 혹은 34위…예전 32개 참가 대회 기준 본선도 못 '
#                                     '오른 성적\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '‘이런’\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 홍명보 감독이 '
#                                     '24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 북중미 월드컵 '
#                                     'A조 3차전 남아프리카공화국과의 경기에서 어두운 표정을 하고 있다. '
#                                     '2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     "(과달라하라=연합뉴스) 오명언 기자 = 홍명보호가 사흘의 '희망 고문' "
#                                     '끝에 2026 북중미 월드컵 조별리그 탈락의 굴욕을 맛봤다.\n'
#                                     '\n'
#                                     '홍명보 감독이 지휘해온 한국 축구대표팀은 28일(이하 한국시간) 대회 '
#                                     '조별리그 K조 경기 결과 조 3위 팀 간 경쟁에서 32강 진출 마지노선인 '
#                                     '8위 밖으로 밀려났다.\n'
#                                     '\n'
#                                     '이날 남은 J조 경기 결과와 관계없이 한국의 탈락은 확정됐다.\n'
#                                     '\n'
#                                     '한국 축구가 월드컵 조별리그를 통과하지 못한 건 2018년 러시아 대회 '
#                                     '이후 8년 만의 일이다.\n'
#                                     '\n'
#                                     '홍명보호는 2010년 남아공(16강), 2022년 카타르(16강) 대회에 '
#                                     '이어 통산 3번째이자 2회 연속 원정 16강 진출에 도전했으나 뜻을 이루지 '
#                                     '못했다.\n'
#                                     '\n'
#                                     '한국이 월드컵에서 조별리그 탈락한 건 1954년 스위스, 1986년 '
#                                     '멕시코, 1990년 이탈리아, 1994년 미국, 1998년 프랑스, '
#                                     '2006년 독일, 2014년 브라질, 2018년 러시아 대회에 이어 이번이 '
#                                     '9번째다.\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '아쉬워하는 손흥민\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 주장 손흥민이 '
#                                     '24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 북중미 월드컵 '
#                                     'A조 3차전 남아프리카공화국과의 경기에서 0대1로 패배한 뒤 아쉬워 하고 '
#                                     '있다. 2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '한국은 J조 결과에 따라 33위 혹은, 34위의 최종 성적표를 받아 '
#                                     '든다.\n'
#                                     '\n'
#                                     '이번 대회에서 처음으로 참가국이 48개국으로 확대됐다. 32개국이 경쟁한 '
#                                     '예전 대회 기준으로 따지면 본선 진출도 해내지 못한 거나 마찬가지인, '
#                                     '처참한 성적이다.\n'
#                                     '\n'
#                                     '2014년 브라질 대회에서 대표팀을 이끌고 1무 2패의 성적을 내 '
#                                     "2002년 한일 대회 '4강 신화'의 주역에서 '실패의 아이콘'으로 "
#                                     '전락했던 홍 감독은 사령탑으로 받은 두 번째 월드컵 기회도 성공으로 마무리 '
#                                     '짓지 못하며 다시 한번 추락할 위기에 놓였다.\n'
#                                     '\n'
#                                     '특히 대회를 불과 1년 앞두고 지휘봉을 잡았던 브라질 대회와 달리 이번에는 '
#                                     '개막을 2년 앞두고 선임돼 충분한 준비 시간이 있었다.\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '작전 지시하는 홍명보 감독\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 류영석 기자 = 24일(현지시간) 멕시코 몬테레이 '
#                                     '스타디움에서 열린 2026 북중미 월드컵 A조 3차전 남아프리카공화국과의 '
#                                     '경기. 홍명보 감독이 선수들에게 작전을 지시하고 있다. 2026.6.25 '
#                                     'ondol@yna.co.kr\n'
#                                     '\n'
#                                     '조별리그 A조로 묶인 한국은 지난 12일 체코와 1차전에서 2-1 역전승을 '
#                                     "거뒀으나 19일 '개최국' 멕시코와의 2차전에선 선전을 펼치고도 수비 "
#                                     '실수에 실점하며 0-1로 석패했다.\n'
#                                     '\n'
#                                     '1, 2차전 장소이자 베이스캠프를 둔 멕시코 과달라하라를 떠나 몬테레이에서 '
#                                     '25일 치른 남아프리카공화국과 마지막 3차전에서 졸전 끝에 0-1로 '
#                                     '충격적인 패배를 당하면서 홍명보호는 승점 3에 머물며 조 3위로 '
#                                     '떨어졌다.\n'
#                                     '\n'
#                                     '한국은 26∼28일 사흘에 걸쳐 다른 조 결과를 초조하게 기다려야 했다.\n'
#                                     '\n'
#                                     '남아공전 직후 기준으로 한국은 3위 간 순위에서 4위로 높은 축이라 32강 '
#                                     '진출 가능성은 작지 않아 보였다.\n'
#                                     '\n'
#                                     "이어진 9개 조 경기에서 한국에 유리한 '경우의 수'가 3개만 실현돼도 "
#                                     '한국은 다음 단계로 나아갈 수 있었다.\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '한국, 32강 자력진출 실패\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 손흥민 등 '
#                                     '선수들이 24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 '
#                                     '북중미 월드컵 A조 3차전 남아프리카공화국과의 경기에서 0대1로 패배한 뒤 '
#                                     '아쉬워하고 있다. 2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '그러나 이후 사흘에 걸쳐 K조까지 8개 조 경기가 치러지는 동안 한국에 '
#                                     '유리한 결과가 나온 건 27일 경기에서 스페인이 우루과이에 이긴 것 '
#                                     '하나뿐이었다.\n'
#                                     '\n'
#                                     '이날 K조에서 우즈베키스탄이 콩고민주공화국에 1-3으로 역전패하면서 한국의 '
#                                     "탈락은 확정됐다. '하늘'도 홍명보호를 버린 셈이다.\n"
#                                     '\n'
#                                     "이번이 4번째 월드컵 무대였던 한국 축구의 '캡틴' 손흥민(LAFC)은 "
#                                     "확연한 '에이징 커브'를 그리며 공격포인트 '제로'에 그쳤다.\n"
#                                     '\n'
#                                     '한 골만 넣었다면 안정환, 박지성을 넘어 한국인 월드컵 최다 4골 신기록을 '
#                                     '쓸 수 있었지만, 한국이 32강 진출에 실패하면서 더는 기회가 주어지지 '
#                                     '않았다.\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '아쉬운 패배\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 류영석 기자 = 24일(현지시간) 멕시코 몬테레이 '
#                                     '스타디움에서 열린 2026 북중미 월드컵 A조 3차전 한국과 '
#                                     '남아프리카공화국의 경기. 한국의 손흥민이 0-1 경기 종료 후 아쉬운 '
#                                     '표정을 짓고 있다. 2026.6.25 ondol@yna.co.kr\n'
#                                     '\n'
#                                     'coup@yna.co.kr\n'
#                                     '\n'
#                                     '관련 뉴스\n'
#                                     '\n'
#                                     '- [2보][월드컵] 한국, 8년 만에 조별리그 탈락…32강 진출 끝내 '
#                                     '좌절\n'
#                                     '- [월드컵] 오늘이 마지막일지 모르지만…32강 간절한 홍명보호 묵묵히 '
#                                     '훈련\n'
#                                     '- [월드컵] 한국, 32강 가면 독일 피해 G조 1위와 시애틀서 격돌\n'
#                                     '- [월드컵] 한국, 32강 가면 벨기에와 격돌…확률은 30%대까지 '
#                                     '추락(종합)\n'
#                                     '\n'
#                                     '제보는 카카오톡 okjebo<저작권자(c) 연합뉴스, 무단 전재-재배포, '
#                                     'AI 학습 및 활용 금지>\n'
#                                     '\n'
#                                     '댓글\n'
#                                     '\n'
#                                     '좋아요 슬퍼요 화나요 후속요청\n'
#                                     '\n'
#                                     '북마크\n'
#                                     '\n'
#                                     '공유\n'
#                                     '\n'
#                                     '공유하기\n'
#                                     '\n'
#                                     '카카오톡 페이스북 X 페이스북 메신저 네이버 밴드 URL 복사\n'
#                                     '\n'
#                                     '닫기\n'
#                                     '\n'
#                                     'URL이 복사되었습니다.\n'
#                                     '\n'
#                                     '댓글\n'
#                                     '\n'
#                                     '글자크기\n'
#                                     '\n'
#                                     '본문 글자 크기 조정\n'
#                                     '\n'
#                                     '폰트 1단계 13px 폰트 2단계 16px 폰트 3단계 18px 폰트 '
#                                     '4단계 20px 폰트 5단계 22px\n'
#                                     '\n'
#                                     '닫기\n'
#                                     '\n'
#                                     '유럽인들이 노점서 떡볶이를 먹는다\n'
#                                     '\n'
#                                     "[베네수 강진] 유기견서 구조견으로…베네수 국민의 희망이 된 '쓰나미'\n"
#                                     '\n'
#                                     '80년 계엄, 김종필 불법구금…장녀에게 1억4천만원 국가배상\n'
#                                     '\n'
#                                     '코스피 150배·삼전닉스 50배에 뭉칫돈…"무법지대 도박판"\n'
#                                     '\n'
#                                     "[월드컵] 네덜란드 공격수 학포, '둘째 유산' 비보에도 32강 준비\n"
#                                     '\n'
#                                     '"스마트폰 걷었더니 서울대 대박"…\'폰프리스쿨\' 성공 사례 주목\n'
#                                     '\n'
#                                     '"경찰에 밥 사고 싶다" K-치안에 감탄한 젠슨 황 가족\n'
#                                     '\n'
#                                     '"구청인데 소화기 사세요"…고령 자영업자 울리는 신종사기 비상\n'
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     '[영상] 흙먼지속 아기, 눈만 껌벅이던 강아지…참혹 현장속 기적의 순간\n'
#                                     '\n'
#                                     '[영상] 냉방기기 품귀·대규모 정전…기록적 폭염에 신음하는 유럽\n'
#                                     '\n'
#                                     "[영상] '핵 올인' 김정은, 트럼프와 담판 시도할 유일한 변수\n"
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     "[월드컵] 홍명보호, 하늘도 버렸다… 사흘 '희망 고문' 끝에 32강행 "
#                                     '좌절\n'
#                                     '\n'
#                                     '美·이란, 연이틀 무력공방…트럼프 "이란 존재하지 않을 수도"\n'
#                                     '\n'
#                                     '베네수 강진후 72시간 골든타임 지나…구조현장엔 희망·절망 교차\n'
#                                     '\n'
#                                     '6월 한달 내내 출렁인 코스피…실적 시즌 7월에는 다를까\n'
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     '### 랭킹뉴스\n'
#                                     '\n'
#                                     '- 많이 본 뉴스\n'
#                                     '- 공감 많은 뉴스\n'
#                                     '\n'
#                                     '한국, 해상 연합훈련 림팩서 첫 해군 지휘\n'
#                                     '\n'
#                                     "'최악 지진' 베네수엘라…참혹 현장 속 '기적의 순간'\n"
#                                     '\n'
#                                     '화면 상단으로 이동\n'
#                                     '\n'
#                                     '뉴스레터연합뉴스 Games APP설치\n'
#                                     '\n'
#                                     '뉴스\n'
#                                     '\n'
#                                     '정치메뉴 열기/닫기\n'
#                                     '\n'
#                                     '북한메뉴 열기/닫기\n'
#                                     '\n'
#                                     '경제메뉴 열기/닫기\n'
#                                     '\n'
#                                     '마켓+메뉴 열기/닫기\n'
#                                     '\n'
#                                     '산업메뉴 열기/닫기\n'
#                                     '\n'
#                                     '사회메뉴 열기/닫기\n'
#                                     '\n'
#                                     '전국메뉴 열기/닫기\n'
#                                     '\n'
#                                     '세계메뉴 열기/닫기\n'
#                                     '\n'
#                                     '문화메뉴 열기/닫기\n'
#                                     '\n'
#                                     '건강메뉴 열기/닫기\n'
#                                     '\n'
#                                     '연예메뉴 열기/닫기\n'
#                                     '\n'
#                                     '스포츠메뉴 열기/닫기\n'
#                                     '\n'
#                                     '사람들메뉴 열기/닫기\n'
#                                     '\n'
#                                     '뉴스+ 메뉴 열기/닫기\n'
#                                     '\n'
#                                     '비주얼뉴스메뉴 열기/닫기\n'
#                                     '\n'
#                                     '테마별뉴스 메뉴 열기/닫기\n'
#                                     '\n'
#                                     '외국어 뉴스\n'
#                                     '\n'
#                                     '뉴스상품\n'
#                                     '\n'
#                                     '출판물\n'
#                                     '\n'
#                                     '서비스안내\n'
#                                     '\n'
#                                     '- 서비스 소개\n'
#                                     '- 모바일앱 안내\n'
#                                     '\n'
#                                     'SNS\n'
#                                     '\n'
#                                     '다양한 채널에서 연합뉴스를 만나보세요!\n'
#                                     '\n'
#                                     '뉴스 검색어 입력 양식\n'
#                                     '\n'
#                                     '통합 검색 삭제 검색\n'
#                                     '\n'
#                                     '전체메뉴 닫기\n'
#                                     '\n'
#                                     '뉴스\n'
#                                     '\n'
#                                     '정치메뉴 열기/닫기\n'
#                                     '\n'
#                                     '북한메뉴 열기/닫기\n'
#                                     '\n'
#                                     '경제메뉴 열기/닫기\n'
#                                     '\n'
#                                     '마켓+메뉴 열기/닫기\n'
#                                     '\n'
#                                     '산업메뉴 열기/닫기\n'
#                                     '\n'
#                                     '사회메뉴 열기/닫기\n'
#                                     '\n'
#                                     '전국메뉴 열기/닫기\n'
#                                     '\n'
#                                     '세계메뉴 열기/닫기\n'
#                                     '\n'
#                                     '문화메뉴 열기/닫기\n'
#                                     '\n'
#                                     '건강메뉴 열기/닫기\n'
#                                     '\n'
#                                     '연예메뉴 열기/닫기\n'
#                                     '\n'
#                                     '스포츠메뉴 열기/닫기\n'
#                                     '\n'
#                                     '사람들메뉴 열기/닫기\n'
#                                     '\n'
#                                     '뉴스+ 메뉴 열기/닫기\n'
#                                     '\n'
#                                     '비주얼뉴스메뉴 열기/닫기\n'
#                                     '\n'
#                                     '테마별뉴스 메뉴 열기/닫기\n'
#                                     '\n'
#                                     '외국어 뉴스\n'
#                                     '\n'
#                                     '뉴스상품\n'
#                                     '\n'
#                                     '출판물\n'
#                                     '\n'
#                                     '서비스안내\n'
#                                     '\n'
#                                     '- 서비스 소개\n'
#                                     '- 모바일앱 안내\n'
#                                     '\n'
#                                     'SNS\n'
#                                     '\n'
#                                     '다양한 채널에서 연합뉴스를 만나보세요!\n'
#                                     '\n'
#                                     'ESC 닫기\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '‘이런’\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 홍명보 감독이 '
#                                     '24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 북중미 월드컵 '
#                                     'A조 3차전 남아프리카공화국과의 경기에서 어두운 표정을 하고 있다. '
#                                     '2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:29\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '아쉬워하는 손흥민\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 주장 손흥민이 '
#                                     '24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 북중미 월드컵 '
#                                     'A조 3차전 남아프리카공화국과의 경기에서 0대1로 패배한 뒤 아쉬워 하고 '
#                                     '있다. 2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:43\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '작전 지시하는 홍명보 감독\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 류영석 기자 = 24일(현지시간) 멕시코 몬테레이 '
#                                     '스타디움에서 열린 2026 북중미 월드컵 A조 3차전 남아프리카공화국과의 '
#                                     '경기. 홍명보 감독이 선수들에게 작전을 지시하고 있다. 2026.6.25 '
#                                     'ondol@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:43\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '한국, 32강 자력진출 실패\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 손흥민 등 '
#                                     '선수들이 24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 '
#                                     '북중미 월드컵 A조 3차전 남아프리카공화국과의 경기에서 0대1로 패배한 뒤 '
#                                     '아쉬워하고 있다. 2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:44\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '아쉬운 패배\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 류영석 기자 = 24일(현지시간) 멕시코 몬테레이 '
#                                     '스타디움에서 열린 2026 북중미 월드컵 A조 3차전 한국과 '
#                                     '남아프리카공화국의 경기. 한국의 손흥민이 0-1 경기 종료 후 아쉬운 '
#                                     '표정을 짓고 있다. 2026.6.25 ondol@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:44\n'
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     '메뉴 열기/닫기\n'
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     '본문으로 돌아가기\n'
#                                     '\n'
#                                     '댓글 닫기',
#                                highlights=None,
#                                highlight_scores=None,
#                                summary=None),
#                         Result(url='https://www.hankyung.com/article/2026062821597',
#                                id='https://www.hankyung.com/article/2026062821597',
#                                title='홍명보호, 북중미 월드컵 최종 34위 마감…역대 최저 순위 | 한국경제',
#                                score=None,
#                                published_date='2026-06-28T06:22:55.000Z',
#                                author=None,
#                                image=None,
#                                favicon=None,
#                                subpages=None,
#                                extras=None,
#                                text='# 홍명보호, 북중미 월드컵 최종 34위 마감…역대 최저 순위 | '
#                                     '한국경제\n'
#                                     '\n'
#                                     'Published: 2026-06-28T15:22:55+09:00\n'
#                                     'Source: hankyung.com (hankyung.com)\n'
#                                     'Language: ko\n'
#                                     '\n'
#                                     '## Story\n'
#                                     '\n'
#                                     '홍명보호, 북중미 월드컵 최종 34위 마감…역대 최저 순위 | 한국경제\n'
#                                     '\n'
#                                     '본문 바로가기\n'
#                                     '\n'
#                                     '전체메뉴\n'
#                                     '\n'
#                                     '통합검색\n'
#                                     '\n'
#                                     '한국경제 통합검색\n'
#                                     '\n'
#                                     '검색어 삭제\n'
#                                     '\n'
#                                     '검색\n'
#                                     '\n'
#                                     '검색창 닫기\n'
#                                     '\n'
#                                     '[![한국경제](https://hkstatic.hankyung.com/resource/common/img/logo/logo-hk-short.svg)](https://www.hankyung.com/)\n'
#                                     '\n'
#                                     '[신문 '
#                                     '구독](https://members.hankyung.com/?utm_source=dotcom&utm_medium=top&utm_campaign=affiliate)\n'
#                                     '\n'
#                                     '한경 프리미엄9 구독\n'
#                                     '\n'
#                                     '[로그인](https://member.hankyung.com/apps.frame/login)\n'
#                                     '\n'
#                                     'My한경\n'
#                                     '\n'
#                                     '[한국경제](https://www.hankyung.com/)전체메뉴 닫기\n'
#                                     '\n'
#                                     '그룹별 가나다순\n'
#                                     '\n'
#                                     '미디어그룹\n'
#                                     '\n'
#                                     '최근 사용 메뉴\n'
#                                     '\n'
#                                     '전문채널\n'
#                                     '\n'
#                                     '특정 주제에 집중한 한경의 전문 콘텐츠 서비스\n'
#                                     '\n'
#                                     '# 트렌드\n'
#                                     '\n'
#                                     '[https://www.hankyung.com/trend](https://www.hankyung.com/trend)\n'
#                                     '\n'
#                                     '- '
#                                     '[핫피플](https://www.hankyung.com/trend/hotpeople)\n'
#                                     '- '
#                                     '[연예](https://www.hankyung.com/trend/entertainment)\n'
#                                     '- '
#                                     '[건강](https://www.hankyung.com/trend/health)\n'
#                                     '- '
#                                     '[음식맛집](https://www.hankyung.com/trend/food)\n'
#                                     '- '
#                                     '[여행레저](https://www.hankyung.com/trend/tour)\n'
#                                     '- '
#                                     '[날씨](https://www.hankyung.com/trend/weather)\n'
#                                     '- '
#                                     '[스포츠](https://www.hankyung.com/trend/sports)\n'
#                                     '- '
#                                     '[연예포토](https://www.hankyung.com/trend/celebrity-photo)\n'
#                                     '- [트렌드 '
#                                     '일반](https://www.hankyung.com/trend/trend-others)\n'
#                                     '\n'
#                                     '[트렌드](https://www.hankyung.com/trend)\n'
#                                     '\n'
#                                     '[한경 PREMIUM9 AI를 넘어서는 성공투자 '
#                                     '구독하기](https://www.hankyung.com/premium9/open-event)\n'
#                                     '\n'
#                                     '# 홍명보호, 북중미 월드컵 최종 34위 마감…역대 최저 순위\n'
#                                     '\n'
#                                     '입력2026.06.28 15:22 수정2026.06.28 15:25\n'
#                                     '\n'
#                                     '기사 스크랩\n'
#                                     '\n'
#                                     '기사 스크랩\n'
#                                     '\n'
#                                     '댓글\n'
#                                     '\n'
#                                     '댓글\n'
#                                     '\n'
#                                     '기사 공유\n'
#                                     '\n'
#                                     '공유\n'
#                                     '\n'
#                                     '글자크기 조절\n'
#                                     '\n'
#                                     '글자크기\n'
#                                     '\n'
#                                     '프린트\n'
#                                     '\n'
#                                     '프린트\n'
#                                     '\n'
#                                     '[![박상경 '
#                                     '](https://hkstatic.hankyung.com/resource/common/img/thumb/thumb-profile.svg)](https://www.hankyung.com/reporter/6143)\n'
#                                     '\n'
#                                     '[박상경](https://www.hankyung.com/reporter/6143)기자 '
#                                     '구독하기\n'
#                                     '\n'
#                                     '[구글 검색 선호 출처로 '
#                                     '추가](https://www.google.com/preferences/source?q=hankyung.com)\n'
#                                     '\n'
#                                     'Google 검색에서 한국경제 기사를 더 자주 볼 수 있습니다.\n'
#                                     '\n'
#                                     '조별리그 1승 2패 조 3위 마감 각 조 3위 상위 8개 팀에 들지 못해 '
#                                     '탈락 확정 홍명보 감독 "데이터로도 경기력 저하 원인 찾기 어려워"\n'
#                                     '\n'
#                                     '![사진=뉴스1](https://img.hankyung.com/photo/202606/ZN.44828316.1.jpg)\n'
#                                     '\n'
#                                     '사진=뉴스1 홍명보 감독이 이끄는 한국 축구대표팀이 2026 '
#                                     '국제축구연맹(FIFA) 북중미 월드컵에서 32강 토너먼트 진출에 실패하며 '
#                                     '최종 순위 34위로 대회를 마감했다.28일 한국은 이번 대회 조별리그 '
#                                     'A조에서 1승 2패(승점 3·득실 차 -1)를 기록하며 조 3위로 '
#                                     '조별리그를 마쳤다. 이번 대회부터 본선 출전국이 32개국에서 48개국으로 '
#                                     '확대 개편되면서 각 조 1·2위 24개 팀과 조 3위 12개 팀 중 상위 '
#                                     '8개 팀이 32강 토너먼트에 진출하는 구조였다. 그러나 조별리그 최종일 '
#                                     '경기 결과 한국은 조 3위 팀 중 10위에 그치며 탈락이 확정됐다.이에 '
#                                     '따라 한국의 최종 순위는 48개 참가국 중 34위가 됐다. 이는 16개국이 '
#                                     '출전해 최하위를 기록했던 1954년 스위스 대회를 제외하고, 조별리그 제도 '
#                                     '도입 이후 종전 최저 순위였던 1998년 프랑스 대회(30위)보다 낮은 '
#                                     '역대 최저 성적이다. 홍 감독 체제 1기였던 2014년 브라질 대회 당시 '
#                                     '최종 순위는 27위였다. 한국 축구의 조별리그 탈락은 2018년 러시아 '
#                                     '대회 이후 8년 만이며 통산 9번째다.한국은 조별리그 1차전에서 체코를 '
#                                     '상대로 황인범(페예노르트)과 오현규(베식타시)의 연속골에 힘입어 2-1 '
#                                     '역전승을 거두며 출발했다. 그러나 개최국 멕시코와의 2차전에서 후반 5분 '
#                                     '골키퍼 김승규(FC도쿄)의 실책으로 결승골을 내주며 0-1로 패했다. 이어 '
#                                     '비기기만 해도 조 2위로 32강에 오를 수 있었던 남아프리카공화국과의 '
#                                     '최종전에서 손흥민(LAFC)이 선발 제외된 가운데 0-1로 패배하며 자력 '
#                                     "진출 기회를 놓쳤다.남아공전 패배 직후 스포츠통계업체 '옵타'는 한국의 "
#                                     '32강 진출 확률을 87%로 전망했으나, 타 조의 타임라인 및 경우의 수 '
#                                     '시뮬레이션 결과 스페인의 우루과이전 승리(1-0) 외에는 한국에 유리한 '
#                                     '결과가 나오지 않았다. 최종적으로 K조 경기에서 콩고민주공화국이 '
#                                     '우즈베키스탄에 3-1 역전승을 거두고, J조 오스트리아와 알제리가 '
#                                     '3-3으로 비기면서 한국의 탈락 및 최종 34위 순위가 확정됐다.대표팀 '
#                                     '내부에서도 경기력 저하에 대한 원인을 정밀하게 진단하지 못했다. 홍 감독은 '
#                                     '남아공전 패배 이튿날 취재진과의 인터뷰에서 "데이터로도 이유를 찾기 '
#                                     '어려웠다"며 "나도 왜 이런 경기력이 나왔는지 당황스럽다"고 '
#                                     '언급했다.선수단은 28일 저녁 식사를 함께하며 타 조 경기를 시켜본 뒤 '
#                                     '탈락이 확정됨에 따라 귀국 일정을 정리했다. 한편 이번 대회 48개 참가국 '
#                                     '중 최하위인 48위는 3패(승점 0·득실 차 -11)를 기록한 이라크가 '
#                                     '차지했으며, 1승 2패(승점 3·득실 차 0)의 이란은 33위로 대회를 '
#                                     '마쳤다.홍 감독은 오는 29일 현지 결산 기자회견을 가진 후 선수단과 함께 '
#                                     '미국을 경유해 30일 인천국제공항을 통해 귀국할 예정이다.박상경 한경닷컴 '
#                                     '기자 highseoul@hankyung.com\n'
#                                     '\n'
#                                     '좋아요 싫어요 후속기사 원해요\n'
#                                     '\n'
#                                     'ⓒ 한경닷컴, 무단전재 및 재배포 금지\n'
#                                     '\n'
#                                     '[한국경제 '
#                                     '구독신청](https://members.hankyung.com/?utm_source=dotcom&amp;utm_medium=article&utm_campaign=affiliate) '
#                                     '[한경 프리미엄9 '
#                                     '구독신청](https://www.hankyung.com/premium9/open-event)\n'
#                                     '\n'
#                                     '![박상경 '
#                                     '](https://hkstatic.hankyung.com/resource/common/img/thumb/thumb-profile.svg)\n'
#                                     '\n'
#                                     '[박상경](https://www.hankyung.com/reporter/6143)\n'
#                                     '\n'
#                                     '관련 뉴스\n'
#                                     '\n'
#                                     '[![ALICE Q 게임 '
#                                     '바로가기](https://img.hankyung.com/data/service/www.hankyung.com/articlePromotion/img/ae0b10dd5abf25a3d2cc6c0a0a9940f8.png)](https://www.hankyung.com/game)\n'
#                                     '\n'
#                                     '1\n'
#                                     '\n'
#                                     "[홍명보호, 처음으로 '귀국 행사' 생략…엿 세례 "
#                                     '걱정됐나](https://www.hankyung.com/article/2026062820617)\n'
#                                     '\n'
#                                     '2026 북중미 월드컵에서 손흥민·이강인·김민재 등 역대 최고 수준으로 '
#                                     '평가받는 멤버와 비교적 수월한 대진으로 기대감을 모았던 한국 축구대표팀이 '
#                                     '결국 32강 토너먼트 진출에 실패하고 씁쓸하게...\n'
#                                     '\n'
#                                     '2026.06.28 13:42\n'
#                                     '\n'
#                                     "[![홍명보호, 처음으로 '귀국 행사' 생략…엿 세례 "
#                                     '걱정됐나](https://img.hankyung.com/photo/202606/ZA.44793299.3.jpg)](https://www.hankyung.com/article/2026062820617)\n'
#                                     '\n'
#                                     '2\n'
#                                     '\n'
#                                     '[홍명보 감독 잘못인데, 왜 조나단에 악플…엉뚱한 '
#                                     '분풀이](https://www.hankyung.com/article/2026062820687)\n'
#                                     '\n'
#                                     '방송인 조나단이 한국의 월드컵 32강 진출이 불발된 후 악플 공격을 '
#                                     '받으면서 "엉뚱한 분풀이"라는 지적이 나오고 있다.28일 미국 조지아주 '
#                                     '애틀랜타 스타디움에서 2026 FIFA 북중미 월드컵 K조 콩고민주공화국과 '
#                                     '...\n'
#                                     '\n'
#                                     '2026.06.28 13:36\n'
#                                     '\n'
#                                     '[![홍명보 감독 잘못인데, 왜 조나단에 악플…엉뚱한 '
#                                     '분풀이](https://img.hankyung.com/photo/202606/01.44827848.3.jpg)](https://www.hankyung.com/article/2026062820687)\n'
#                                     '\n'
#                                     '3\n'
#                                     '\n'
#                                     '[박지성, 한국 32강 탈락에 "10년간 배우고도 까먹었다" '
#                                     '분노](https://www.hankyung.com/article/2026062819697)\n'
#                                     '\n'
#                                     '홍명보 감독이 이끄는 국가대표 축구팀이 2026 FIFA 북중미 월드컵 '
#                                     '32강 진출에 실패한 후 박지성 SBS 해설위원이 작심 발언을 '
#                                     '했다.박지성은 28일(한국시간) 미국 조지아주 애틀랜타 스타디움에서 열린 '
#                                     '북중미 ...\n'
#                                     '\n'
#                                     '2026.06.28 11:30\n'
#                                     '\n'
#                                     '[![박지성, 한국 32강 탈락에 "10년간 배우고도 까먹었다" '
#                                     '분노](https://img.hankyung.com/photo/202606/02.44790884.3.jpg)](https://www.hankyung.com/article/2026062819697)\n'
#                                     '\n'
#                                     '많이 본 뉴스\n'
#                                     '\n'
#                                     '1\n'
#                                     '\n'
#                                     '["다이소도 아닌데"…3만원 들고 가면 가방에 옷까지 '
#                                     '풀세팅](https://www.hankyung.com/article/202606269802g)\n'
#                                     '\n'
#                                     '2026.06.27 20:00\n'
#                                     '\n'
#                                     '[!["다이소도 아닌데"…3만원 들고 가면 가방에 옷까지 '
#                                     '풀세팅](https://img.hankyung.com/photo/202606/01.44803495.3.jpg)](https://www.hankyung.com/article/202606269802g)\n'
#                                     '\n'
#                                     '2\n'
#                                     '\n'
#                                     '["대실 안 해요" 서울 모텔 돌변한 이유가…\'돈벼락\' '
#                                     '맞았다](https://www.hankyung.com/article/2026062607161)\n'
#                                     '\n'
#                                     '2026.06.26 20:00\n'
#                                     '\n'
#                                     '[!["대실 안 해요" 서울 모텔 돌변한 이유가…\'돈벼락\' '
#                                     '맞았다](https://img.hankyung.com/photo/202606/99.44809122.3.jpg)](https://www.hankyung.com/article/2026062607161)\n'
#                                     '\n'
#                                     '3\n'
#                                     '\n'
#                                     '["집에서 삼겹살 자주 구워 먹었는데"…뜻밖의 연구 '
#                                     '결과](https://www.hankyung.com/article/2026062588137)\n'
#                                     '\n'
#                                     '2026.06.25 22:07\n'
#                                     '\n'
#                                     '[!["집에서 삼겹살 자주 구워 먹었는데"…뜻밖의 연구 '
#                                     '결과](https://img.hankyung.com/photo/202606/99.26416666.3.jpg)](https://www.hankyung.com/article/2026062588137)\n'
#                                     '\n'
#                                     '4\n'
#                                     '\n'
#                                     '[![PREMIUM9](https://hkstatic.hankyung.com/resource/www/common/img/icon/icon-premium9.svg)](https://www.hankyung.com/premium9/0102001) '
#                                     '[핫스톡](https://www.hankyung.com/premium9/0102001)\n'
#                                     '\n'
#                                     '[삼전닉스 못 샀다면…올해 소외된 대형주 10개 '
#                                     '뽑아보니](https://www.hankyung.com/article/202606260168i)\n'
#                                     '\n'
#                                     '2026.06.27 08:00\n'
#                                     '\n'
#                                     '[![삼전닉스 못 샀다면…올해 소외된 대형주 10개 '
#                                     '뽑아보니](https://img.hankyung.com/photo/202606/01.44806377.3.jpg)](https://www.hankyung.com/article/202606260168i)\n'
#                                     '\n'
#                                     '5\n'
#                                     '\n'
#                                     "['자산 26억' 58세 명퇴자, 국민연금 7년 "
#                                     "남았는데…'날벼락'](https://www.hankyung.com/article/202606260031i)\n"
#                                     '\n'
#                                     '2026.06.27 10:00\n'
#                                     '\n'
#                                     "[!['자산 26억' 58세 명퇴자, 국민연금 7년 "
#                                     "남았는데…'날벼락'](https://img.hankyung.com/photo/202606/01.44804978.3.jpg)](https://www.hankyung.com/article/202606260031i)\n"
#                                     '\n'
#                                     '이 시각 관심정보\n'
#                                     '\n'
#                                     '팝업 닫기\n'
#                                     '\n'
#                                     '글자크기\n'
#                                     '\n'
#                                     '- 1단계\n'
#                                     '- 2단계\n'
#                                     '- 3단계\n'
#                                     '- 4단계\n'
#                                     '- 5단계\n'
#                                     '\n'
#                                     '글자행간\n'
#                                     '\n'
#                                     '- 1단계\n'
#                                     '- 2단계\n'
#                                     '- 3단계\n'
#                                     '\n'
#                                     '팝업 닫기\n'
#                                     '\n'
#                                     '- 카카오톡\n'
#                                     '- 페이스북\n'
#                                     '- 엑스\n'
#                                     '- URL복사\n'
#                                     '- 네이버\n'
#                                     '- 밴드\n'
#                                     '- 메일\n'
#                                     '\n'
#                                     '팝업 닫기\n'
#                                     '\n'
#                                     '로그인이 필요한 서비스 입니다. 로그인 하시겠습니까?\n'
#                                     '\n'
#                                     '아니오 예\n'
#                                     '\n'
#                                     '한국경제신문 '
#                                     '[회사소개](https://company.hankyung.com/ked/) '
#                                     '[구독신청](https://members.hankyung.com/?utm_source=dotcom&utm_medium=footer&utm_campaign=affiliate) '
#                                     '[고충처리](https://company.hankyung.com/ked/kor/ombudsman) '
#                                     '[광고안내](https://company.hankyung.com/ked/kor/ad) '
#                                     '[블루애드](https://ooh.hankyung.com/)대표번호: '
#                                     '02-3604-114 사업자등록번호: 110-81-07390 '
#                                     '통신판매업신고번호: 중구 02559\n'
#                                     '\n'
#                                     '한경닷컴 '
#                                     '[회사소개](https://company.hankyung.com/dotcom/) '
#                                     '[제휴](https://company.hankyung.com/dotcom/partnership/business/)/ '
#                                     '[콘텐츠구입](https://company.hankyung.com/dotcom/partnership/contents/) '
#                                     '[광고안내](https://company.hankyung.com/dotcom/partnership/advertising/) '
#                                     '[사이트맵](https://www.hankyung.com/sitemap.html) '
#                                     '[고객센터](https://www.hankyung.com/help) '
#                                     '[RSS](https://www.hankyung.com/feed) '
#                                     '[이용약관](https://id.hankyung.com/user/selectAuthAgree.do) '
#                                     '[개인정보처리방침](https://id.hankyung.com/user/selectPrivacy.do) '
#                                     '[청소년보호정책(책임자: '
#                                     '이지연)](https://id.hankyung.com/user/selectYouthProtection.do)서울시 '
#                                     '중구 청파로 463 한국경제신문사 대표번호: 02-3277-9900 '
#                                     '사업자등록번호: 104-81-47984 통신판매업신고번호: 중구 00606 '
#                                     '인터넷신문등록번호: 서울 아01035 등록(발행)일자: 2009.11.23 '
#                                     '발행·편집인: 박수진 본지는 한국신문윤리위원회의 서약사로서 신문윤리강령을 '
#                                     '준수합니다.\n'
#                                     '\n'
#                                     'Copyright 1999-2026. 한경닷컴 All rights '
#                                     'reserved.\n'
#                                     '\n'
#                                     '상단 바로가기\n'
#                                     '\n'
#                                     '[내 배지 '
#                                     '보러가기](https://www.hankyung.com/myhankyung)\n'
#                                     '\n'
#                                     '팝업 닫기',
#                                highlights=None,
#                                highlight_scores=None,
#                                summary=None),
#                         Result(url='https://www.spotvnews.co.kr/news/articleView.html?idxno=825357',
#                                id='https://www.spotvnews.co.kr/news/articleView.html?idxno=825357',
#                                title="[오피셜] 손흥민의 치욕, 월드컵 마지막 기록 '남아공전 후반 교체 "
#                                      "출전' 유력...'꿀대진' 홍명보호, 월드컵 탈락 확정 < 월드컵 국외 "
#                                      '< 해외축구 < 기사본문 - SPOTV NEWS',
#                                score=None,
#                                published_date='2026-06-28T01:44:00.000Z',
#                                author='SPOTV NEWS',
#                                image='https://cdn.spotvnews.co.kr/news/thumbnail/202606/825357_1354144_4336_v150.jpg',
#                                favicon=None,
#                                subpages=None,
#                                extras=None,
#                                text="[오피셜] 손흥민의 치욕, 월드컵 마지막 기록 '남아공전 후반 교체 출전' "
#                                     "유력...'꿀대진' 홍명보호, 월드컵 탈락 확정 < 월드컵 국외 < "
#                                     '해외축구 < 기사본문 - SPOTV NEWS\n'
#                                     '\n'
#                                     '## 본문영역\n'
#                                     '\n'
#                                     '[스포티비뉴스=장하준 기자] 홍명보 감독이 이끄는 한국 축구대표팀의 '
#                                     '2026 국제축구연맹(FIFA) 북중미 월드컵 여정이 조별리그에서 막을 '
#                                     '내렸다.\n'
#                                     '\n'
#                                     '한국은 28일(한국시간) 열린 K조 경기 결과에 따라 조 3위 팀 순위 '
#                                     '경쟁에서 32강 진출 마지노선인 8위 밖으로 밀려났다. 이어 남아 있던 '
#                                     'J조 경기 결과와 상관없이 토너먼트 진출 가능성이 완전히 사라지며 조별리그 '
#                                     '탈락이 확정됐다.\n'
#                                     '\n'
#                                     '이로써 한국은 8년 만에 월드컵 조별리그 문턱을 넘지 못했다. 2018년 '
#                                     '러시아 월드컵 이후 다시 한 번 조별리그에서 대회를 마감하게 됐다.\n'
#                                     '\n'
#                                     '홍명보호는 이번 대회에서 2010년 남아프리카공화국 월드컵과 2022년 '
#                                     '카타르 월드컵에 이어 역대 세 번째 원정 16강 진출, 그리고 사상 첫 '
#                                     '원정 16강 2회 연속 달성에 도전했다. 그러나 기대했던 성과를 이루지 '
#                                     '못하며 아쉬움을 남겼다.\n'
#                                     '\n'
#                                     '한국 축구의 월드컵 조별리그 탈락은 이번이 통산 아홉 번째다. 앞서 '
#                                     '1954년 스위스, 1986년 멕시코, 1990년 이탈리아, 1994년 '
#                                     '미국, 1998년 프랑스, 2006년 독일, 2014년 브라질, 2018년 '
#                                     '러시아 월드컵에서도 조별리그를 통과하지 못한 바 있다.\n'
#                                     '\n'
#                                     '최종 순위는 J조 경기 결과에 따라 결정된다. 한국은 이번 대회를 33위 '
#                                     '또는 34위로 마칠 예정이다.\n'
#                                     '\n'
#                                     '이번 월드컵은 사상 처음으로 참가국이 48개국으로 확대돼 진행됐다. '
#                                     '그럼에도 한국은 토너먼트 진출에 실패했다. 기존 32개국 체제와 비교하면 '
#                                     '본선 진출에 버금가는 성과조차 거두지 못한 셈으로, 한국 축구에는 뼈아픈 '
#                                     '결과로 남게 됐다.\n'
#                                     '\n'
#                                     '동시에 한국 대표팀 역사상 최고의 선수로 꼽히는 손흥민은 사실상 본인의 '
#                                     '마지막 월드컵을 이렇게 마무리하게 됐다. 남아공전 후반 교체 출전은 그의 '
#                                     '마지막 월드컵 경력이 될 가능성이 커졌다.\n'
#                                     '\n'
#                                     '기자명 장하준 기자 waterjun@spotv.net\n'
#                                     '\n'
#                                     '#### 관련기사\n'
#                                     '\n'
#                                     "- '18살 차이' 장기하♥윤가이, 2년 넘게 사랑 키웠다...소속사도 "
# ...
#                                     '1승2패로 승점 3점, 골득실차 -1, 그리고 2골을 기록했다.\n'
#                                     '\n'
#                                     '현재 B조 3위가 확정된 보스니아 헤르체고비나는 1승1무1패로 한국보다 '
#                                     '앞섰으며, C조의 스코틀랜드는 1승2패로 한국과 승점은 같지만 골득실차 '
#                                     '-3으로 한국에 밀리는 상황이다.\n'
#                                     '\n'
#                                     '만약 한국이 32강에 진출하면 오는 30일 미국 휴스턴에서 E조 1위 또는 '
#                                     '다음 달 2일 시애틀에서 G조 1위와 대결한다. E조 1위는 독일로 '
#                                     '확정됐다.\n'
#                                     '\n'
#                                     '## 관련 기사 더 보기\n'
#                                     '\n'
#                                     '### 2026 월드컵 실시간 경기 결과 및 순위\n'
#                                     '\n'
#                                     '2026년 6월 9일\n'
#                                     '\n'
#                                     "### 월드컵 경기장 청소하는 자국 팬들에게 '집에서도 그렇게 하라'는 "
#                                     '일본 여성들\n'
#                                     '\n'
#                                     '2026년 6월 19일\n'
#                                     '\n'
#                                     "### '사실 좀 무서웠어요', 월드컵서 인종차별 당한 유튜버가 밝힌 당시 "
#                                     '상황\n'
#                                     '\n'
#                                     '2026년 6월 22일\n'
#                                     '\n'
#                                     "### 2026 북중미 월드컵: 경제 논리가 만든 역대 가장 '극단적인' "
#                                     '대회\n'
#                                     '\n'
#                                     '2026년 6월 13일\n'
#                                     '\n'
#                                     '### 2026 월드컵: 출생국 아닌 다른 나라 대표팀 택하는 선수가 '
#                                     '많아지는 이유\n'
#                                     '\n'
#                                     '2026년 6월 24일\n'
#                                     '\n'
#                                     '### FIFA, 월드컵 순위 산정 방식 변경...모든 게 바뀐다\n'
#                                     '\n'
#                                     '2026년 6월 20일\n'
#                                     '\n'
#                                     '## 주요 뉴스\n'
#                                     '\n'
#                                     '### 2026 월드컵 실시간 경기 결과 및 순위\n'
#                                     '\n'
#                                     '2026년 6월 9일\n'
#                                     '\n'
#                                     "### 한국, 남아공에 1-0 패...32강 진출 '안갯속'\n"
#                                     '\n'
#                                     '5분 전\n'
#                                     '\n'
#                                     "### '창문이 흔들거립니다' … 베네수엘라 연속 강진 … 주민들이 전하는 "
#                                     '공포\n'
#                                     '\n'
#                                     '12분 전\n'
#                                     '\n'
#                                     '## 이 시간 이슈\n'
#                                     '\n'
#                                     '### 봉쇄 일주일, 시민들은 왜 현장을 지키고 있나\n'
#                                     '\n'
#                                     '2026년 6월 12일\n'
#                                     '\n'
#                                     "### '투표용지 부족' 사태 쟁점과 향후 절차는?\n"
#                                     '\n'
#                                     '2026년 6월 4일\n'
#                                     '\n'
#                                     "### '투표용지 부족 사태'에 분노한 시민들\n"
#                                     '\n'
#                                     '2026년 6월 4일\n'
#                                     '\n'
#                                     '### 6·3 지방선거: 서울과 부산 북구 등 주요 격전지 개표 결과는?\n'
#                                     '\n'
#                                     '2026년 6월 4일\n'
#                                     '\n'
#                                     "### 북한 김정은, 왜 엄마를 공개하지 않을까…'제주에 뿌리 둔 재일교포 "
#                                     "2세'\n"
#                                     '\n'
#                                     '2026년 6월 1일\n'
#                                     '\n'
#                                     "### '공약 보고 뽑았는데...지키겠죠?' 지방선거 사전투표소를 찾은 "
#                                     '사람들\n'
#                                     '\n'
#                                     '2026년 5월 29일\n'
#                                     '\n'
#                                     "### '칠십 평생 이런 선거 처음 봅니데이'...논란의 부산 북구갑을 "
#                                     '가다\n'
#                                     '\n'
#                                     '2026년 5월 27일\n'
#                                     '\n'
#                                     "### '적대국' 한국에서 '백년의 적' 일본 물리치고 우승컵 들어올린 "
#                                     '북한 여자 축구\n'
#                                     '\n'
#                                     '2026년 5월 24일\n'
#                                     '\n'
#                                     "### '유치원 패러디 영상, 웃으며 볼 수 없었어요' 전현직 교사들이 "
#                                     '말하는 유치원의 현실\n'
#                                     '\n'
#                                     '2026년 5월 23일\n'
#                                     '\n'
#                                     '## 많이 본 뉴스\n'
#                                     '\n'
#                                     '1\n'
#                                     '\n'
#                                     '한국, 멕시코에 패배…32강 진출 경우의 수는?\n'
#                                     '\n'
#                                     '2\n'
#                                     '\n'
#                                     "한국, 남아공에 1-0 패...32강 진출 '안갯속'\n"
#                                     '\n'
#                                     '3\n'
#                                     '\n'
#                                     'FIFA, 월드컵 순위 산정 방식 변경...모든 게 바뀐다\n'
#                                     '\n'
#                                     '4\n'
#                                     '\n'
#                                     '2026 월드컵: 출생국 아닌 다른 나라 대표팀 택하는 선수가 많아지는 '
#                                     '이유\n'
#                                     '\n'
#                                     '5\n'
#                                     '\n'
#                                     '2026 월드컵 실시간 경기 결과 및 순위\n'
#                                     '\n'
#                                     '6\n'
#                                     '\n'
#                                     '축구 입문자를 위한 월드컵 가이드\n'
#                                     '\n'
#                                     '7\n'
#                                     '\n'
#                                     '2026 북중미 월드컵 전경기 일정 벽걸이 차트\n'
#                                     '\n'
#                                     '8\n'
#                                     '\n'
#                                     "'사실 좀 무서웠어요', 월드컵서 인종차별 당한 유튜버가 밝힌 당시 상황\n"
#                                     '\n'
#                                     '9\n'
#                                     '\n'
#                                     "미 양원, '전쟁 권한 결의안' 통과 … 트럼프의 이란 전쟁 비판\n"
#                                     '\n'
#                                     '10\n'
#                                     '\n'
#                                     '폭염 앓는 서유럽 … 프랑스·영국·스페인서 사상 최고 기온 경신',
#                                highlights=None,
#                                highlight_scores=None,
#                                summary=None),
#                         Result(url='https://www.mt.co.kr/sports/2026/06/30/202606291437776617O',
#                                id='https://www.mt.co.kr/sports/2026/06/30/202606291437776617O',
#                                title='"월드컵 역대급 꿀조에서 탈락" 美 매체 팩폭...\'D-\' 홍명보호 '
#                                      '성적표 나왔다 "에이스 손흥민 벤치→최약체 남아공에 패배" - 머니투데이',
#                                score=None,
#                                published_date='2026-06-29T20:25:00.000Z',
#                                author='OSEN 제공',
#                                image='https://menu.mt.co.kr/cdn-cgi/image/w=1200,h=912,fit=cover,bg=whilte,f=auto,quality=high,sharpen=2,g=face/mobile/osen/data/2026/06/29/202606291437776617_1.jpg',
#                                favicon='https://menu.mt.co.kr/common/favicons/favicon-32.ico',
#                                subpages=None,
#                                extras=None,
#                                text='"월드컵 역대급 꿀조에서 탈락" 美 매체 팩폭...\'D-\' 홍명보호 '
#                                     '성적표 나왔다 "에이스 손흥민 벤치→최약체 남아공에 패배" - 머니투데이\n'
#                                     '\n'
#                                     '로그인|회원가입\n'
#                                     '\n'
#                                     '닫기\n'
#                                     '\n'
#                                     '## "월드컵 역대급 꿀조에서 탈락" 美 매체 팩폭...\'D-\' '
#                                     '홍명보호 성적표 나왔다 "에이스 손흥민 벤치→최약체 남아공에 패배"\n'
#                                     '\n'
#                                     '2026 FIFA 북중미 월드컵 조별리그에서 탈락한 홍명보호가 미국 '
#                                     'ESPN으로부터 낙제점인 D- 성적표를 받았다. 한국은 남아프리카공화국과의 '
#                                     '조별리그 3차전에서 0-1로 패하며 32강 진출이 좌절되었고, 이에 홍명보 '
#                                     '감독은 자진 사퇴를 선언했다. ESPN은 한국이 에이스 손흥민을 선발 '
#                                     '제외하고 최약체 남아공에 경기 내용까지 밀리며 무기력하게 패배했다고 '
#                                     '지적했다.\n'
#                                     '\n'
#                                     '[OSEN=고성환 기자] 한국 축구 역사에 남을 대참사를 쓴 결과다. '
#                                     '2026 국제축구연맹(FIFA) 북중미 월드컵 조별리그에서 탈락한 '
#                                     "홍명보호가 'D-'라는 성적표를 받았다.\n"
#                                     '\n'
#                                     '미국 \'ESPN\'은 28일(이하 한국시간) "지금부터 대회가 끝날 '
#                                     '때까지 탈락한 47개 팀을 평가할 것이다. 대회 전 기대치, 대회에서 '
#                                     '보여준 경기력, 그리고 그 밖에 고려할 만한 요소들을 종합해 가장 최근 '
#                                     '탈락한 팀부터 순서대로 채점한다"라며 월드컵 조별리그에서 탈락한 팀들의 '
#                                     '성적을 매겼다.\n'
#                                     '\n'
#                                     '홍명보 감독이 이끄는 한국 축구대표팀의 최종 평점은 D-로 낙제점이었다. '
#                                     '이유는 분명하다. 조별리그 3차전에서 FIFA 랭킹 60위 '
#                                     '남아프리카공화국을 상대로 0-1로 충격패하며 32강 진출이 좌절됐기 때문. '
#                                     '남아공과 비기기만 해도 조 2위로 32강에 올라갈 수 있었지만, 최악의 '
#                                     '졸전으로 기회를 걷어찼다.\n'
#                                     '\n'
#                                     '그 여파로 홍명보 감독은 자진 사퇴를 선언했다. 그는 한국 축구 역사상 '
#                                     '최초로 두 차례 월드컵에 나서서 모두 조별리그 탈락한 지도자로 남게 '
#                                     '됐다.\n'
#                                     '\n'
#                                     'ESPN은 "최종전을 앞두고 한국은 사실상 32강에서 홈경기나 다름없는 '
#                                     '환경을 얻을 상황이었다. 경기 장소는 로스앤젤레스였고, 상대도 프랑스나 '
#                                     '아르헨티나가 아닌 충분히 해볼 만한 캐나다가 될 가능성이 컸다. 게다가 '
#                                     '캐나다 역시 홈 이점을 잃은 상태였다. 필요했던 것은 앞선 두 경기에서 '
#                                     '이번 대회 최약체로 보였던 남아공을 이기는 것뿐이었다"라고 짚었다.\n'
#                                     '\n'
#                                     '모두가 한국과 캐나다의 32강 맞대결을 점쳤지만, 남아공이 무기력한 한국을 '
#                                     '무너뜨리면서 캐나다를 만나러 갔다. 매체는 "하지만 감독은 에이스 손흥민을 '
#                                     '선발에서 제외했고, 한국은 0-1 패배를 당하는 과정에서 경기 내용까지 '
#                                     '남아공에 밀렸다. 그렇게 한국의 월드컵은 끝났다"고 전했다.\n'
#                                     '\n'
#                                     '사실 한국의 기대치를 생각하면 최하점인 F를 받아도 이상하지 않았다. '
#                                     '모두가 손흥민과 이재성, 이강인, 김민재 등을 보유한 한국의 무난한 32강 '
#                                     '진출을 점쳤다. 멕시코, 체코, 남아공과 함께 A조에 배정되면서 조 편성도 '
#                                     '역대 최고 수준이라는 평가를 받았다.\n'
#                                     '\n'
#                                     '그럼에도 D-로 참은 ESPN. 매체는 "F가 아닌 D-를 준 이유는 '
#                                     '체코전 승리에서는 꽤 좋은 경기력을 보여줬기 때문이다. 또 멕시코전에서는 '
#                                     "이번 대회 최고의 '더블 세이브'만 아니었다면 무승부를 만들 수도 있었다. "
#                                     '그 슈팅이 들어갔다면 지금 이 글을 쓰고 있지도 않았을 것이다. 하지만 '
#                                     '들어가지 않았다"고 설명했다.\n'
#                                     '\n'
#                                     '## 독자들의 PICK!\n'
#                                     '\n'
#                                     '### "24살 연하 직원과 바람난 남편...언니집까지 경매로 날렸어요"\n'
#                                     '\n'
#                                     '### "며느리가 죽는 게 낫지" 17년 버텼는데 무너진 아내…남편은 '
#                                     '방관\n'
#                                     '\n'
#                                     '### "아빠랑 하는 병원놀이" 두 딸에 몹쓸짓...언니는 세상 떠났다\n'
#                                     '\n'
#                                     '### \'15살 임신\' 싱글맘 "아이 낳자 돌변한 남친...양육비도 안 '
#                                     '줘"\n'
#                                     '\n'
#                                     '- '
#                                     'https://www.mt.co.kr/entertainment/2026/06/30/2026063003323668849\n'
#                                     '- '
#                                     'https://www.mt.co.kr/entertainment/2026/06/29/2026062906252099463\n'
#                                     '- '
#                                     'https://www.mt.co.kr/entertainment/2026/06/29/2026062915583457758\n'
#                                     '- '
#                                     'https://www.mt.co.kr/entertainment/2026/06/30/2026063003103273909\n'
#                                     '\n'
#                                     '한국에도 패하면서 탈락한 A조 꼴찌 체코도 나란히 D-를 기록했다. 체코는 '
#                                     '첫 경기에서 홍명보호를 만나 1-2로 역전패했고, 남아공전에서도 선제골을 '
#                                     '지키지 못하며 1-1로 비겼다. 그리고 마지막 경기에서 멕시코에 0-3으로 '
#                                     '대패하며 씁쓸히 짐을 싸야 했다.\n'
#                                     '\n'
#                                     'ESPN은 "이 팀에는 세트피스가 있었다. 그리고 그 외에는 거의 아무것도 '
#                                     '없었다"라며 "체코의 모든 득점은 세트피스에서 나왔다. 34개의 슈팅 '
#                                     '가운데 18개가 세트피스에서 나왔고, 총 기대득점(xG) 2.37 가운데 '
#                                     '1.38도 세트피스에서 만들어졌다"고 짚었다.\n'
#                                     '\n'
#                                     '이어 매체는 "최상위 수준의 선수가 없는 첫 출전 국가라면, 조금이라도 '
#                                     '우위를 만들기 위해 이런 방식에 의존하는 것도 이해할 수 있다. 하지만 '
#                                     '체코의 선발 명단 대부분은 유럽 상위 리그에서 뛰는 선수들"이라고 '
#                                     '지적했다.\n'
#                                     '\n'
#                                     '한국 축구에도 뼈아픈 일침까지 덧붙였다. ESPN은 "체코 정도의 '
#                                     '전력이라면 최소한 32강에는 올라가고, 16강 진출을 노릴 만한 이변을 '
#                                     '만들 수 있는 위치까지는 가야 한다. 그런데 체코는 월드컵 역사상 가장 '
#                                     '약한 수준의 조 가운데 하나에서 최하위로 대회를 마쳤다"라고 강조했다.\n'
#                                     '\n'
#                                     '/ [email protected]\n'
#                                     '\n'
#                                     '<저작권자 © ‘돈이 보이는 리얼타임 뉴스’ 머니투데이. 무단전재 및 '
#                                     '재배포, AI학습 이용 금지>\n'
#                                     '\n'
#                                     '## 지금 뜨는 검색키워드\n'
#                                     '\n'
#                                     '## 많이 찾는 종목\n'
#                                     '\n'
#                                     '- 코스피\n'
#                                     '- 코스닥\n'
#                                     '\n'
#                                     '공유',
#                                highlights=None,
#                                highlight_scores=None,
#                                summary=None)],
#                autoprompt_string=None,
#                resolved_search_type='',
#                auto_date=None,
#                context=None,
#                statuses=None,
#                cost_dollars=CostDollars(total=0.007,
#                                         search={'neural': 0.007},
#                                         contents=None))

# %%
# Tool 정보 확인 - LLM이 TOOL을 사용할지를 결정할 때 판단 근거, 호출할 때 전달할 값을 결정하는 근거
print("도구이름:", tavily_search.name, exa_search.name)
print("도구설명:", tavily_search.description)
# Out:
# 도구이름: tavily_search exa_search_results_json
# 도구설명: A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. It not only retrieves URLs and snippets, but offers advanced search depths, domain management, time range filters, and image search, this tool delivers real-time, accurate, and citation-backed results.Input should be a search query.

# %%
# 도구 Schema - 도구 호출할 대 값을 전달할 파라민터 정보
tavily_search.args
# Out:
# {'query': {'description': 'Search query to look up',
#   'title': 'Query',
#   'type': 'string'},
#  'include_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to restrict search results to.\n\n        Use this parameter when:\n        1. The user explicitly requests information from specific websites (e.g., "Find climate data from nasa.gov")\n        2. The user mentions an organization or company without specifying the domain (e.g., "Find information about iPhones from Apple")\n\n        In both cases, you should determine the appropriate domains (e.g., ["nasa.gov"] or ["apple.com"]) and set this parameter.\n\n        Results will ONLY come from the specified domains - no other sources will be included.\n        Default is None (no domain restriction).\n        ',
#   'title': 'Include Domains'},
#  'exclude_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to exclude from search results.\n\n        Use this parameter when:\n        1. The user explicitly requests to avoid certain websites (e.g., "Find information about climate change but not from twitter.com")\n        2. The user mentions not wanting results from specific organizations without naming the domain (e.g., "Find phone reviews but nothing from Apple")\n\n        In both cases, you should determine the appropriate domains to exclude (e.g., ["twitter.com"] or ["apple.com"]) and set this parameter.\n\n        Results will filter out all content from the specified domains.\n        Default is None (no domain exclusion).\n        ',
#   'title': 'Exclude Domains'},
#  'search_depth': {'anyOf': [{'enum': ['basic',
#      'advanced',
#      'fast',
#      'ultra-fast'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'basic',
#   'description': 'Controls search thoroughness and result comprehensiveness.\n    \n        Use "basic" for simple queries requiring quick, straightforward answers.\n        \n        Use "advanced" for complex queries, specialized topics, \n        rare information, or when in-depth analysis is needed.\n        \n        Use "fast" for optimized low latency with high relevance.\n        \n        Use "ultra-fast" when latency is prioritized above all else.\n        ',
#   'title': 'Search Depth'},
#  'include_images': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#   'default': False,
#   'description': 'Determines if the search returns relevant images along with text results.\n   \n        Set to True when the user explicitly requests visuals or when images would \n        significantly enhance understanding (e.g., "Show me what black holes look like," \n        "Find pictures of Renaissance art").\n        \n        Leave as False (default) for most informational queries where text is sufficient.\n        ',
#   'title': 'Include Images'},
#  'time_range': {'anyOf': [{'enum': ['day', 'week', 'month', 'year'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': None,
#   'description': 'Limits results to content published within a specific timeframe.\n        \n        ONLY set this when the user explicitly mentions a time period \n        (e.g., "latest AI news," "articles from last week").\n        \n        For less popular or niche topics, use broader time ranges \n        ("month" or "year") to ensure sufficient relevant results.\n   \n        Options: "day" (24h), "week" (7d), "month" (30d), "year" (365d).\n        \n        Default is None.\n        ',
#   'title': 'Time Range'},
#  'topic': {'anyOf': [{'enum': ['general', 'news', 'finance'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'general',
#   'description': 'Specifies search category for optimized results.\n   \n        Use "general" (default) for most queries, INCLUDING those with terms like \n        "latest," "newest," or "recent" when referring to general information.\n\n        Use "finance" for markets, investments, economic data, or financial news.\n\n        Use "news" ONLY for politics, sports, or major current events covered by \n        mainstream media - NOT simply because a query asks for "new" information.\n        ',
#   'title': 'Topic'},
#  'start_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or after this date.\n        \n        Use this parameter when you need to:\n        - Find recent developments or updates on a topic\n        - Exclude outdated information from search results\n        - Focus on content within a specific timeframe\n        - Combine with end_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-01-15" for January 15, 2024).\n        \n        Examples:\n        - "2024-01-01" - Results from January 1, 2024 onwards\n        - "2023-12-25" - Results from December 25, 2023 onwards\n        \n        When combined with end_date, creates a precise date range filter.\n        \n        Default is None (no start date restriction).\n        ',
#   'title': 'Start Date'},
#  'end_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or before this date.\n        \n        Use this parameter when you need to:\n        - Exclude content published after a certain date\n        - Study historical information or past events\n        - Research how topics were covered during specific time periods\n        - Combine with start_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-03-31" for March 31, 2024).\n        \n        Examples:\n        - "2024-03-31" - Results up to and including March 31, 2024\n        - "2023-12-31" - Results up to and including December 31, 2023\n        \n        When combined with start_date, creates a precise date range filter.\n        For example: start_date="2024-01-01", end_date="2024-03-31" \n        returns results from Q1 2024 only.\n        \n        Default is None (no end date restriction).\n        ',
#   'title': 'End Date'}}

# %% [markdown]
# ## LLM ToolCalling 흐름
#
# ### 1. Tool 생성 및 LLM Model에 tool binding
# - `LLM-Model.bind_tools(tools=[tool_1, tool_2, ...])`

# %%
from langchain_openai import ChatOpenAI
from langchain_exa import ExaSearchResults
exa_search =ExaSearchResults(max_result=5)
model = ChatOpenAI(model="gpt-5.4-mini")
tool_model = model.bind_tools(tools=[exa_search])

# model: LLM, tool_model: LLM + tool

# %%
result = tool_model.invoke("안녕하세요")

# %%
print(result.content) # LLM 응답 text
print(result.tool_calls) # 호출할 tool에 대한 정보(어떤 tool을 어떻게 호출할지)
# 응답에는 위 둘중 하나만 값이 있다.
# Out:
# 안녕하세요! 무엇을 도와드릴까요?
# []

# %%
result2 = tool_model.invoke("2026년 7월 7일 서울의 날씨는 어떤가요")

# %%
print(result2.content)

# %%
print(result2.tool_calls)
# Out:
# [{'name': 'exa_search_results_json', 'args': {'query': '2026년 7월 7일 서울 날씨 예보 weather Seoul July 7 2026', 'num_results': 5, 'type': 'fast', 'livecrawl': 'fallback', 'use_autoprompt': True, 'text_contents_options': {'max_characters': 3000}, 'summary': True}, 'id': 'call_x1LVkZgzu8nlC54NswTbuLRQ', 'type': 'tool_call'}]

# %%
result3 = tool_model.invoke("2026년 7월 7일 서울, 런던, 뉴욕의 날씨를 알려줘. 그리고 오늘 월드컵 경기 결과들도 알려줘")

# %%
print(result3.content)

# %%
print(result3.tool_calls)
# Out:
# [{'name': 'exa_search_results_json', 'args': {'query': '2026-07-07 Seoul weather forecast July 7 2026', 'num_results': 5, 'type': 'fast', 'livecrawl': 'fallback', 'summary': True}, 'id': 'call_xudGm1X2ufYdn4vG1qYYfaFE', 'type': 'tool_call'}, {'name': 'exa_search_results_json', 'args': {'query': '2026-07-07 London weather forecast July 7 2026', 'num_results': 5, 'type': 'fast', 'livecrawl': 'fallback', 'summary': True}, 'id': 'call_EcQXngEbQl7M01P4rGTEB2Tu', 'type': 'tool_call'}, {'name': 'exa_search_results_json', 'args': {'query': '2026-07-07 New York weather forecast July 7 2026', 'num_results': 5, 'type': 'fast', 'livecrawl': 'fallback', 'summary': True}, 'id': 'call_3qngyXAOFBFdLyqFrqMJ30KB', 'type': 'tool_call'}, {'name': 'exa_search_results_json', 'args': {'query': 'today World Cup results July 7 2026', 'num_results': 10, 'type': 'fast', 'livecrawl': 'fallback', 'summary': True}, 'id': 'call_t9IKhBD8a2ZEohLMUsDqiQ4E', 'type': 'tool_call'}]

# %%
print(len(result3.tool_calls))
# Out:
# 4

# %%
for r in result3.tool_calls:
    print(r)
    print("=====")
# Out:
# {'name': 'exa_search_results_json', 'args': {'query': '2026-07-07 Seoul weather forecast July 7 2026', 'num_results': 5, 'type': 'fast', 'livecrawl': 'fallback', 'summary': True}, 'id': 'call_xudGm1X2ufYdn4vG1qYYfaFE', 'type': 'tool_call'}
# =====
# {'name': 'exa_search_results_json', 'args': {'query': '2026-07-07 London weather forecast July 7 2026', 'num_results': 5, 'type': 'fast', 'livecrawl': 'fallback', 'summary': True}, 'id': 'call_EcQXngEbQl7M01P4rGTEB2Tu', 'type': 'tool_call'}
# =====
# {'name': 'exa_search_results_json', 'args': {'query': '2026-07-07 New York weather forecast July 7 2026', 'num_results': 5, 'type': 'fast', 'livecrawl': 'fallback', 'summary': True}, 'id': 'call_3qngyXAOFBFdLyqFrqMJ30KB', 'type': 'tool_call'}
# =====
# {'name': 'exa_search_results_json', 'args': {'query': 'today World Cup results July 7 2026', 'num_results': 10, 'type': 'fast', 'livecrawl': 'fallback', 'summary': True}, 'id': 'call_t9IKhBD8a2ZEohLMUsDqiQ4E', 'type': 'tool_call'}
# =====

# %% [markdown]
# ### 2. Tool 호출
# - LLM 모델이 tool 요청을 결정한 경우 **어떤 tool을 어떻게 호출할 지** AIMessage의 `tool_calls` 속성에 넣어 반환한다.
# - `tool_calls` 의 호출 정보를 넣어 `tool.invoke()` 호출한다.
#    - `tool.invoke(result.tool_calls[0])`
#    - **반환타입**: `ToolMessage`
#      - Tool의 처리결과를 담는 Message Type 이다.

# %%
# exa_search tool을 too_calls[k]를 전달해서 호출
result3.tool_calls
# Out:
# [{'name': 'exa_search_results_json',
#   'args': {'query': '2026-07-07 Seoul weather forecast July 7 2026',
#    'num_results': 5,
#    'type': 'fast',
#    'livecrawl': 'fallback',
#    'summary': True},
#   'id': 'call_xudGm1X2ufYdn4vG1qYYfaFE',
#   'type': 'tool_call'},
#  {'name': 'exa_search_results_json',
#   'args': {'query': '2026-07-07 London weather forecast July 7 2026',
#    'num_results': 5,
#    'type': 'fast',
#    'livecrawl': 'fallback',
#    'summary': True},
#   'id': 'call_EcQXngEbQl7M01P4rGTEB2Tu',
#   'type': 'tool_call'},
#  {'name': 'exa_search_results_json',
#   'args': {'query': '2026-07-07 New York weather forecast July 7 2026',
#    'num_results': 5,
#    'type': 'fast',
#    'livecrawl': 'fallback',
#    'summary': True},
#   'id': 'call_3qngyXAOFBFdLyqFrqMJ30KB',
#   'type': 'tool_call'},
#  {'name': 'exa_search_results_json',
#   'args': {'query': 'today World Cup results July 7 2026',
#    'num_results': 10,
#    'type': 'fast',
#    'livecrawl': 'fallback',
#    'summary': True},
#   'id': 'call_t9IKhBD8a2ZEohLMUsDqiQ4E',
#   'type': 'tool_call'}]

# %%
search_result1 = exa_search.invoke(result3.tool_calls[0])
type(search_result1)
# Out:
# langchain_core.messages.tool.ToolMessage

# %%
print(search_result1.content)
# Out:
# Title: Tuesday's weather forecast | Yonhap News Agency
# URL: https://en.yna.co.kr/view/AEN20260707002500315
# ID: https://en.yna.co.kr/view/AEN20260707002500315
# Score: None
# Published Date: 2026-07-07T00:01:21.000Z
# Author: English News Desk
# Image: https://r.yna.co.kr/global/home/v01/img/yonhapnews_logo_1200x800_en02.jpg
# Favicon: https://r.yna.co.kr/global/favicon.ico
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Here’s the Seoul weather forecast for July 7, 2026:
#
# - Location: Seoul (12 major cities forecast)
# - Temperature: High 30°C / Low 24°C
# - Conditions: Rain likely
# - Rain chance: 60%
#
# Note: Other nearby cities show similar rain chances (60%) except Jeju and Gwangju have lower rain chances (Jeju 20%, Gwangju 20%), with Jeju expected sunny (20% rain).
#
#
# Title: Weather in Seoul,, for July 7 — Temperature, precipitation, wind
# URL: https://meteum.ai/weather/en/seoul/date/july/7
# ID: https://meteum.ai/weather/en/seoul/date/july/7
# Score: None
# Published Date: None
# Author: None
# Image: https://weather.yastatic.net/s3/weather-frontend/front2/_next/static/media/meteum_black.e74474f0.svg
# Favicon: https://meteum.ai/weather/favicon.ico
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Forecast for Seoul on July 7, 2026:
#
# - Conditions: Hot, cloudy with rain (morning showers, light rain in the afternoon, overcast in the evening).
# - Temperatures: High around 29°C; morning 25°C, night 27°C.
# - Feels like: 31°C in the morning, up to 35°C in the afternoon/evening.
# - Wind: SE 2.4 m/s in the morning; W 3 m/s in the afternoon; NE 1.6 m/s in the evening; NE 4 m/s at night (gusts up to ~14–15 m/s).
# - Humidity: High (roughly 75–89%), wetter during the morning.
# - Pressure: ~747–749 mmHg.
#
# Practical takeaway: Expect hot and humid conditions with intermittent rain; carry an umbrella and stay hydrated.
#
#
# Title: Seoul 7 July Weather. Forecast for Seoul - South Korea
# URL: https://globalmeteo.com/weather/seoul/jul-07/
# ID: https://globalmeteo.com/weather/seoul/jul-07/
# Score: None
# Published Date: None
# Author: None
# Image: https://globalmeteo.com/images/precip-svg/23.svg
# Favicon: https://globalmeteo.com/images/icon/favicon-32x32.png
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Summary:
# - The page provides Seoul weather forecast for July 7, 2026, based on GFS data and local time in Seoul (GMT+9).
# - Expected conditions for July 7, 2026 show hot daytime temperatures around 89–90°F (approximately 32–32°C) with Likely heavy rain and thunderstorms in the forecast:
#   - Today (Tue, July 7, 2026): Heavy rain, high near 89°F (flow 76°F in the excerpt appears to be a formatting artifact; main high ~89°F/32°C).
#   - Tomorrow (Wed, July 8): Thunderstorms; high around 82°F (≈28°C).
#   - Thu (Jul 9): Thunderstorms; high around 78°F (≈26°C).
#   - Fri (Jul 10): Thunderstorms; high around 84°F (≈29°C).
#   - Sat (Jul 11): Cloudy; high around 90°F (≈32°C).
# - Hourly snapshot for July 7 shows temperatures ranging from mid-70s°F overnight to up to 89°F in the afternoon, with light to moderate winds (roughly 3–7 mph) and standard atmospheric pressure around 29.6 inHg.
# - The page notes the forecast is prepared from GFS data and allows climate-norm comparison for July 7 in Seoul.
#
# If you need a tighter, real-time hour-by-hour forecast for July 7, 2026, I can extract the exact hourly temperatures and precipitation chances from the table.
#
#
# Title: Capital Area Braces for Heavy Monsoon Rains, Up to 150 mm
# URL: https://www.chosun.com/english/national-en/2026/07/07/IVBIYQPLOBET3GHCEUQKVHELBU/
# ID: https://www.chosun.com/english/national-en/2026/07/07/IVBIYQPLOBET3GHCEUQKVHELBU/
# Score: None
# Published Date: 2026-07-07T01:28:40.000Z
# Author: None
# Image: None
# Favicon: None
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Summary: The Korea Meteorological Administration forecast on July 7, 2026, calls for heavy monsoon rains starting July 7–9, with the capital area (Seoul) expected to see the heaviest rainfall on July 8–9. Expected rainfall: central regions 20–60 mm on July 7; 50–150 mm in the capital area and Chungcheong from July 8–9 (higher totals near 150 mm). Very heavy rain (over 30 mm/hr) possible in central regions on July 8 and in southern regions on July 9, with some areas potentially reaching ~50 mm/hr. Temperatures remain hot and humid, with daytime highs around 34–35°C and higher feels-like temperatures due to humidity.
#
#
# Title: KMA warns of thunderstorms and heavy rain across central Korea on July 8 night  - DongA Science
# URL: https://www.dongascience.com/en/news/78809
# ID: https://www.dongascience.com/en/news/78809
# Score: None
# Published Date: 2026-07-07T11:44:10.000Z
# Author: Byeongku Lee
# Image: https://image.dongascience.com/Photo/2026/07/17833917287066.jpg
# Favicon: None
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Summary: The KMA warns of unsettled weather in central South Korea around July 7–9, 2026. Key points:
#
# - July 7 (afternoon): Showers with gusty winds, thunder, and lightning mainly in the central region; expected rainfall 5–60 mm in Seoul metro and Gangwon inland/mountains; 5–40 mm in broader central areas, northern Jeonbuk, Gyeongbuk, and inland Gyeongnam.
# - July 8 (overnight into morning): A stationary front moves north, bringing heavy rain to central and Jeolla regions; rainfall intensifies.
# - July 8 night to July 9 morning: Heavy rain expected in Chungnam and Jeonbuk, with totals potentially over 200 mm; rainfall intensity up to 50 mm/hour in Seoul metro area and central regions.
# - Additional notes: Thunderstorms, heat waves, and tropical nights expected; indirect effects from Typhoon Bavi are possible but limited.
# - Advisories: Prepare in advance for possible damage from heavy rain, including potential retaining wall collapses and Wednesday-night vulnerabilities. Carry an umbrella during rain events.
#
# CostDollars: total=0.012
#   - search: {'neural': 0.007}

# %% [markdown]
# ##### tool_call 이 여러개일 경우
# - 질의에 대해 tool을 여러번 호출 해야 하는 경우 tool_calling 정보를 여러개 반환할 수 있다.
#     - 예) 검색할 키워드가 여러개인 경우.
# - `tool.batch([tool_call1, tool_call2, ..])`

# %%
search_result = exa_search.batch(result3.tool_calls)

# %%
print(len(search_result))
search_result
# Out:
# 4
# [ToolMessage(content="Title: Tuesday's weather forecast | Yonhap News Agency\nURL: https://en.yna.co.kr/view/AEN20260707002500315\nID: https://en.yna.co.kr/view/AEN20260707002500315\nScore: None\nPublished Date: 2026-07-07T00:01:21.000Z\nAuthor: English News Desk\nImage: https://r.yna.co.kr/global/home/v01/img/yonhapnews_logo_1200x800_en02.jpg\nFavicon: https://r.yna.co.kr/global/favicon.ico\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Seoul weather forecast for July 7, 2026:\n- Temperature: high around 30°C, low around 24°C\n- Conditions: Rain likely in Seoul (60% chance)\n- Other cities show similar rain risk: Incheon, Suwon, Cheongju, Daejeon, Chuncheon, Gangneung, Daegu: ~60% rain; Jeju and Busan: mostly sunny/cloudy with lower rain chances (Jeju 20%, Busan 20%)\n- Notable: Jeju expected sunny (20% rain); overall, central and eastern regions have higher probability of showers, with Taegu highest rain chance among major cities.\n\n\nTitle: Weather in Seoul,, for July 7 — Temperature, precipitation, wind\nURL: https://meteum.ai/weather/en/seoul/date/july/7\nID: https://meteum.ai/weather/en/seoul/date/july/7\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://weather.yastatic.net/s3/weather-frontend/front2/_next/static/media/meteum_black.e74474f0.svg\nFavicon: https://meteum.ai/weather/favicon.ico\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Forecast for Seoul on July 7, 2026:\n- Conditions: hot, cloudy, with rain. Intermittent showers likely throughout the day.\n- Temperatures: morning around 25°C; afternoon around 29°C (feels like 35°C); evening around 29°C (feels like 35°C); night ~27°C (feels like 30°C).\n- Wind: generally light to moderate, SE in the morning (up to 14 m/s), W in the afternoon (up to 15 m/s), NE in the evening/night (up to 10–15 m/s).\n- Humidity: high (roughly 75–89%), with rain contributing to muggy conditions.\n- Pressure: around 747–749 mmHg.\n\nNote: Information is drawn from a forecast showing hot, rainy conditions with elevated heat indices.\n\n\nTitle: Seoul 7 July Weather. Forecast for Seoul - South Korea\nURL: https://globalmeteo.com/weather/seoul/jul-07/\nID: https://globalmeteo.com/weather/seoul/jul-07/\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://globalmeteo.com/images/precip-svg/23.svg\nFavicon: https://globalmeteo.com/images/icon/favicon-32x32.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary:\n- Forecast for Seoul, July 7, 2026: Expect hot and humid conditions with thunderstorms and heavy rain possible later in the day.\n- Specifics (local time GMT+9): Early morning around 76–77°F, rising to around 89–90°F by afternoon, with increasing wind up to ~7 mph.\n- Conditions by time: Mostly cloudy daytime with potential heavy rain; thunderstorms forecast for the afternoon into evening.\n- Pressures around 29.62–29.66 inHg; general pattern shows a hot day with thunderstorm risk in Seoul on July 7, 2026.\n- Note: The page bases its forecast on GFS data and provides climate-norm context for July 7 in Seoul.\n\n\nTitle: Capital Area Braces for Heavy Monsoon Rains, Up to 150 mm\nURL: https://www.chosun.com/english/national-en/2026/07/07/IVBIYQPLOBET3GHCEUQKVHELBU/\nID: https://www.chosun.com/english/national-en/2026/07/07/IVBIYQPLOBET3GHCEUQKVHELBU/\nScore: None\nPublished Date: 2026-07-07T01:28:40.000Z\nAuthor: None\nImage: None\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary: The July 7, 2026 forecast for Seoul (capital area) calls for the stationary monsoon front to move north, bringing increasing rainfall through July 8–9. On July 7, central regions including Seoul are expected to receive 20–60 mm of rain, with heavier totals anticipated from the 8th to 9th: about 50–150 mm in the capital area and Chungcheong, 50–100 mm in Gangwon, and variable a ...
#  ToolMessage(content="Title: London (Greater London) weather - Met Office\nURL: https://weather.metoffice.gov.uk/forecast/gcpvj0v07\nID: https://weather.metoffice.gov.uk/forecast/gcpvj0v07\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://weather.metoffice.gov.uk/forecast/static/images/common/icons/social_card.jpg\nFavicon: https://weather.metoffice.gov.uk/favicon.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Forecast summary for London (Greater London) on July 7, 2026:\n\n- Today’s high: 33°C (maximum daytime temperature around 33°C; very warm).\n- Overall: Hot and sunny with minimal rain expected.\n- Temperatures through the day: start around mid-20s°C overnight, rising to around 33°C in the afternoon, cooling back into the low 20s°C by evening.\n- Precipitation: Very low chance of rain (<5%) all day.\n- Wind: Light winds, generally 2–7 mph, easing overnight.\n- Key times: Peak heat in the mid-afternoon (roughly 1–4 pm) with temperatures up to 33°C.\n\nUpdated: 10:57pm on 7 July 2026.\n\n\nTitle: London, United Kingdom Hourly Weather Forecast | Weather Underground\nURL: https://wu-next-prod-us-east-1-aws.wunderground.com/hourly/gb/london/ILONDO540/date/2026-7-7\nID: https://wu-next-prod-us-east-1-aws.wunderground.com/hourly/gb/london/ILONDO540/date/2026-7-7\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://www.wunderground.com/static/i/c/v4/31.svg\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: London, United Kingdom hourly forecast (July 7, 2026) highlights:\n- Tonight (July 7): Clear sky, low around 66°F (18°C). Winds N 5–10 mph.\n- Tomorrow (July 8): Mainly sunny and hot, high near 91°F (33°C). Winds light/variable.\n- Current conditions: Clear with temperature around 80°F at Chiswick Station. Pressure ~30.04 in, visibility 10 miles, humidity ~50%.\n\nAdditional: Moon phase shows last quarter around 1:15 PM; civil/nighttime twilight times listed (sunrise 4:53 AM, sunset 9:20 PM). No precipitation expected.\n\n\nTitle: London - BBC Weather\nURL: https://www.bbc.com/weather/6058560\nID: https://www.bbc.com/weather/6058560\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://weather.files.bbci.co.uk/weather-web-component-renderer/109/og-image.png\nFavicon: https://static.files.bbci.co.uk/core/website/assets/static/icons/favicon/weather/favicon-32.97881c35d3eb6eac0075.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary:\n- The page provides London weather forecasts from BBC Weather, including a 14-day outlook and day-by-day details.\n- For July 7, 2026 specifically, the site shows a forecast starting with tonight and listing conditions for the following day.\n- Tonight: Clear sky with light winds (low around 16°C).\n- Wednesday 8 July: Sunny with high around 30°C, low around 18°C, light SW breeze.\n- The forecast continues with mild to warm conditions in the near term, including thundery showers on Thursday 9 July and varying precipitation through the week, with mostly sunny days and occasional rain.\n\nNote: The page update timestamp is today at 19:02. For exact hourly details and the precise conditions for July 7, 2026, you may want to view the day-by-day forecast on the page.\n\n\nTitle: Weather in London,, for July 7 — Temperature, precipitation, wind\nURL: https://meteum.ai/weather/en/london/date/july/7\nID: https://meteum.ai/weather/en/london/date/july/7\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://weather.yastatic.net/s3/weather-frontend/front2/_next/static/media/meteum_black.e74474f0.svg\nFavicon: https://meteum.ai/weather/favicon.ico\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Forecast for London on July 7, 2026:\n\n- Temperature: High around 30°C (feels ~29°C). Morning ~22°C, night ~23°C.\n- Sky/precipitation: Hot and cloudy; no rain indicate ...
#  ToolMessage(content="Title: NYC weather: Tuesday morning forecast | FOX 5 New York\nURL: https://www.fox5ny.com/video/fmc-7g63jpr7bicsd5xa.amp\nID: https://www.fox5ny.com/video/fmc-7g63jpr7bicsd5xa.amp\nScore: None\nPublished Date: 2026-07-07T11:44:00.000Z\nAuthor: None\nImage: None\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Forecast for New York on July 7, 2026:\n- Tuesday will see temperatures reaching up to 74°F.\n- Humidity remains high.\n- More rain is expected later in the week.\n\n\nTitle: New York, NY 7 July Weather. Forecast for New York, NY - United States, New York\nURL: https://globalmeteo.com/weather/new-york/jul-07/\nID: https://globalmeteo.com/weather/new-york/jul-07/\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://globalmeteo.com/images/precip-svg/18.svg\nFavicon: https://globalmeteo.com/images/icon/favicon-32x32.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary:\n- The page provides a July 7, 2026 weather forecast for New York, NY.\n- Forecast overview: temperatures around the upper 60s to low 70s °F during the day (e.g., 68–75°F latest updates), with light to moderate winds (roughly 8–11 mph from the NE). Cloud cover is shown for evening (6 pm) with cloudy conditions listed.\n- Time-specific snapshot (typical daily progression for July 7): 12 am ~67°F, morning ~64–70°F, afternoon ~70–75°F, evening ~68°F with variable wind around 8–11 mph; pressure near ~29.96–30.01 inHg.\n- Note: Data is based on GFS model and formatted for personal use; includes climate-normal comparisons and historical July 7 data for context.\n\nIf you want, I can pull a tighter hourly forecast for July 7, 2026 or compare this to climate normals.\n\n\nTitle: New York, NY 7 Days Weather - The Weather Network\nURL: https://www.theweathernetwork.com/en/city/us/new-york/new-york/7-days\nID: https://www.theweathernetwork.com/en/city/us/new-york/new-york/7-days\nScore: None\nPublished Date: None\nAuthor: Pelmorex Corp.\nImage: https://www.theweathernetwork.com/images/logos/twn-logo.png\nFavicon: https://www.theweathernetwork.com/favicon.ico\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary of 2026-07-07 New York weather (as shown on The Weather Network)\n\n- Forecast date: Tue Jul 7\n- Afternoon: 21°C, Feels 21°C; Cloudy with showers; precipitation ~40% (<1 mm)\n- Evening: 21°C, Feels 21°C; Passing showers; precipitation ~30%\n- Overnight: 18°C, Feels 18°C; minimal rain chances (~30%)\n\nOther quick notes:\n- Humidity: ~94% in the afternoon\n- Wind: NE around 20 km/h with gusts up to ~32 km/h\n\nThis page also provides the 7-day and hourly/72-hour views, but the key July 7 forecast is as above.\n\n\nTitle: New York City, NY Monthly Weather | AccuWeather\nURL: https://www.accuweather.com/en/us/new-york/10021/july-weather/14-349727_1_al\nID: https://www.accuweather.com/en/us/new-york/10021/july-weather/14-349727_1_al\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://www.accuweather.com/images/logos/aw-logo-og-meta.png\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary:\n- The page provides July 2026 weather for New York City with daily highs from about 21.9° to 31.7°C and overnight lows from about 17.8° to 23.3°C.\n- Average July high: 29°C; average July low: 22°C.\n- It notes day-by-day RealFeel temperatures for a more accurate sense of actual conditions.\n- The forecast is part of AccuWeather’s 2026 monthly forecast and includes a 10-day view.\n\n\nTitle: Weather in New York, State of New York, United States, for July 7 — Temperature, precipitation, wind\nURL: https://yandex.com/weather/en/new-york/date/july/7\nID: https://yandex.com/weather/en/new-york/date/july/7\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://weather.yastatic.net/s3/weather-frontend/front2/_ ...
#  ToolMessage(content="Title: FIFA World Cup Matches Scores — July 7, 2026\nURL: https://exa.ai/library/sports/fifa-world-cup?date=2026-07-07&t=6a4da7cf63877a08abd5b2bc\nID: https://exa.ai/library/sports/fifa-world-cup?date=2026-07-07\nScore: None\nPublished Date: 2026-07-08T00:28:44.940Z\nAuthor: None\nImage: None\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Today’s World Cup results (July 7, 2026):\n\n- Belgium 4, USA 1 (Seattle, WA)\n- Egypt 2, Argentina 3 (Atlanta, GA)\n- Colombia 0, Switzerland 0 (Vancouver, BC)\n\nAll three matches finished as of final.\n\n\nTitle: Argentina 3-2 Egypt (7 Jul, 2026) Game Analysis - ESPN\nURL: https://africa.espn.com/football/report/_/gameId/760509\nID: https://africa.espn.com/football/report/_/gameId/760509\nScore: None\nPublished Date: 2026-07-07T18:11:15.000Z\nAuthor: None\nImage: None\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Argentina 3-2 Egypt (July 7, 2026) – World Cup Round of 16\n\n- Argentina overturned a 2-0 deficit in the second half to win in stoppage time.\n- Yasser Ibrahim gave Egypt a halftime lead; Mostafa Zico extended Egypt’s lead after VAR ruled out Messi’s earlier penalty.\n- Cristian Romero headed Argentina onto the comeback trail; Lionel Messi equalized in the 83rd minute.\n- Enzo Fernández headed the late winner in stoppage time (2nd minute of added time) to send Argentina to the quarterfinals.\n- Location: Atlanta, Georgia, USA. Final score: Argentina 3, Egypt 2.\n\n\nTitle: World Cup: Lionel Messi rips Argentina from the jaws of defeat vs. Egypt - Yahoo Sports\nURL: https://sports.yahoo.com/soccer/article/world-cup-lionel-messi-rips-argentina-from-the-jaws-of-defeat-vs-egypt-180541451.html\nID: https://sports.yahoo.com/soccer/article/world-cup-lionel-messi-rips-argentina-from-the-jaws-of-defeat-vs-egypt-180541451.html\nScore: None\nPublished Date: None\nAuthor: Jay Busbee   Senior writer Tue, July 7, 2026 at 6:05 PM UTC · 6 min read\nImage: https://s.yimg.com/ny/api/res/1.2/QL5FXHJVbI89CyPEuCircQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDI7Y2Y9d2VicA--/https://d29szjachogqwa.cloudfront.net/images/2026-07/80a66085-6ec8-436e-aeb2-fa8a84c03984\nFavicon: https://sports.yahoo.com/favicon.ico?0aa76129f3cb808f\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Lionel Messi sparked a dramatic 3-2 comeback win for Argentina over Egypt in the World Cup, overturning a 2-0 deficit by scoring the equalizer and the late winner. Egypt led early, Messi leveled the score with a cross-headed goal from Romero, and Argentina pulled ahead with a late Filipe Fernandez header after a VAR-overturned goal earlier (Zico via Salah assist). Argentina advances to the World Cup quarterfinals; Egypt’s run ends. Argentina now awaits the winner of Colombia vs. Switzerland.\n\n\nTitle: Argentina v Egypt, 07 July 2026 - 11v11 match report\nURL: https://www.11v11.com/matches/argentina-v-egypt-07-july-2026-393774/\nID: https://www.11v11.com/matches/argentina-v-egypt-07-july-2026-393774/\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://www.11v11.com/generic/graphics/logos/11v11-logo-65x62.gif\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary: On July 7, 2026, in the FIFA World Cup Finals Round of 16, Argentina defeated Egypt 3-2 at Mercedes-Benz Stadium, Atlanta. Referee: François Letexier. Attendance: 68,239. Argentina goals: Cristian Romero (79), Lionel Messi (83), Enzo Fernández (90+2). Egypt goals: Yasser Ibrahim (15), Mostafa Zico (67). Final score: Argentina 3, Egypt 2.\n\n\nTitle: Balogun reprieve in vain as Belgium beat USA to set up Spain quarterfinal | World Cup 2026 News | Al Jazeera\nURL: https://www.aljazeera.com/sports/2026/7/7/usa-cant-make-most-of-balogun-reprieve-as-belgium-set-up-spain-quaterfinal\nID: https://www.aljazeera.com/sports ...

# %% [markdown]
# ### 3. Tool의 처리(응답) 결과를 LLM 요청시 사용
# - ToolMessage를 prompt 에 추가하여 LLM에 요청한다.
# - ToolMessage 는 Tool Calling 정보를 가진 AIMessage 다음에 들어와야 한다.
# - Prompt 순서
#     1. 일반 prompt (system, 대화 history, .., human)
#     2. AIMessage: tool calling 정보를 가진 AIMessage. (tool_model에 질의 받은 tool calling 정보가 있는 응답)
#     3. ToolMessage:  Tool의 처리 결과

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import chain
from langchain_tavily import TavilySearch
from langchain_exa import ExaSearchResults
from datetime import date
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
prompt_str = """
- 당신은 사용자의 다양한 질문에 답변하는 AI assistant입니다.
- 사용자의 질문에 상대적 시간 표현이 포함되어 있고 절대 날짜가 명시되어 있지 않은 경우, 오늘 날짜를 기준으로 실제 날짜를 계산한 뒤 검색합니다.
    - 상대적 시간 표현 예: 현재, 오늘, 어제, 내일, 이번 주, 지난주, 이번 달, 지난달, 올해, 작년
- 오늘 날짜는 {today}입니다.
- 답변에 필요한 정보가 부족하거나 최신 정보 확인이 필요한 경우, 적절한 tool을 사용해 정보를 수집합니다.
    - 질문에 답변하기 위해 웹 검색 tool을 사용할 때, 질문에 시점 정보가 필요한 경우 계산된 날짜나 시간 범위를 검색 쿼리에 포함해야 합니다.
- 웹 검색이 필요할 경우 binding 된 웹검색 tool(tavily_search, exa_search_results_json) 을 모두 사용합니다.
- 사용할 수 있는 tool은 다음과 같습니다.
    - tavily_search: 웹 검색 tool
    - exa_search_results_json: 웹 검색 tool
"""

# %%
model = ChatOpenAI(model="gpt-5.4-mini")
tavily_search = TavilySearch(max_results=5)
exa_search = ExaSearchResults(max_results=5)
tool_model = model.bind_tools([tavily_search, exa_search])
today = date.today().strftime('%Y년, %m월, %d일')
prompt = ChatPromptTemplate(
    [
        ('system', prompt_str),
        ('human', "{query}"),
        MessagesPlaceholder(variable_name="tool_message", optional=True)
    ],
    partial_variables={'today': today},
)
# promt.invoke({"query": "질문"})

tool_model_chain = prompt | tool_model

# %%
tavily_search_name = tavily_search.name
exa_search_name = exa_search.name
@chain
def web_agent(query:str)->tuple[str, list]:
    """
    Agent의 전체 흐름을 처리하는 Runnable.
    사용자 질문을(query) 받아소 tool_model과 tool을 이용해 최종 응답을 생성해서 반환한다.
    Args:{query}
        query(str): 사용자 질의
    Retuirns:
        tuple[str, list] : AI의 최종답변(str)과 tool 메세지들(list)
    """
    messages = []
    ai_message = tool_model_chain.invoke(query)
    while ai_message.tool_calls:
        for tool_call in ai_message.tool_calls:
            if tool_call["name"] == tavily_search_name:
                messages.append(tavily_search.invoke(tool_call))
            elif tool_call["name"] == exa_search_name:
                messages.append(exa_search.invoke(tool_call))
        messages = [ai_message] + messages
        ai_message = tool_model_chain.invoke(
            {"query":query, "tool_messages":messages}
        )
    messages.append(ai_message)
    return ai_message.content, messages

# %%
result1 =  web_agent.invoke("안녕하세요. 반갑습니다.")

# %%
result1
# Out:
# ('안녕하세요! 반갑습니다. 무엇을 도와드릴까요?',
#  [AIMessage(content='안녕하세요! 반갑습니다. 무엇을 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 2020, 'total_tokens': 2038, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DzAS2xzpvrQNjf7UFNnUvplsN6jdx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f3f20-fbbe-7752-ad67-f3952a8dbb39-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2020, 'output_tokens': 18, 'total_tokens': 2038, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})])

# %%
result2 = web_agent.invoke("북중미 월드컵 결과")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 result2 = web_agent.invoke("북중미 월드컵 결과")
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:5313, in RunnableLambda.invoke(self, input, config, **kwargs)
#    5298 """Invoke this `Runnable` synchronously.
#    5299
#    5300 Args:
#    (...)   5310
#    5311 """
#    5312 if hasattr(self, "func"):
# -> 5313     return self._call_with_config(
#    5314         self._invoke,
#    5315         input,
#    5316         ensure_config(config),
#    5317         **kwargs,
#    5318     )
#    5319 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    5320 raise TypeError(msg)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:2289, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2285     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2286     with set_config_context(child_config) as context:
#    2287         output = cast(
#    2288             "Output",
# -> 2289             context.run(
#    2290                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2291                 func,
#    2292                 input_,
#    2293                 config,
#    2294                 run_manager,
#    2295                 **kwargs,
#    2296             ),
#    2297         )
#    2298 except BaseException as e:
#    2299     run_manager.on_chain_error(e)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\config.py:526, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     524 if run_manager is not None and accepts_run_manager(func):
#     525     kwargs["run_manager"] = run_manager
# --> 526 return func(input, **kwargs)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:5170, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    5168                 output = chunk
#    5169 else:
# -> 5170     output = call_func_with_variable_args(
#    5171         self.func, input_, config, run_manager, **kwargs
#    5172     )
#    5173 # If the output is a Runnable, invoke it
#    5174 if isinstance(output, Runnable):
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\config.py:526, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     524 if run_manager is not None and accepts_run_manager(func):
#     525     kwargs["run_manager"] = run_manager
# --> 526 return func(input, **kwargs)
#
# Cell In[27], line 20, in web_agent(query)
#      16         for tool_call in ai_message.tool_calls:
#      17             if tool_call["name"] == tavily_search_name:
#      18                 messages.append(tavily_search.invoke(tool_call))
#      19             elif tool_call["name"] == exa_search_name:
# ---> 20                 messages.append(exa_search.invoke(tool_call))
#      21         messages = [ai_message] + messages
#      22         ai_message = tool_model_chain.invoke(
#      23             {"query":query, "tool_messages":messages}
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\tools\base.py:738, in BaseTool.invoke(self, input, config, **kwargs)
#     730 @override
#     731 def invoke(
#     732     self,
#    (...)    735     **kwargs: Any,
#     736 ) -> Any:
#     737     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 738     return self.run(tool_input, **kwargs)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\tools\base.py:1100, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1098 if error_to_raise:
#    1099     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1100     raise error_to_raise
#    1101 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1102 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\tools\base.py:1066, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1064     if config_param := _get_runnable_config_param(self._run):
#    1065         tool_kwargs |= {config_param: config}
# -> 1066     response = context.run(self._run, *tool_args, **tool_kwargs)
#    1067 if self.response_format == "content_and_artifact":
#    1068     msg = (
#    1069         "Since response_format='content_and_artifact' "
#    1070         "a two-tuple of the message content and raw tool output is "
#    1071         f"expected. Instead, generated response is of type: "
#    1072         f"{type(response)}."
#    1073     )
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_exa\tools.py:144, in ExaSearchResults._run(self, query, num_results, text_contents_options, highlights, include_domains, exclude_domains, start_crawl_date, end_crawl_date, start_published_date, end_published_date, use_autoprompt, livecrawl, summary, type, run_manager)
#     123 """Use the tool.
#     124
#     125 Args:
#    (...)    141
#     142 """  # noqa: E501
#     143 try:
# --> 144     return self.client.search_and_contents(
#     145         query,
#     146         num_results=num_results,
#     147         text=text_contents_options,
#     148         highlights=highlights,
#     149         include_domains=include_domains,
#     150         exclude_domains=exclude_domains,
#     151         start_crawl_date=start_crawl_date,
#     152         end_crawl_date=end_crawl_date,
#     153         start_published_date=start_published_date,
#     154         end_published_date=end_published_date,
#     155         use_autoprompt=use_autoprompt,
#     156         livecrawl=livecrawl,
#     157         summary=summary,
#     158         type=type,
#     159     )  # type: ignore[call-overload, misc]
#     160 except Exception as e:
#     161     return repr(e)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\exa_py\api.py:1607, in Exa.search_and_contents(self, query, **kwargs)
#    1591 options = nest_fields(
#    1592     options,
#    1593     [
#    (...)   1604     "contents",
#    1605 )
#    1606 options = to_camel_case(options, skip_keys=["schema"])
# -> 1607 data = self.request("/search", options)
#    1608 cost_dollars = parse_cost_dollars(data.get("costDollars"))
#    1609 results = []
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\exa_py\api.py:1234, in Exa.request(self, endpoint, data, method, params, headers)
#    1232         return res
#    1233     else:
# -> 1234         res = requests.post(
#    1235             self.base_url + endpoint, data=json_data, headers=request_headers
#    1236         )
#    1237 elif method.upper() == "PATCH":
#    1238     res = requests.patch(
#    1239         self.base_url + endpoint, data=json_data, headers=request_headers
#    1240     )
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\requests\api.py:134, in post(url, data, json, **kwargs)
#     117 def post(
#     118     url: _t.UriType,
#     119     data: _t.DataType = None,
#     120     json: _t.JsonType = None,
#     121     **kwargs: Unpack[_t.PostKwargs],
#     122 ) -> Response:
#     123     r"""Sends a POST request.
#     124
#     125     :param url: URL for the new :class:`Request` object.
#    (...)    131     :rtype: requests.Response
#     132     """
# --> 134     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\requests\api.py:71, in request(method, url, **kwargs)
#      67 # By using the 'with' statement we are sure the session is closed, thus we
#      68 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      69 # cases, and look like a memory leak in others.
#      70 with sessions.Session() as session:
# ---> 71     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\requests\sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\requests\sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\requests\adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     693     resolved_timeout = TimeoutSauce(connect=timeout, read=timeout)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#     711     raise ConnectionError(err, request=request)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\urllib3\connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785 response_conn = conn if not release_conn else None
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#     804 clean_exit = True
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Playdata\SKN\SKN31\10_AI_Agent\.venv\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\http\client.py:1450, in HTTPConnection.getresponse(self)
#    1448 try:
#    1449     try:
# -> 1450         response.begin()
#    1451     except ConnectionError:
#    1452         self.close()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     334 # read until we get a non-100 response
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#     338         break
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\http\client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#     299         raise LineTooLong("status line")
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(result2[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(result2[0])
#
# TypeError: 'AIMessage' object is not subscriptable

# %%
result2[1][0].tool_calls
print(result2[1][0].tool_calls)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 result2[1][0].tool_calls
#       2 print(result2[1][0].tool_calls)
#
# TypeError: 'AIMessage' object is not subscriptable

# %% [markdown]
# # 사용자 정의 Tool 구현
#
# ## @tool 사용
# - 함수로 구현하고 `@tool` 데코레이터를 사용해 tool(StructuredTool)로 정의한다.
#     - `langchain_core.tools` 모듈에 있다.
# - tool name
#     - 함수의 이름이 tool의 이름이 된다.
# - parameters
#     - 함수의 파라미터가 tool의 파라미터가 된다.
#     - **type hint**를 이용해 타입을 지정한다.
# - description
#     - doctring이 description이 된다.
#     - RunnableBinding(model + tool)이 tool을 잘 찾을 수 있도록 하려면 **tool의 기능을 최대한 구체적**으로 작성한다.
# - **@tool이 적용된 함수(StructuredTool)가 tool**이므로 model에 binding 한다.

# %%
from langchain_core.tools import tool
@tool
def plus(num1:int|float, num2:int|float)->int|float:
    """받은 두개의 수를 덧셈하는 툴"""
    return num1 + num2

@tool
def minus(num1:int|float, num2:int|float)->int|float:
    """받은 두개의 수를 뺄셈하는 툴"""
    return num1 - num2

@tool
def multifly(num1:int|float, num2:int|float)->int|float:
    """받은 두개의 수를 곱셈하는 툴"""
    return num1 * num2
# 파라미터에 대한 자세한 설명을 해야하는 경우 -> pydntic.BaseModel로 정의
from pydantic import BaseModel, Field
class DivideToolParameter(BaseModel):
    num1:int|float = Field(..., description="나눌 때 사용할 첫번째 값")
    num1:int|float = Field(..., description="나눌 때 사용할 두번째 값. 0은 사용할 수가 없다")

@tool("divide_tool")
def divide(num1:int|float, num2:int|float)->int|float:
    """받은 두개의 수를 나눗셈하는 툴"""
    return num1 / num2

type(plus)
# Out:
# langchain_core.tools.structured.StructuredTool

# %%
print(divide.name)
print(divide.description)
divide.args
# Out:
# divide_tool
# 받은 두개의 수를 나눗셈하는 툴
# {'num1': {'anyOf': [{'type': 'integer'}, {'type': 'number'}], 'title': 'Num1'},
#  'num2': {'anyOf': [{'type': 'integer'}, {'type': 'number'}], 'title': 'Num2'}}

# %%
plus.invoke({"num1":10,"num2":20})
divide.invoke({"num1":10,"num2":20})
# Out:
# 0.5

# %%
model = ChatOpenAI(model="gpt-5.4-mini").bind_tools([plus, minus, multifly, divide])
result = tool_model.invoke("30 - 20 * 10의 결과는 얼마야? 계산할 때 툴이 있으면 툴을 사용해줘")

# %%
result.content
# Out:
# '30 - 20 * 10 = 30 - 200 = **-170** 입니다.\n\n계산은 간단해서 툴 없이도 바로 할 수 있었어요.'

# %%
result.tool_calls
# Out:
# []

# %% [markdown]
# ## Runnable을 tool로 정의
# - `Runnable객체.as_tool()`
#     - name, description, args_schema 파라미터를 이용해 tool의 이름, 설명, 스키마를 설정한다.

# %%
! uv pip install wikipedia
# 위키백과사전 검색 라이브러리
# Out:
# Checked 1 package in 318ms

# %%
from langchain_community.document_loaders import WikipediaLoader
from pydantic import BaseModel, Field
from langchain_core.runnables import chain
import json
@chain
def wikipedia_search(inputs: dict)->str:
    """
    사용자가 쿼리를 검새어로 위키백과서전을 검색하고 그 결과 중 k개의 문서 내용을 반환한다.
    Args;
        inputs(dict): key-query, max-result.query(str) 검색할 키워드, max_result(int) 검색할 결과수
    Returns:
        str - 검색한 결과들을 json 형식의 문자열로 반환.
        형식: {"result":[{검색괸 문서정보들}, {검색괸 문서정보들}]}
    """

    query = inputs['query']
    max_result = inputs.get("max_result", 3)
    loader = WikipediaLoader(
        query=query,
        load_max_docs=max_result,
        lang="ko"
    )
    cnt = 0 
    result_list = []
    while True:
        cnt += 1
        try:
            docs = loader.load()            
            for doc in docs:
                result_list.append(
                    {
                        "content":doc.page_content,
                        "title":doc.metadata.get("title"),
                        "url":doc.metadata.get("source"),
                    }
                )
            break
        except Exception as e:
            if cnt == 4:
                break
            continue
    if result_list:
        result= {"result":result_list}
    else:
        result = {"result":"검색된 문서가 없습니다."}
    return json.dumps(result, ensure_ascii=False)

# %%
l = {"name":"홍길동", "age":30}
json.dumps(l, ensure_ascii=False)
# Out:
# '{"name": "홍길동", "age": 30}'

# %%
type(wikipedia_search)
r = wikipedia_search.invoke({'query':"비빔밥", "max_result":5})

# %%
json.loads(r)
# Out:
# {'result': [{'content': '비빔은 한국의 밥 요리이다. 쌀밥에 고기나 나물 등과 여러 가지의 양념을 넣어 비벼 먹는 음식이며, 비빔밥이나 제삿밥, 골동반(骨董飯), 교반(攪飯)으로도 부른다. 과거 궁중에서는 비빔이라 불렀다. 대한민국의 국민 음식 가운데 하나로 여겨진다.\n\n\n== 역사 ==\n비빔밥의 기원은 정확하지 않다. 그릇이 많이 없는 집 밖에서 산신제나 동신제를 지낼 때 신인공식(神人共食)이라는 생각에 따라 그릇 하나에 이것저것 받아 섞어 먹던 것, 또는 조상을 위한 제사를 지낼 때 제물을 빠짐없이 음복하기 위해 밥에 여러 가지 제찬을 고루 섞어 비벼 먹던 것에서 발달하였을 수 있다.\n비빔밥은 조선 중기의 문신 박지혜(1569~1635)가 지은 역사서 《기재잡기》에 "혼돈반(混沌飯)"으로, 조선 후기의 문신 권상일(1679~1760)이 쓴 일기인 《청대일기》에 "골동반(骨董飯)"으로 언급된다. 그 외에도 실학자 이익(1681~1764)이 지은 《성호전집》에는 "골동(骨董)"으로, 실학자 이덕무(1741~1793)의 《청장관전서》에는 "골동반(汨董飯)"으로, 이학규(1770~1835)의 《낙하생집》에는 "골동반(骨董飯)"과 "골동(骨董)"으로 언급된다.\n\n"전임(?∼1509)이 대답하기를, \'오직 공께서 명하시는 대로 먹겠습니다\' 하니, 곧 밥 한 대접에다가 생선과 채소를 섞어 세상에서 말하는 비빔밥과 같이(如俗所謂混沌飯/여속소위혼돈반) 만들고 술 세 병들이나 되는 한 잔을 대접하니, 전임이 두어 숟갈에 그 밥을 다 먹어 치우고 단숨에 그 술을 들이켰다."\n\n1810년 장혼이 지은 학습용 백과서 《몽유편》에는 "브뷔음"이라는 한글 표기가 등장하며, 1870년 《명물기략》에는 "비빔밥을 한자로는 \'골동반(骨董飯)\'이라고 쓰고, 부를 때는 \'부빔밥(捊排飯/부배반)\'이라고 한다(骨董飯取飮食雜和飯俗言捊排飯又曰谷董/골동반취음식잡화반속언부배반우왈곡동)."는 언급이 나온다.\n이규경(1788~1856)이 지은 《오주연문장전산고》에는 채소비빔밥, 잡비빔밥, 회비빔밥, 전어비빔밥, 대하비빔밥, 새우젓갈비빔밥, 새우알비빔밥, 게장비빔밥, 달래비빔밥, 생오이비빔밥, 김가루비빔밥, 고추장비빔밥, 황두비빔밥 등 여러 가지 비빔밥이 소개되어 있으며, 지역의 특산물을 소개하며 "평양의 감홍로, 냉면, 비빔밥(平壤之紺紅露冷麪骨蕫飯/평양지감홍로랭면골동반)"을 들기도 하였다.\n19세기 후반의 조리서인 《시의전서》에는 비빔밥의 조리법이 다음과 같이 언급된다.\n\n"밥을 정히 짓고 고기는 재워 볶고 간납은 부쳐 썬다. 각색 남새를 볶아 놓고 좋은 다시마로 튀각을 튀겨서 부숴 놓는다. 밥에 모든 재료를 다 섞고 깨소금·기름을 많이 넣어 비벼서 그릇에 담는다. 위에는 잡탕거리처럼 계란을 부쳐서 골패짝만큼씩 썰어 얹는다. 완자는 고기를 곱게 다져 잘 재워 구슬만큼씩 빚은 다음 밀가루를 약간 묻혀 계란을 씌워 부쳐 얹는다. 비빔밥 상에 장국은 잡탕국으로 해서 쓴다."\n\n\n== 비빔밥종류 ==\n\n지역에 따라 여러 가지 비빔밥이 있는데, 특히 전주비빔밥과 진주비빔밥 등이 유명하다. 최근 식단이 서구화되면서, 다양한 재료를 활용한 퓨전 비빔밥이 등장하거나, 잊혀져가는 지방의 비빔밥을 재해석해 현대화하기도 한다.\n\n꼬막비빔밥: 전라남도 순천, 벌교의 비빔밥으로 벌교 꼬막과 무순 등을 넣고 비벼 만든다.\n닭비빔밥: 평안도 지방의 비빔밥으로 삶은 닭고기를 넣어 푸짐하고 고추장대신 참기름에 고춧가루를 개어 칼칼하다. 또한 닭고기와 콩나물이 들어간 닭국을 곁들여 먹는다.\n돌솥비빔밥: 돌솥에 내는 비빔밥이다.\n마산비빔밥: 경상남도 마산의 비빔밥으로 마산의 특산물인 장에 미더덕과 조개의 육즙으로 무친 나물을 넣고 만든다.\n멍게젓비빔밥: 멍게젓을 이용한 거제도의 대표적인 향토음식이다. 거제도의 특산물인 멍게를 잘게 썰어 서늘한 곳에 2~5일 젓갈로 숙성시킨 후 밥위에 비벼 먹는다. 고추장 대신 김가루와 깨소금, 참기름에 비벼먹는다.\n알밥: 생선알을 넣어 만든 비빔밥이다.\n육회비빔밥: 여러 가지 야채와 배를 썰어 넣고 육회가 어우러진 것으로, 부드럽게 씹히는 생고기와 감칠맛 나는 매콤한 양념장이 어우러져 함평만이 독특한 비빔밥이다.\n전주비빔밥: 전북특별자치도 전주시의 비빔밥으로서, 재료 중에서 콩나물이 중요하다. 임실군에서 나는 서목태와 좋은 물로 길러서 오래 삶아도 질감이 좋은 것이 특징이다. 밥을 지을 때 쇠머리 고운 물로 밥을 짓고 뜸들일 때에 콩나물을 넣는다. 달걀 노른자는 생으로 올라간다. 콩나물국과 함께 먹는다. 육수에 밥을 짓고 쇠고기, 콩나물, 시금치, 쑥갓, 고사리, 도라지, 미나리, 표고버섯 등을 얹어 고추장에 비벼먹는 따뜻한 밥이다. 육회가 올려지기도 한다.\n진주비빔밥: 경상남도 진주 지방의 비빔밥으로 놋그릇에 흰밥과 다섯 가지 나물을 담은 후 고추장을 얹는 데, 그 모습이 아름다워서 화반(花飯)이라고 불린다. 일반적인 비빔밥처럼 콩나물 대신 숙주나물을 쓰며, 해초나물과 해물보탕국 한국자 넣고, 그 위에 소고기 육회를 듬뿍 얹어낸다. 곁들여 먹는 국물은 선짓국을 쓴다.\n통영비빔밥: 경상남도 통영의 비빔밥으로, 그 지역 사람들은 명절의 차례 및 기 제사, 잔치 등에 먹는다. 미륵도 근처 이끼섬에서 자생하는 방풍초(防風草)를 나물로 무친 방풍나물이 들어간다. 그외 볶은 조개를 두부에 섞어 만든 톳나물과 계절에 따라 10가지 이상의 나물을 넣는다. 생합자와 바지락 볶은 것을 넣는 것도 특색이다.\n평양비빔밥: 전주비빔밥과 유사하지만 육회대신 볶은 소고기를, 콩나물 대신 숙주나물을 사용하여 고유의 독특한 맛을 지닌다.\n해주비빔밥: 황해도 해주의 비빔밥으로, 모양이 아름다워서 교반(交飯)이라고 하여 유명하였다.\n헛제삿밥: 대구 헛제삿밥도 유명했으나 지금은 사라지고, 안동의 헛제삿밥만이 남았다. 실제 제사가 아니라 제삿상에 주로 올리는 음식들을 요리하여, 제사가 아닌 평상시에 비벼 먹는 비빔밥을 의미한다. 실제 제사를 올린 음식으로 비빔밥을 해 먹을 때에는 \'제삿밥\'으로 지칭한다. 고추장 대신, 간장으로 맛을 내며, 전이나 구운 생선 토막, 또는 산적을 곁들인다.\n회덮밥: 생선회를 넣어 만든 비빔밥이다. 대표적으로 홍어회 비빔밥 / 장어 덮밥/ 참치 덮밥/광어 덮밥/연어 덮밥/새우장 덮밥\n산채비빔밥: 여러 가지 나물을 넣고 참기름과 고추장에 비벼서 먹는 비빔밥이라고 전해지고 있다.\n닭고기 비빔밥:닭과 여러가지 야채 및 고명으로 계란을 올려서 고추장에 비벼먹는 비빔밥이라고 한다.\n\n\n== 풍속 ==\n비빔밥을 "헛제삿밥"이라고도 하며, 밤참을 파는 집을 "헛제삿집"이라고도 한다. 이는 밤참을 먹는 것이 마치 제례 후에 음복을 하고 종가에서 비벼주는 밥을 먹는 듯하다는 뜻에서 붙여진 말로, 현대에도 제사를 지내는 집에서는 음복 후에 젯메(밥)와 제삿상에 올린 적, 숙채, 간납 등을 넣고 밥을 비벼 먹는 경우가 있다.\n섣달 그믐날에는 그 해에 먹던 반찬이 해를 넘기는 것을 꺼려하여서, 남은 밥에 먹다 남은 반찬을 모두 넣고 비벼서 밤참으로 나누어 먹기도 하였다.\n농촌에서는 들밥을 준비할 때 밥과 나물을 준비하고 그릇으로 쓸 자그마한 바가지를 많이 가지고 나가면, 일꾼들이 각자 바가지에 먹을 만큼 밥을 덜고 나물과 고추장을 덜어 넣어 비벼 먹기도 하였다.\n\n\n== 사진 ==\n\n\n== 같이 보기 ==\n껌 엄푸\n볶음밥\n비빔국수\n\n\n== 각주 ==',
#    'title': '비빔밥',
#    'url': 'https://ko.wikipedia.org/wiki/%EB%B9%84%EB%B9%94%EB%B0%A5'},
#   {'content': "《보석 비빔밥》은 2009년 9월 5일부터 2010년 2월 21일까지 방영된 문화방송 주말 특별기획 드라마이며 해당 작품부터 MBC의 주말 특별기획 드라마가 9시 45분으로 이동하면서 2009년 4월 4일 독립 편성된 뒤 토요일 밤 10시 35분에 편성됐지만 MBC가 《2009 외인구단》을 통해 주말 특별기획 드라마를 부활(2차)시킴에 따라 같은 해 5월 2일부터 9시 45분으로 옮겨간 《세바퀴》는 《2009 외인구단》과 그 후속작 《친구, 우리들의 전설》이 기대 이하의 성적에 그치자 앞서 본 것처럼 해당 작품부터 주말 특별기획 드라마가 9시 45분으로 옮겨짐에 따라 2009년 9월 5일부터 토요일 10시 45분으로 옮겨갔고 주말 《뉴스데스크》시간대가 2010년 가을개편부터 8시로 조정되자 같은 해 11월 6일부터 토요일 밤 11시 15분으로 이동했다.\n\n\n== 기획 의도 ==\n네 가지 보석(비취, 루비, 산호, 호박) 이름을 지닌 4남매의 로맨스 이야기를 다룬 홈 드라마.\n\n\n== 등장 인물 ==\n\n\n=== 루비네 ===\n한진희 : 궁상식(55세) 역 - 궁씨 집안의 가장이며 5남매의 아빠, S호텔 도어맨.\n한혜숙 : 피혜자(55세) 역 - 궁씨 집안의 안주인이며 5남매의 엄마.\n강세정 : 궁비취(28세) 역 - 장녀, 구성작가 → 분식집 사장, 영국의 아내.\n소이현 : 궁루비(26세) 역 - 차녀, 간호사. 병훈의 여자친구- 아내\n이현진 : 궁산호(24세) 역 - 장남, 외무고시생 → 외교관. 강지의 남자친구->남편\n이일민 : 궁호박(18세) 역 - 차남, 고등학생.\n레시퐁 레오 : 궁태자(2세) 역 - 3남, 궁상식이 밖에서 낳아온 아들\n김영옥 : 결명자(74세) 역 - 상식의 어머니, 욕쟁이며 5남매의 친할머니.\n정혜선 : 백조(74세) 역 - 혜자의 친정엄마, 5남매의 외할머니\n\n\n=== 영국이네 ===\n박근형 : 서로마 (62세) 역 - 영국과 끝순의 아버지, 태리의 남편, 청명자기 회장\n홍유진 : 이태리 (55세) 역 - 영국과 끝순의 엄마, 로마의 아내\n이태곤 : 서영국(30세) 역 - 로마의 큰아들, 끝순의 오빠, 비취의 남편\n최아진 : 서끝순(18세) 역 - 로마의 막내딸, 영국의 여동생, 호박의 여자친구\n\n\n=== 그 외 인물 ===\n마이클 블렁크 : 카일(32세) 역 - 수도승 지원자\n정유미 : 이강지(23세) 역 - 산호의 여자친구 → 아내\n서우림 : 사장(70세) 역 - 루비가 일하는 병원의 환자, 전 의상실 사장이자 자산가\n신신애 : 피혜자의 친구 역\n최재호 : 조방규(40세) 역 - 궁상식의 동료, 호텔 도어맨\n황효은 : 마예순(35세) 역 - 로마네 가사 도우미\n윤종화 : 유병훈(29세) 역 - 루비의 남자친구 → 남편, 대학병원 의사\n이서빈 : 황우빈(30세) 역 - 영국의 친구, 연예인\n정이연 : 명선미 역 - 서끝순의 간호사이자 보디가드\n원종례 : 병훈 모 역 - 병훈의 어머니\n설운도 : 설황도 역 - 모창가수, 사장의 연인\n서동수 : 김손광 역 - 드라마 PD, 진상\n김지혜 : 옥동자(18세) 역 - 끝순의 친구\n홍석천 : 홍사현 역 - 비취가 집필하는 '늙은 아씨들' PD\n박대원 : 이진욱 역\n정세형 : 황 과장 역 - 서로마의 운전기사\n차성훈 : 박 기사 역\n서수남 : 미인대회 진행자 역\n김광규 : 성형외과 의사 역 (특별출연)\n오미희 : 정애 역 (특별출연) - 카일의 어머니, 재력가의 세련된 안주인\n김희라 : 사장네 가사 도우미\n양영준 : 박사월(74) 노래방 사장 결명자의 재혼남 역\n\n\n== 시청률 ==\n최저 시청률과 최고 시청률은 시청률 조사회사와 지역별로 시청률에 차이가 있을 수 있습니다.\n\n\n== 수상 ==\n2009년 MBC 연기대상 미니시리즈 여자 우수상 강세정\n2009년 MBC 연기대상 연속극 부문 황금 연기상 김영옥, 정혜선\n\n\n== 경쟁 프로그램 ==\n스타일 (SBS)\n그대, 웃어요 (SBS)\n천추태후 (KBS2)\n열혈 장사꾼 (KBS2)\n명가 (KBS1)\n\n\n== 참고 사항 ==\n임성한 작가의 전작 <보고 또 보고>처럼 가제는 <손짓>이었으나, 가족 구성원의 다양한 이야기를 맛있게 비벼낸다는 의미에서 제목을 <보석 비빔밥>으로 바꾸었다.\n이시영은 궁루비 역에 캐스팅되었으나 최종적으로 출연이 무산되었다.\n설운도는 한혜숙의 추천으로 첫 드라마 출연을 하게 되었다.\n2009년 10월 3일 (9회) 방영분에서 루비네 가족들이 서로 언쟁을 벌인 끝에 자식들이 부모에게 집에서 나가달라는 장면을 두고 시청자들 사이에서는 논란이 일어났다. 아무리 드라마라고 하지만 힘들게 키워준 부모를 자식 넷이 합세하여 집에서 쫓아냈다는 것은 예의와 윤리도덕상 벗어나는 행동이며, 공교스럽게도 추석 당일에 이런 장면이 방송된 것에 대한 유감을 표시하기도 했다. 드라마 홈페이지에서는 시청자들의 비판과 항의가 잇따라 빗발쳤으며 일각에서는 '고려장 드라마', '패륜 및 불효조장 드라마', '늙은 부모님들을 조롱한 드라마'라며 비꼬기도 했으며 '갈수록 막장으로 갔다'라는 비판도 이어졌다. 더군더나 궁상식 부부가 밖을 떠돌다가 각자 시댁 어머니와 친정 어머니 집을 왕래하는 장면 또한 문제로 제기되었다.\n2019년 개국한 MBC ON에서 재방송되었으며 MBC는 해당 드라마에 앞서 《그대, 웃어요》를 편성할 예정이었으나 해당 드라마 때문에 무산되자 SBS에서 간신히 편성됐다.\n\n\n== 각주 ==\n\n\n== 외부 링크 ==\niMBC 보석 비빔밥 홈페이지",
#    'title': '보석비빔밥',
#    'url': 'https://ko.wikipedia.org/wiki/%EB%B3%B4%EC%84%9D%EB%B9%84%EB%B9%94%EB%B0%A5'},
#   {'content': '전주비빔밥(全州－)은 전북특별자치도 전주의 향토 음식이다. 밥 뜸을 들일 때 밥솥에 콩나물을 넣어 밥 김으로 데쳐 솥 안에서 밥과 뒤섞은 다음, 김, 황포묵, 쑥갓 등을 곁들여 낸다.\n\n\n== 같이 보기 ==\n전라도의 음식 목록\n진주비빔밥\n\n\n== 각주 ==',
#    'title': '전주비빔밥',
#    'url': 'https://ko.wikipedia.org/wiki/%EC%A0%84%EC%A3%BC%EB%B9%84%EB%B9%94%EB%B0%A5'},
#   {'content': '경상남도(慶尙南道)는 대한민국 남동부에 있는 도이다. 남쪽으로는 남해, 동쪽으로는 부산광역시· 울산광역시, 서쪽으로는 전남광주통합특별시·전북특별자치도와 경계를 이루고, 북쪽으로는 대구광역시·경상북도와 접한다. 행정구역은 8시 10군이며, 대한민국의 행정 구역 중 관할 면적이 네 번째로 넓다.\n경상남도청 소재지는 창원시 의창구이다.\n\n\n== 역사 ==\n선사 시대부터 사람이 거주하던 지역으로 낙동강을 비롯한 큰 강과 평야를 바탕으로 농경문화를 발달시켰으며, 발달한 철기문화를 바탕으로 고대 가야 문화를 꽃피웠다. 1896년(고종 33년)에 지방제도 관제 등을 개정하는 과정에서 경상도를 남북으로 나누어 지금의 경상남도가 되었다.\n1963년 1월 1일 부산시는 부산직할시로 승격되어 경상남도에서 완전히 분리되었으며, 1995년 양산군 일부가 기장군으로 분리되어 부산광역시에 편입되었다. 울산시는 1997년 7월 15일 울산광역시로 승격되어 경상남도에서 완전히 분리되었다.\n\n\n==== 대한제국 ====\n1896년 8월 4일 종전의 진주부 일원과 동래부 동래군, 양산군, 기장군, 울산군, 언양군, 거제군, 대구부 밀양군, 창녕군, 영산군을 합쳐 1부(동래부) 29군을 관할하는 경상남도가 설치되고, 수부(首府)를 진주에 두었다.\n1899년 5월 6일 마산포가 개항장이 되면서 창원군을 창원부로 개편하였다.(2부 28군)\n1900년 5월 16일 고성군의 옛 삼도수군통제영에 진남군이 설치되었다.(2부 29군)\n1903년 7월 3일 동래부, 창원부가 다시 동래군, 창원군이 되었다.(31군)\n1906년 10월 1일 동래군, 창원군이 다시 동래부, 창원부가 되었다.(2부 29군)\n1908년 9월 14일 진해군과 웅천군을 창원부에, 칠원군을 함안군에 합병하였다.(2부 26군)\n1909년 3월 13일 진남군을 용남군으로 개칭하였다.\n\n\n==== 일제강점기 ====\n\n1910년 10월 1일 동래부를 부산부로, 창원부를 마산부로 개칭하였다.\n1914년 3월 1일 아래 표와 같이 부·군을 통폐합하였다.\n\n1925년 4월 1일 도청을 부산부로 이전하였다.\n1933년 4월 1일 도제(道制)가 시행됨에 따라 법인격이 부여된 지방자치단체가 되었다.\n1939년 10월 1일 진주군 진주읍이 진주부가 되고, 진주군은 진양군으로 개칭하였다.\n\n\n==== 대한민국 ====\n1949년 8월 15일 부산부를 부산시로, 마산부를 마산시로, 진주부를 진주시로 개칭하였다.\n1953년 1월 1일 거제군이 다시 설치되었다.\n1955년 9월 1일 창원군 진해읍이 진해시가, 통영군 통영읍이 충무시가 되었다.\n1956년 7월 8일 사천군 삼천포읍, 남양면이 합병하여 삼천포시가 되었다.\n1962년 6월 1일 울산군 울산읍, 방어진읍, 하상면, 대현면을 관할로 울산시가 설치되고, 울산군은 울주군으로 개칭하였다.\n1963년 1월 1일 부산시가 정부 직할이 되어 경상남도의 관할 구역에서 제외되었다.\n1973년 7월 1일 동래군이 폐지되어 양산군에 병합되었다.\n1976년 9월 1일 마산시 일부에 경상남도직할 창원지구출장소가 설치되었다.\n1980년 4월 1일 경상남도직할 창원지구출장소를 관할로 창원시가 설치되고, 창원군을 의창군으로 개칭하였다.\n1981년 7월 1일 김해군 김해읍을 관할로 김해시가 설치되었다.\n1983년 7월 1일 도청을 창원시로 이전하였다.\n1989년 1월 1일 거제군 장승포읍을 관할로 장승포시가, 밀양군 밀양읍을 관할로 밀양시가 설치되었다.\n1991년 1월 1일 의창군을 창원군으로, 울주군을 울산군으로 개칭하였다.\n1995년 1월 1일 창원군이 폐지되어 마산시와 창원시에 분할 편입되고, 진주시와 진양군, 충무시와 통영군, 울산시와 울산군, 밀양시와 밀양군, 장승포시와 거제군이 각각 폐지되고, 도농복합형태의 진주시, 통영시, 울산시, 밀양시, 거제시가 설치되었다.\n1995년 3월 1일 양산군 중 옛 동래군(기장군) 지역이 부산광역시에 편입되어 기장군이 설치되었다.\n1995년 5월 10일 삼천포시, 사천군, 김해군이 각각 폐지되고, 도농복합형태의 사천시, 김해시가 설치되었다.\n1996년 3월 1일 양산군이 폐지되고, 도농복합형태의 양산시가 설치되었다.\n1997년 7월 15일 울산시가 폐지되고, 해당 관할구역은 신설 울산광역시 중구, 남구, 동구, 북구, 울주군에 분할 편입되었다.\n2010년 7월 1일 창원시, 마산시, 진해시가 통합되었다. 통합시 명칭은 창원시가 되었다.\n\n\n== 지리 ==\n경남의 현재 면적은 10,531.1 km2이다. 이는 대한민국 전체 면적 99,600.87 km2의 약 10.6%를 차지하며, 17개 시도 가운데 경상북도, 강원특별자치도, 전라남도에 이어 4번째이다. 또한 섬이 많은 도로서 거제도와 남해군을 비롯한 480여 개의 섬이 전체 면적의 약 1.2%를 차지한다.\n경남의 경도와 위도상 위치는 북위 34도 29분에서 35도 54분, 동경 127도 34분에서 129도 13분이다. 위도상 유사한 지역은 일본의 교토와, 지중해 키프로스, 미국의 오클라호마 등이다.\n경남은 한반도의 동남단에 위치하여 동쪽으로는 부산광역시, 울산광역시, 남쪽으로는 남해와 접해있으며, 북쪽으로는 대구광역시 달성군, 경상북도 청도군, 고령군, 성주군, 김천시와 접경하고 있다. 서쪽으로는 소백산맥을 경계로 전북특별자치도 무주군, 장수군, 남원시, 전라남도 구례군, 광양시와 접해 있다.\n\n백두대간 끝자락에는 대한민국 본토에서는 가장 높은 해발 1,915m의 지리산이 위치하고 있다. 1967년 12월 29일 대한민국 최초의 국립공원으로 지정되었으며, 천왕봉을 주봉으로 수많은 봉우리가 있다. 덕유산은 전북특별자치도 무주군·장수군과 경상남도 거창군 ·함양군에 걸쳐 있는 높이 1,614m의 산이다. 1975년 2월 1일 국립공원으로 지정되었다. 그 외에도 소백산맥을 따라 백운산(1,279m) 등이 있으며, 동부 산악 지대는 태백산맥의 여맥 잔가지인 천황산(1,189m), 신불산(1,209m) 등 산악들이 발달해 있다.\n중앙 저지대는 낙동강 강변 지대로 낙동강은 본도에 들어와서 각 지류를 합하여 남해로 유입하는데 하류의 김해 지방에서 삼각주 평야를 이루었다. 남해안은 소백산맥의 남쪽 말단부가 침몰하여 수심이 깊고 출입이 심한 만입과 크고 작은 섬이 산재하는 다도해를 이룬다. 특히 통영을 중심으로 하는 한려수도 일대는 충무공의 전승지와 아울러 관광지로서 한려해상국립공원으로 되어 있다.\n\n\n=== 기후 ===\n한반도의 동남단에 위치하여 저위도이고, 남쪽에는 바다에 접하여 바다의 영향이 크며 북서쪽에는 높은 산맥이 가로 놓여 있어 겨울의 찬 서북풍을 막음으로써 기후는 대한민국 전체를 통하여 온화한 편이다. 경남 내륙지방의 연평균 기온은 12~13°C, 강수량은 1,200~1,500mm이며 1월과 8월의 평균기온은 각각 -0.5, 25.1°C이다. 경남 해안지방의 연평균기온은 14~15°C, 강수량은 1,400~1,800mm이며 평균기온은 각각 2.3, 25.9°C이다.\n\n\n== 정치 ==\n\n\n== 행정 구역 ==\n\n일제강점기에 도청 소재지가 진주에서 부산부(府)로 옮겨진 바 있다. 1983년 경남도청을 부산에서 창원시로 이전하였다. 현재 도청은 창원시 의창구 중앙대로 300에 위치한다.\n\n\n=== 사라진 행정구역 ===\n칠원군\n진해군\n웅천군\n언양군\n영산군\n기장군\n초계군\n삼가군\n곤양군\n안의군\n단성군\n용남군\n울도군\n부산시\n동래군\n삼천포시\n울산시\n울주군\n장승포시\n진양군\n창원군\n의창군\n충무시\n마산시\n회원구\n합포구\n진해시\n김해군\n밀양군\n양산군\n진주부\n추화군\n금관군\n김해부\n창원부\n임관군\n모화군\n울산군\n수산시\n\n\n== 인구 ==\n조선 후기 경상남도 지역은 농업을 기반으로 하는 인구 구조를 지니고 있었으며, 낙동강 유역과 진주, 밀양, 김해 등 전통적인 고을이 중심지로 기능하였다. 일제강점기에는 마산항과 부산항의 개항, 그리고 군수 산업 및 식민지 개발 정책으로 인하여 일부 지역의 인구가 급격히 ...
#    'title': '경상남도',
#    'url': 'https://ko.wikipedia.org/wiki/%EA%B2%BD%EC%83%81%EB%82%A8%EB%8F%84'},
#   {'content': 'The 비빔밥은 매주 수요일 저녁 7시 30분에 전주 KBS 1TV로 방송되는 텔레비전 프로그램이다.\n\n\n== 기획 의도 ==\n전라북도 농촌 희망 프로젝트를 담은 텔레비전 프로그램이다.\n\n\n== 방송 시간 ==\n\n\n== 구성 ==\n청년이장 마을을 부탁해\n나는 이장이다\n\n\n== 외부 링크 ==\nKBS The 비빔밥 홈페이지',
#    'title': 'The 비빔밥',
#    'url': 'https://ko.wikipedia.org/wiki/The_%EB%B9%84%EB%B9%94%EB%B0%A5'}]}

# %%
class WikiSearchParameter(BaseModel):
    query: str = Field(..., description="한국어 위키피디어에서 조회할 검색 keyword")
    max_result: int|None = Field(default=3, description=" 검색할 문서의 최대 개수")

wikipedia_search_tool = wikipedia_search.as_tool(
    name="search_wikipedia_korea",
    description="""이 도구는 힌국위키백과사전에서 정보를 검색""",
    args_schema=WikiSearchParameter
)

# %%
wikipedia_search_tool.name
# Out:
# 'search_wikipedia_korea'

# %%
tool_model = ChatOpenAI(model="gpt-5.4-mini").bind_tools([wikipedia_search_tool])
res = tool_model.invoke("사마귀의 종류")

# %%
res.content
res.tool_calls
# Out:
# [{'name': 'search_wikipedia_korea',
#   'args': {'query': '사마귀 종류', 'max_result': 5},
#   'id': 'call_JEschtrkvHNLQAQVhnZCGGUU',
#   'type': 'tool_call'}]

# %%
wikipedia_search_tool.invoke(res.tool_calls[0])
# Out:
# ToolMessage(content='{"result": [{"content": "사마귀목은 신시하강에 속하는 곤충 목의 하나이다. 바퀴목, 흰개미와 함께 망시류에 포함된다. 한때 바퀴목(Dictyoptera)의 한 아목으로 취급되었다. 육식 곤충 2,400여 종을 포함하고 있다. 앞다리는 먹잇감을 도망가지 못하도록 붙잡기에 알맞도록 낫 모양으로 가시가 많다. 보통 곤충을 잡아먹지만, 동족을 잡아먹기도 하고 심지어 작은 개구리나 도마뱀, 새까지 잡아먹는다. 논에 메뚜기같은 해충을 제거하려고 농약대신 친환경적으로 논에 넣기도 한다.\\n\\n\\n== 생태 ==\\n\\n사마귀는 번데기 과정을 거치지 않고 어른벌레가 되는 불완전 변태를 한다. 먹이는 살아있는 거미와 곤충들인데, 곤충학자 앙리 파브르의 《곤충기》에 따르면 사마귀는 먹이의 종류의 구애없이 사냥하며, 목 부위를 먼저 물어뜯어 신경을 마비시킨 뒤 산 채로 잡아먹는다고 한다. 그러나 대부분은 부위를 상관하지 않고 씹어먹는다. 사마귀는 사냥을 위해 거리를 재기 위한 3차원적 거리 재기 능력 또한 가지고 있어 곤충 중 최초로 3D안경을 쓰고 시각을 측정하는 연구도 이루어졌는데, 사마귀 또한 3D화면을 인식할 수 있다고 한다. 사냥의 속도와 정확도를 최적화하는 방식으로 진화해 왔는데 사냥의 성공률을 높이기 위해 먹이가 회피를 시도할 경우 앞다리를 뻗는 방향을 어느정도 조절할 수 있다.\\n가을에 짝짓기를 마친 암컷은 짝짓기 한 수컷까지 잡아먹을 정도로 활발한 먹이사냥으로 산란에 필요한 영양을 보충한 뒤, 알을 낳는다. 사마귀는 알의 상태에서 겨울을 나기 때문에, 거품으로 알주머니를 만들어서 알을 보호한다. 알주머니 안에는 공기가 들어가서 추운 겨울에도 살아남을 수 있다. 봄이 되면 애벌레가 부화하는데, 개미, 도마뱀, 도롱뇽, 거미, 여치 등의 사마귀 애벌레 사냥으로 수가 조절된다. 애벌레 사마귀는 번데기 과정 없이 성장하는 불완전변태로 어른벌레가 되며, 유충과 성충 모두 육식성이다.\\n사마귀 암컷은 교미 후 수컷을 무조건 잡아먹는 것으로 악명 높은데, 이는 산란기로 말미암아 예민한 상태로 알을 키우기 위한 충분한 영양섭취를 위해 눈앞에 닥치는 대로 잡아먹는 것으로 추정된다. 하지만 모든 수컷 사마귀는 아니고 간혹 조심성 없는 수컷 사마귀가 잡아먹히는 것이며 게다가 매번 그런 것도 아니다. 수컷 사마귀는 목숨을 걸고 조심스럽게 암컷에게 접근하지 않으면 교미를 채 하기도 전에 잡아먹힐 수 있다. 짝짓기가 끝이 나면 수컷도 얼마 지나지 않아 죽는다. 시기적으로 일찍 성체가 된 암컷 사마귀가 첫번째 교미할 경우 수컷 사마귀가 잡아먹힐 확률이 크고 두번째 이후부터는 수컷이 먹힐 확률이 감소하며, 늦게 성충이 된 암컷 사마귀들은 반대로 첫번째 교미일 때 수컷 사마귀를 잡아먹을 확률이 낮고 두번째 이후부터는 포식할 확률이 높다고 한다. 계절적으로 수컷 사마귀들의 개체수가 감소하는 시기에 교미하는 경우가 많아 불필요하게 수컷을 포식하는 것을 막기 위함이라고 한다.\\n또한 다른 곤충을 잡아먹는 육식성 곤충인 만큼 연가시의 기생률이 상당히 높은데, 사마귀에 기생하는 연가시 기생률을 알아보기 위해 2년간 49지역에서 사마귀를 채집해본결과 총 21곳(42.9%)에서 연가시에 감염된 사마귀가 발견됐다고 한다.\\n\\n\\n=== 방어와 위장 ===\\n\\n일반적으로, 사마귀는 숨어서 방어한다. 위협을 할 때에는 높게 서고 날개를 크게 펼치면서 앞다리를 치켜세운다. 날개를 크게 펼치고 앞다리를 치켜듬으로써, 사마귀는 자신의 몸집이 더 커 보이고 무서워 보이게 한다. 몇몇 사마귀들은 날개가 밝은 색이고, 날개에 모양이 있어서 효과가 더 큰 경우도 있다.\\n\\n\\n== 천적 ==\\n사마귀의 대표적인 천적으로는 성충의 몸안에 기생하는 유선형동물(연가시)이 있다. 연가시류 동물은 잠자리나 여치 등의 먹이 곤충의 몸속에서 기생하고 있다가, 사마귀가 곤충을 잡아먹으면 그때 살 곳을 사마귀의 몸속으로 옮기는 것이다. 그렇게 사마귀에게 기생한 연가시는 사마귀 뱃속에서 양분을 빼앗으며 산다.\\n사마귀 몸 속에 기생하는 기생벌과 기생파리 따위의 곤충들도 천적이다. 그 외 사마귀 약충을 잡아먹는 포식성 여치와 개미와 깡충거미, 알집에 기생하는 사마귀꼬리좀벌과 사마귀수시렁이도 천적이다. 또한 애벌레의 먹이를 마련하기 위해 곤충을 사냥하는 검정말벌, 장수말벌 등의 말벌류나 개구리, 두꺼비 같은 양서류, 도마뱀, 카멜레온 같은 파충류, 참새, 까치, 때까치, 매 등 곤충을 잡아먹는 조류들도 천적이다.\\n\\n\\n== 인간과의 관계 ==\\n사마귀의 알집은 상표초(桑螵蛸), 상표소(桑螵蛸) 라 하여 한의학에서 약재로 사용하였다.\\n\\n\\n== 하위 분류 ==\\n다음은 사마귀목 과의 분지도를 나타낸 것이다.\\n\\n\\n=== 한국의 사마귀 ===\\n한국의 사마귀는 모두 3과 9종이 알려져 있다.\\n\\n사마귀과 (Mantidae)\\n사마귀아과 Mantinae\\n왕사마귀 (Tenodera sinensis Saussure 1871)\\n사마귀 (Tenodera angustipennis Saussure 1869)\\n좀사마귀 (Statilia maculata Thunberg 1784)\\n민무늬좀사마귀 (Statilia nemoralis Saussure 1870)\\n항라사마귀 (Mantis religiosa sinica Bazyluk 1960)\\n넓적배사마귀 (Hierodula patellifera Audinet-Serville 1839)\\n붉은긴가슴넓적배사마귀 (Hierodula chinensis Werner, 1929)\\nGonypetidae\\nIridopteryginae\\n좁쌀사마귀 (Amantis nawai Shiraki 1908)\\n애기사마귀과 (Hymenopodidae)\\n애기사마귀아과 Acromantinae\\n애기사마귀 (Acromantis japonica Westwood 1889)\\n\\n\\n== 계통 분류 ==\\n다음은 2002년 \\"생명의 나무 프로젝트\\"(The Tree of Life Web Project)에 제안된 계통 분류이다.\\n\\n\\n== 각주 ==\\n\\n\\n== 외부 링크 ==\\n\\n사마귀의 생태에 대한 오마이뉴스 권용숙 기자의 기사\\nMantis Study Group Information on mantids, scientific articles and rearing guide\\nDo female mantises really eat their mates? 보관됨 2007-01-28 - 웨이백 머신\\nThe Legal Myths Surrounding the Praying Mantis\\nPraying mantis photos, information and care.\\nMantis phylogenetics and Evolution.", "title": "사마귀목", "url": "https://ko.wikipedia.org/wiki/%EC%82%AC%EB%A7%88%EA%B7%80%EB%AA%A9"}, {"content": "포유류, 무척추동물 및 대부분의 물고기에서 항문(肛門, 문화어: 홍문, anus)은 소화관(창자)의 출구 끝, 즉 입의 반대편에 위치한 외부 몸 구멍이다. 항문의 기능은 소화 후 남은 노폐물의 배출을 돕는 것이다.\\n항문을 통해 배출되는 창자 내용물에는 기체인 방귀와 반고체 상태의 똥이 포함되는데, 똥은 (동물의 종류에 따라) 다음과 같은 것들을 포함한다: 뼈, 모발 펠릿, 동물 내 산포된 씨 및 소화 바위와 같은 소화 불가능한 물질; 셀룰로스나 리그닌처럼 소화 가능한 영양소가 추출된 후 남은 잔여 음식 물질; 소화관에 남아 있으면 유독할 물질; 배설된 대사물질인 빌리루빈 함유 쓸개즙; 그리고 죽은 점막 상피 또는 과도한 장내세균 및 다른 내공생체이다. 항문을 통한 똥의 통과는 일반적으로 근육 괄약근에 의해 조절되며, 원치 않는 통과를 막지 못하면 변실금이 발생한다.\\n양서류, 파충류 및 새는 액체 및 고체 노폐물을 배설하고, 교미 및 산란을 위해 유사한 구멍(총배설강으로 알려짐)을 사용한다. 단 ...

# %% [markdown]
# ## Vector Store(Vector 저장소)를 tool로 생성
#
# 1.  `langchain_core.tools.create_retriever_tool` 함수 이용
#     - 이미 만든 retriever를 Agent가 호출할 수 있는 Tool로 변환하는 함수
#     - **주요 파라미터**
#         - `retriever`: vectorstore.as_retriever() 등으로 만든 Retriever
#         - `name`: Agent가 사용할 Tool 이름
#         - `description`: Agent가 언제 이 Tool을 써야 하는지 판단하는 설명
#         - `document_prompt`:
#           - 검색된 각 문서를 어떤 형식으로 문자열화할지 지정. 개별 검색결과를 지정한 PromptTemplate에 맞춰 프롬프트를 만든다.
#           - PromptTemplate의 변수는 Document의 metadata의 key 값들을 사용하여, 그 값(value)이 입력되도록 한다.
#         - `document_separator`: 검색결과가 여러개일 경우 그 결과를 하나의 문자열로 묶어서 반환한다. 합칠때 사용할 구분자를 지정한다. 기본값은 `\n\n` 이다.
#         - `response_format`: Tool 응답을 content:str만 줄지("content"), 원본 Document까지 artifact ("content_and_artiface")로 줄지 지정
#
# 2. `@tool` 을 이용해 직접 구현
#    - query를 입력받아 retriever를 이용해 조회하여 그 결과를 반환하는 tool을 직접 구현한다.
#    - create_retriever_tool() 함수는 빠르고 쉽게 구현할 수 있지만 유연성이 떨어진다. 그래서 전/후 처리등을 직접 제어해야 할 경우 @tool을 이용해 구현한다.
#
# 3. Retriever도 Runnable이므로 `as_tool()` 메소드를 이용해 변환할 수 있다.

# %% [markdown]
# ### text loading -> Document 생성
# - 레스토랑 메뉴를 vector store에 저장한다.
# 1. 메뉴 text 를 로딩한다.
# 2. 각 메뉴의 내용(음식이름, 메뉴설명, 파일명)을 넣어 Document를 생성한다.

# %%
# 문서 Load
import os
# 메뉴읽어 오기
menu_file_path = "data/restaurant_menu.txt"
with open(menu_file_path, "r", encoding="utf-8") as f:
    menu = f.read()

# %%
menu
# Out:
# '1. 라따뚜이\n   - 가격: 17,000원\n   - 주요 재료: 가지, 호박, 파프리카, 토마토 소스, 올리브 오일\n   - 메뉴 설명: 프랑스 남부를 대표하는 전통 요리로, 신선한 채소를 얇게 썰어 층층이 쌓아 올리고 허브와 토마토 소스를 더해 구워냅니다. 채소 본연의 단맛과 상큼한 소스가 조화를 이룹니다. 비건 고객도 즐길 수 있는 건강한 메뉴입니다. 따뜻한 바게트와 함께 제공됩니다.\n\n2. 카르보나라\n   - 가격: 20,000원\n   - 주요 재료: 스파게티 면, 판체타, 달걀 노른자, 파르미지아노 치즈\n   - 메뉴 설명: 이탈리아 전통 방식으로 만든 크리미한 파스타입니다. 판체타의 풍미와 달걀 노른자가 어우러져 고소하고 깊은 맛을 자랑합니다. 신선한 파르미지아노 치즈가 풍미를 더하며, 후추를 뿌려 맛을 완성합니다.\n\n3. 부르기뇽 스튜\n   - 가격: 28,000원\n   - 주요 재료: 쇠고기, 적포도주, 양파, 당근, 베이컨\n   - 메뉴 설명: 프랑스 부르고뉴 지방에서 유래된 스튜 요리로, 고기를 적포도주와 함께 오랜 시간 푹 끓여 부드럽고 진한 풍미를 자랑합니다. 신선한 허브와 채소가 맛을 풍부하게 하고, 바게트와 함께 제공됩니다.\n\n4. 니스 샐러드\n   - 가격: 18,000원\n   - 주요 재료: 참치, 방울토마토, 올리브, 삶은 달걀, 그린빈\n   - 메뉴 설명: 프랑스 니스 지방의 상큼한 샐러드로, 다양한 채소와 참치를 사용해 풍성한 맛과 식감을 제공합니다. 발사믹 비네거 드레싱이 가미되어 가볍게 즐기기 좋은 요리입니다. 신선함과 영양을 동시에 잡은 메뉴입니다.\n\n5. 프렌치 어니언 수프\n   - 가격: 12,000원\n   - 주요 재료: 양파, 비프 스톡, 화이트 와인, 그뤼에르 치즈\n   - 메뉴 설명: 달콤하게 캐러멜라이즈된 양파와 진한 비프 스톡으로 만든 프랑스 전통 수프입니다. 바삭한 바게트 위에 그뤼에르 치즈를 녹여 깊은 풍미를 더했습니다. 추운 날씨에 특히 잘 어울리는 따뜻한 메뉴입니다.\n\n6. 트러플 피자\n   - 가격: 26,000원\n   - 주요 재료: 트러플 오일, 모짜렐라 치즈, 얇은 피자 도우, 루꼴라\n   - 메뉴 설명: 얇고 바삭한 도우 위에 고급 트러플 오일과 모짜렐라 치즈를 얹어 구워낸 피자입니다. 루꼴라를 더해 신선하고 고소한 맛이 특징입니다. 고급스러운 한 끼를 즐기기에 완벽한 선택입니다.\n\n7. 밀라노풍 송아지 커틀렛\n   - 가격: 30,000원\n   - 주요 재료: 송아지 고기, 빵가루, 파르미지아노 치즈, 루꼴라 샐러드\n   - 메뉴 설명: 얇게 저민 송아지 고기를 바삭하게 튀겨 낸 이탈리아 전통 요리입니다. 레몬을 곁들여 고기의 풍미를 돋우며, 상큼한 루꼴라 샐러드가 함께 제공됩니다. 바삭한 식감과 부드러운 고기의 조화가 일품입니다.\n\n8. 프로방스 치킨\n   - 가격: 22,000원\n   - 주요 재료: 닭고기, 타임, 로즈마리, 올리브, 토마토\n   - 메뉴 설명: 프랑스 프로방스 지방의 허브와 토마토 소스로 조리한 닭고기 요리입니다. 부드럽고 촉촉한 닭고기와 향긋한 허브가 입맛을 돋웁니다. 라이스나 바게트와 함께 즐기기 좋습니다.\n\n9. 해산물 링귀니\n   - 가격: 24,000원\n   - 주요 재료: 링귀니 면, 홍합, 새우, 오징어, 화이트 와인\n   - 메뉴 설명: 신선한 해산물과 화이트 와인을 곁들여 만든 이탈리아 대표 파스타입니다. 면과 해산물이 풍부하게 어우러져 깊고 풍성한 맛을 자랑합니다. 바다의 풍미를 그대로 담은 특별한 메뉴입니다.\n\n10. 토마토 브루스케타\n    - 가격: 12,000원\n    - 주요 재료: 토마토, 바질, 올리브 오일, 바게트\n    - 메뉴 설명: 바삭하게 구운 바게트 위에 신선한 토마토와 바질을 얹고 올리브 오일로 마무리한 간단한 요리입니다. 입맛을 돋우는 상큼한 맛이 특징입니다. 가벼운 전채로 적합합니다.\n\n11. 크림 스피나치 라자냐\n    - 가격: 23,000원\n    - 주요 재료: 라자냐 면, 크림 소스, 시금치, 리코타 치즈\n    - 메뉴 설명: 부드럽고 크리미한 소스와 신선한 시금치가 조화를 이루는 라자냐입니다. 리코타 치즈를 풍부하게 사용해 깊은 맛을 더했습니다. 따뜻하고 풍성한 한 끼로 제격입니다.\n\n12. 바질 페스토 뇨끼\n    - 가격: 19,000원\n    - 주요 재료: 감자 뇨끼, 바질 페스토, 파르미지아노 치즈\n    - 메뉴 설명: 부드럽고 쫀득한 감자 뇨끼에 향긋한 바질 페스토를 곁들인 이탈리아 대표 요리입니다. 신선한 치즈와 허브가 요리의 맛을 풍부하게 만듭니다. 가벼운 식사로 적합합니다.\n\n13. 티라미수\n    - 가격: 10,000원\n    - 주요 재료: 마스카르포네 치즈, 에스프레소, 코코아 파우더, 사보이아르디\n    - 메뉴 설명: 이탈리아를 대표하는 디저트로, 부드러운 마스카르포네 치즈 크림과 촉촉한 에스프레소 시트가 어우러집니다. 코코아 파우더가 위에 뿌려져 달콤쌉쌀한 맛이 특징입니다. 커피와 함께 즐기기에 완벽한 디저트입니다.\n\n14. 크렘 브륄레\n    - 가격: 11,000원\n    - 주요 재료: 크림, 설탕, 바닐라 빈, 달걀 노른자\n    - 메뉴 설명: 부드러운 크림 베이스 위에 바삭한 캐러멜 층이 올라간 프랑스 디저트입니다. 숟가락으로 캐러멜을 부수며 즐기는 식감이 매력적입니다. 부드럽고 달콤한 맛이 입안을 가득 채웁니다.\n\n15. 레몬 타르트\n    - 가격: 9,000원\n    - 주요 재료: 레몬 커드, 타르트 크러스트, 슈거 파우더\n    - 메뉴 설명: 상큼한 레몬 커드와 바삭한 타르트 크러스트가 완벽한 조화를 이루는 디저트입니다. 달콤한 맛과 상큼한 맛이 균형을 이루며, 가볍게 즐기기 좋은 메뉴입니다. 애프터눈 티와 잘 어울립니다.'

# %%
# Split - 메뉴별로 분리하기 위해 직접 처리
from langchain_core.documents import Document
import re
from pprint import pprint

def create_documents(menu_all: str, file_name) -> list[Document]:
    """메뉴별로 분리 한뒤 Document로 변환. 변환된 Document들을 리스트로 반환
    metadata: 메뉴이름, 주요 재료, 가격, source(파일이름)
    """
    menu_list = menu_all.split("\n\n")
    menu_documents = []
    for menu_item in menu_list:

        # 메뉴 이름 추출
        menu_name_pattern = r"(^\d+.\s)([가-힣a-zA-Z\d ]+)" # 정규표현식
        menu_name_result = re.search(menu_name_pattern, menu_item)
        menu_name = menu_name_result.group(2).strip()  # 메뉴 이름 추출 # 1은 번호

        # 주요재료 추출 - text로 indexing.
        menu_ingredient_pattern = r"(?<=주요 재료: ).+" # 긍정후방탐색 
        ingredients = re.search(menu_ingredient_pattern, menu_item).group().strip()
    
        # 가격추출
        price_pattern = r"(?<=가격: )[\d,]+(?=원)" # 전방탐색과 후방탐색 동시 사용
        price_result = re.search(price_pattern, menu_item)
        price = int(price_result.group().replace(",", ""))

        
        # 메뉴 이름을 제외한 나머지는 메뉴 설명으로 간주
        menu_doc = Document(
            page_content=menu_item,     # 메뉴 설명을 page_content에 넣는다. metadata는 나중에 따로 따로 payload filtering 할 수있기 때문에 
            metadata={
                "menu_name": menu_name, # 메뉴 이름
                "price": price,         # 가격
                "ingredients": ingredients, # 재료 리스트
                "source": file_name     # 메뉴가 저장된 파일 이름
            }
        )
        menu_documents.append(menu_doc)
    return menu_documents


menu_documents = create_documents(menu, menu_file_path)
print(len(menu_documents))
# Out:
# 15

# %%
menu_documents[0].metadata
# Out:
# {'menu_name': '라따뚜이',
#  'price': 17000,
#  'ingredients': '가지, 호박, 파프리카, 토마토 소스, 올리브 오일',
#  'source': 'data/restaurant_menu.txt'}

# %%
# VectorDB 저장 및 VectorStore 생성
from langchain_qdrant import QdrantVectorStore
from langchain_openai import OpenAIEmbeddings
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
from dotenv import load_dotenv

load_dotenv()

COLLECTION_NAME = "restaurant_menu"
VECTOR_SIZE = 1536  # OpenAIEmbeddings의 벡터 크기

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

client = QdrantClient(host="localhost", port=6333)
if client.collection_exists(COLLECTION_NAME):
    client.delete_collection(COLLECTION_NAME)

# Collection 생성
client.create_collection(
    collection_name=COLLECTION_NAME,
    # 벡터 저장소에 대한 설정. - vector_config는 default이므로 이름을 안줘도 됨(default 로 잡힘) 이름을 줄 거면 {"이름":VectorParams()} 설정
    vectors_config=VectorParams(
        size=VECTOR_SIZE, 
        distance=Distance.COSINE
    )
)

vectorstore = QdrantVectorStore(
    client=client, # QdrantClient
    embedding=embeddings, # Embedding Model
    collection_name=COLLECTION_NAME # 연결할 Collection 지정.
)
ids = vectorstore.add_documents(menu_documents) # list[Document] -> upsert
print(f"저장된 문서 개수: {len(ids)}")
##################################################
# Retriever 생성
##################################################
menu_retriever = vectorstore.as_retriever(
    search_kwargs={"k": 3}  # 검색할 결과 개수
)

from langchain_core.runnables import ConfigurableField
retriever = menu_retriever.configurable_fields(
    search_type=ConfigurableField(
        id="search_type"
    ),
    search_kwargs=ConfigurableField(
        id="search_kwargs"
    ),
)
# Out:
# 저장된 문서 개수: 15

# %%
query = "이탈리아 음식을 추천해줘"
result = retriever.invoke(query)
for doc in result:
    print(doc.metadata)
# Out:
# {'menu_name': '티라미수', 'price': 10000, 'ingredients': '마스카르포네 치즈, 에스프레소, 코코아 파우더, 사보이아르디', 'source': 'data/restaurant_menu.txt', '_id': '6737b064-3372-4417-98ed-8765a1b94fe8', '_collection_name': 'restaurant_menu'}
# {'menu_name': '밀라노풍 송아지 커틀렛', 'price': 30000, 'ingredients': '송아지 고기, 빵가루, 파르미지아노 치즈, 루꼴라 샐러드', 'source': 'data/restaurant_menu.txt', '_id': '0eff3cad-80c1-4f96-8433-c6701b65feca', '_collection_name': 'restaurant_menu'}
# {'menu_name': '바질 페스토 뇨끼', 'price': 19000, 'ingredients': '감자 뇨끼, 바질 페스토, 파르미지아노 치즈', 'source': 'data/restaurant_menu.txt', '_id': '390b1f15-c54d-4c4e-a886-72d98f3a7b4e', '_collection_name': 'restaurant_menu'}

# %%
# create_retriever_tool()
from langchain_core.tools import create_retriever_tool
from langchain_core.prompts import PromptTemplate

# 내가 원하는 포맷으로 만들려고 할 때 그 template를 PromtTemplate로 작성
return_doc_format = PromptTemplate(
    template="""메뉴이름:{menu_name}
음식재료: {ingredients}
메뉴내용: 
{page_content}"""
)


menu_retriever_tool = create_retriever_tool(
    retriever=retriever,
    description="이 도구는 vectorstore에 저장된 restaurant menu를 검색하는 tool입니다. 음식 메뉴에 대한 정보가 필요할 때 사용합니다.",
    name= "menu_retriever_tool",
    document_prompt=return_doc_format,
)

# %%
print(type(menu_retriever_tool))
print(menu_retriever_tool.name)
menu_retriever_tool.args
# Out:
# <class 'langchain_core.tools.structured.StructuredTool'>
# menu_retriever_tool
# {'query': {'description': 'query to look up in retriever',
#   'title': 'Query',
#   'type': 'string'}}

# %%
query
# Out:
# '이탈리아 음식을 추천해줘'

# %%
res = menu_retriever_tool.invoke(query)
print(res)
# Out:
# 메뉴이름:티라미수
# 음식재료: 마스카르포네 치즈, 에스프레소, 코코아 파우더, 사보이아르디
# 메뉴내용:
# 13. 티라미수
#     - 가격: 10,000원
#     - 주요 재료: 마스카르포네 치즈, 에스프레소, 코코아 파우더, 사보이아르디
#     - 메뉴 설명: 이탈리아를 대표하는 디저트로, 부드러운 마스카르포네 치즈 크림과 촉촉한 에스프레소 시트가 어우러집니다. 코코아 파우더가 위에 뿌려져 달콤쌉쌀한 맛이 특징입니다. 커피와 함께 즐기기에 완벽한 디저트입니다.
#
# 메뉴이름:밀라노풍 송아지 커틀렛
# 음식재료: 송아지 고기, 빵가루, 파르미지아노 치즈, 루꼴라 샐러드
# 메뉴내용:
# 7. 밀라노풍 송아지 커틀렛
#    - 가격: 30,000원
#    - 주요 재료: 송아지 고기, 빵가루, 파르미지아노 치즈, 루꼴라 샐러드
#    - 메뉴 설명: 얇게 저민 송아지 고기를 바삭하게 튀겨 낸 이탈리아 전통 요리입니다. 레몬을 곁들여 고기의 풍미를 돋우며, 상큼한 루꼴라 샐러드가 함께 제공됩니다. 바삭한 식감과 부드러운 고기의 조화가 일품입니다.
#
# 메뉴이름:바질 페스토 뇨끼
# 음식재료: 감자 뇨끼, 바질 페스토, 파르미지아노 치즈
# 메뉴내용:
# 12. 바질 페스토 뇨끼
#     - 가격: 19,000원
#     - 주요 재료: 감자 뇨끼, 바질 페스토, 파르미지아노 치즈
#     - 메뉴 설명: 부드럽고 쫀득한 감자 뇨끼에 향긋한 바질 페스토를 곁들인 이탈리아 대표 요리입니다. 신선한 치즈와 허브가 요리의 맛을 풍부하게 만듭니다. 가벼운 식사로 적합합니다.

# %%
from langchain_openai import ChatOpenAI
tool_model = ChatOpenAI(model="gpt-5.4-mini").bind_tools([menu_retriever_tool])
res = tool_model.invoke("토마토를 재료로 하는 요리를 추천해줘")

# %%
res.content
res.tool_calls
# Out:
# [{'name': 'menu_retriever_tool',
#   'args': {'query': '토마토를 재료로 하는 메뉴 추천'},
#   'id': 'call_zMAzM3TPYDBURuPZzB889Mld',
#   'type': 'tool_call'}]

# %%
menu_retriever_tool.invoke(res.tool_calls[0])
# Out:
# ToolMessage(content='메뉴이름:라따뚜이\n음식재료: 가지, 호박, 파프리카, 토마토 소스, 올리브 오일\n메뉴내용: \n1. 라따뚜이\n   - 가격: 17,000원\n   - 주요 재료: 가지, 호박, 파프리카, 토마토 소스, 올리브 오일\n   - 메뉴 설명: 프랑스 남부를 대표하는 전통 요리로, 신선한 채소를 얇게 썰어 층층이 쌓아 올리고 허브와 토마토 소스를 더해 구워냅니다. 채소 본연의 단맛과 상큼한 소스가 조화를 이룹니다. 비건 고객도 즐길 수 있는 건강한 메뉴입니다. 따뜻한 바게트와 함께 제공됩니다.\n\n메뉴이름:레몬 타르트\n음식재료: 레몬 커드, 타르트 크러스트, 슈거 파우더\n메뉴내용: \n15. 레몬 타르트\n    - 가격: 9,000원\n    - 주요 재료: 레몬 커드, 타르트 크러스트, 슈거 파우더\n    - 메뉴 설명: 상큼한 레몬 커드와 바삭한 타르트 크러스트가 완벽한 조화를 이루는 디저트입니다. 달콤한 맛과 상큼한 맛이 균형을 이루며, 가볍게 즐기기 좋은 메뉴입니다. 애프터눈 티와 잘 어울립니다.\n\n메뉴이름:토마토 브루스케타\n음식재료: 토마토, 바질, 올리브 오일, 바게트\n메뉴내용: \n10. 토마토 브루스케타\n    - 가격: 12,000원\n    - 주요 재료: 토마토, 바질, 올리브 오일, 바게트\n    - 메뉴 설명: 바삭하게 구운 바게트 위에 신선한 토마토와 바질을 얹고 올리브 오일로 마무리한 간단한 요리입니다. 입맛을 돋우는 상큼한 맛이 특징입니다. 가벼운 전채로 적합합니다.', name='menu_retriever_tool', tool_call_id='call_zMAzM3TPYDBURuPZzB889Mld')

# %%
# @tool을 이용해 정의
from pydantic import BaseModel, Field
class SearchMenuParameter(BaseModel):
    query:str = Field(..., description="의미기반 검색으로 메뉴를 찾을 query")
    top_k:int =Field(default=3, description="Vector DB에서 조회할 문서 개수")

@tool(args_schema=SearchMenuParameter)
def search_menu_tool(query:str, top_k:int|None=3) ->str:
    """이 도구는 vectorstore에 저장된 restaurant menu를 검색하는 tool입니다. 음식 메뉴에 대한 정보가 필요할 때 사용합니다."""
    result_list = []
    config = {
        "configuration": {
            "search_kwargs":{
                "k": top_k
            }
        }
    }
    docs = retriever.invoke(query, config=config)
    for doc in docs:
        result_list.append(
            {
                "content":doc.page_content,
                "title":doc.metadata['menu_name'],
                "url":doc.metadata['source']
            }
        )
    if result_list:
        result = {"result": result_list}
    else:
        result = {"result": "검색된 메뉴가 없습니다."}
    return json.dumps(result, ensure_ascii=False)

# %%
search_menu_tool.name
search_menu_tool.description
search_menu_tool.args
# Out:
# {'query': {'description': '의미기반 검색으로 메뉴를 찾을 query',
#   'title': 'Query',
#   'type': 'string'},
#  'top_k': {'default': 3,
#   'description': 'Vector DB에서 조회할 문서 개수',
#   'title': 'Top K',
#   'type': 'integer'}}

# %%
tool_model = ChatOpenAI(model="gpt-5.4-mini").bind_tools(tools=[search_menu_tool])
res = tool_model.invoke("식당 메뉴중에 면요리를 추천해줘")

# %%
res.content
res.tool_calls
# Out:
# [{'name': 'search_menu_tool',
#   'args': {'query': '면요리 추천 메뉴 파스타 국수 라면 우동 짜장면 짬뽕 냉면 비빔국수', 'top_k': 5},
#   'id': 'call_1pr6KhE9cFH2ph8wXv2C7ZmV',
#   'type': 'tool_call'}]

# %%
res = search_menu_tool.invoke(res.tool_calls[0])

# %%
pprint(res.content)
# Out:
# ('{"result": [{"content": "6. 트러플 피자\\n   - 가격: 26,000원\\n   - 주요 재료: 트러플 오일, '
#  '모짜렐라 치즈, 얇은 피자 도우, 루꼴라\\n   - 메뉴 설명: 얇고 바삭한 도우 위에 고급 트러플 오일과 모짜렐라 치즈를 얹어 구워낸 '
#  '피자입니다. 루꼴라를 더해 신선하고 고소한 맛이 특징입니다. 고급스러운 한 끼를 즐기기에 완벽한 선택입니다.", "title": "트러플 '
#  '피자", "url": "data/restaurant_menu.txt"}, {"content": "1. 라따뚜이\\n   - 가격: '
#  '17,000원\\n   - 주요 재료: 가지, 호박, 파프리카, 토마토 소스, 올리브 오일\\n   - 메뉴 설명: 프랑스 남부를 '
#  '대표하는 전통 요리로, 신선한 채소를 얇게 썰어 층층이 쌓아 올리고 허브와 토마토 소스를 더해 구워냅니다. 채소 본연의 단맛과 상큼한 '
#  '소스가 조화를 이룹니다. 비건 고객도 즐길 수 있는 건강한 메뉴입니다. 따뜻한 바게트와 함께 제공됩니다.", "title": '
#  '"라따뚜이", "url": "data/restaurant_menu.txt"}, {"content": "8. 프로방스 치킨\\n   - '
#  '가격: 22,000원\\n   - 주요 재료: 닭고기, 타임, 로즈마리, 올리브, 토마토\\n   - 메뉴 설명: 프랑스 프로방스 지방의 '
#  '허브와 토마토 소스로 조리한 닭고기 요리입니다. 부드럽고 촉촉한 닭고기와 향긋한 허브가 입맛을 돋웁니다. 라이스나 바게트와 함께 즐기기 '
#  '좋습니다.", "title": "프로방스 치킨", "url": "data/restaurant_menu.txt"}]}')

# %% [markdown]
# # create_agent() 를 이용한 Agent 구현
#
# - create_agent()
#   - 랭체인에서 제공하는 표준 에이전트 생성함수로 LLM이 도구를 사용해서 문제를 해결하는 기본구조를 기반으로 설계되었다.
#     - Agent 생성 및 실행을 표준화, 단순화 하기 위헤 Langchain 1.0에서 도입 되었다.
#     - 도구사용 기본 구조에 **middleware**를 이용해 다양한 시점에 다양한 동작이 실행될 수 있는 유연한 구조를 지원한다.
#
#     ![기본구조](figures/langgraph_basic_flow.png)
#   - 0.x 버전까지는 Agent 생성 함수는
#     1. model과 tool들을 넣어 Agent를 생성하고
#     2. 그것을 실행하는 Executor를 생성하는 방식으로
#   - 여러 단계를 거쳐야 했다.
#   - create_agent()는 이러한 단계를 1단계로 축약한 API이다.
#
# - create_agent 설계 철학
#     1. Agent를 구성하는 모든 실행단위는 Runnable 이다.
#     2. Agent도 Runnable 이다.
#     3. Agent는 하나의 표준 팩토리 함수(생성함수)로 통합한다.
#
# ## 주요 파라미터
# - https://reference.langchain.com/python/langchain/agents/
# - `model`
#   - Agent에서 사용할 모델을 지정한다.
#   - 문자열로 모델이름을 넣을 수도 있고 BaseChatModel(ex: ChatOpenAI) 타입의 객체를 전달 할 수도 있다.
# - `tools`
#   -  Agent가 사용할 외부 도구(tool) 목록(list)을 전달한다.
# - `system_prompt`
#   - Agent에 입력하는 시스템 프롬프트. 문자열 또는 `SystemMessage`객체로 입력한다.
#   - 이 prompt는 모델 호출시 가장 먼저 입력되는 것으로 Agent의 행동 지침, 성격을 정의하는 데 사용된다.
# - `middleware`
#   - Agent 실행 흐름에서 특정 지점에서 동작을 가로채서 실행되는 middelware(중간처리기) 목록을 전달한다.
#   - Agent실행 전/후, Model 호출 전/후 등 사전 정의된 hook에 맞춰 정의된 middleware들을 등록한다.
# - `response_format`
#   - Agent 최종 출력 결과 형식을 구조화하는 schema를 설정.
# - `checkpointer`
#   - 에이전트 실행 중 상태를 저장하는 객체, 즉 단기 메모리 저장소을 설정한다.
# - `store`
#   - 지속성 저장소 즉 장기 메모리 저장소를 설정한다.

# %%
system_prompt  = """
당신은 레스토랑 메뉴 정보와 일반적인 음식 관련 지식을 제공하는 AI 어시스턴트입니다. 
주요 목표는 사용자의 요청에 대한 정확한 정보를 제공하고 메뉴를 추천하는 것입니다.

주요 지침들(guidelines):
1. 레스토랑의 메뉴관련 정보를 확인하려면 search_menu_tool 도구를 사용하십시오. 이 도구는 레스토랑의 메뉴들의 가격, 음식의 특징들에 대한 정보를 제공합니다.
2. 사용자 요청한 음식에 menu에 없을 경우에는 tavily_search 도구를 이용해서 음식을 검색해서 추천합니다. 
3. 음식과 관련없는 요청 중에 최신정보가 필요한 경우에도 tavily_search 도구를 사용해서 정보를 검색해서 제공합니다.
4. 일반적인 음식 정보, 음식의 유래, 문화적 배경에 대한 정보는 search_wikipedia_korea 도구를 사용하십시오. 이 도구는 한국 wikipedia 에서 정보를 검색해서 제공합니다.
5. 검색 결과를 기반으로 명확하고 간결한 답변을 제공하십시오.
6. 요청 받은 질문이 모호하거나 필요한 정보가 부족한 경우 정중하게 설명을 요청하세요.
7. 메뉴 정보를 제공할 때는 가격, 주재료, 특징 순으로 설명하세요.
8. 메뉴를 추천 할 때는 간단하게 추천 이유를 설명해주세요.
9. 최종 응답은 챗봇과 같은 대화형 스타일을 유지하세요. 친근하고 매력적이며 자연스럽게 소통하되 전문성을 보이는 어조를 유지하세요.

- 각 도구의 목적과 기능을 정확하게 이해하고 각 적절한 상황에서 사용하세요.
- 각 도구들을 결합해서 사용자의 요청에 정확한 대답을 하세요.
- 항상 가장 최신의 정확한 정보를 제공하기 위해 노력하세요.
"""

# %%
from langchain.agents import create_agent
from langchain_tavily import TavilySearch
from tools import wikipedia_search_tool, search_menu_tool
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# 툴들 정의
tavily_search = TavilySearch(max_results=5)
tools = [wikipedia_search_tool, search_menu_tool, tavily_search]

# 모델 정의
model = ChatOpenAI(model="gpt-5.4-mini")

# 에이전트 생성
agent = create_agent(
    model=model,
    tools=tools,
    system_prompt=system_prompt,
)

# %%
from IPython.display import Image, display
display(Image(
    agent.get_graph().draw_mermaid_png()
))

# %%
res = agent.invoke(
    {
        "messages": [
            ("human", "파스타 메뉴를 추천해줘, 그리고 파스타의 유래에 대해서 설명해줘.")
        ]
    }
)

# %%
res
# Out:
# {'messages': [HumanMessage(content='파스타 메뉴를 추천해줘, 그리고 파스타의 유래에 대해서 설명해줘.', additional_kwargs={}, response_metadata={}, id='75aa1c2a-5f42-43b9-a081-603cf62f0621'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 1815, 'total_tokens': 1882, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1664}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DzDZswOlUVUoEjRxhfpggoviTMXVM', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f3fd8-5d3d-7011-a395-94275e9e7656-0', tool_calls=[{'name': 'search_menu_tool', 'args': {'query': '파스타 메뉴 추천', 'top_k': 5}, 'id': 'call_3CiEDbieLdK74FrVWfggItM2', 'type': 'tool_call'}, {'name': 'search_wikipedia_korea', 'args': {'query': '파스타', 'max_result': 3}, 'id': 'call_troSgHfqAAj2rjXbjUgVAXH7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1815, 'output_tokens': 67, 'total_tokens': 1882, 'input_token_details': {'audio': 0, 'cache_read': 1664}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"result": [{"content": "15. 레몬 타르트\\n    - 가격: 9,000원\\n    - 주요 재료: 레몬 커드, 타르트 크러스트, 슈거 파우더\\n    - 메뉴 설명: 상큼한 레몬 커드와 바삭한 타르트 크러스트가 완벽한 조화를 이루는 디저트입니다. 달콤한 맛과 상큼한 맛이 균형을 이루며, 가볍게 즐기기 좋은 메뉴입니다. 애프터눈 티와 잘 어울립니다.", "title": "레몬 타르트", "url": "data/restaurant_menu.txt"}, {"content": "4. 니스 샐러드\\n   - 가격: 18,000원\\n   - 주요 재료: 참치, 방울토마토, 올리브, 삶은 달걀, 그린빈\\n   - 메뉴 설명: 프랑스 니스 지방의 상큼한 샐러드로, 다양한 채소와 참치를 사용해 풍성한 맛과 식감을 제공합니다. 발사믹 비네거 드레싱이 가미되어 가볍게 즐기기 좋은 요리입니다. 신선함과 영양을 동시에 잡은 메뉴입니다.", "title": "니스 샐러드", "url": "data/restaurant_menu.txt"}, {"content": "6. 트러플 피자\\n   - 가격: 26,000원\\n   - 주요 재료: 트러플 오일, 모짜렐라 치즈, 얇은 피자 도우, 루꼴라\\n   - 메뉴 설명: 얇고 바삭한 도우 위에 고급 트러플 오일과 모짜렐라 치즈를 얹어 구워낸 피자입니다. 루꼴라를 더해 신선하고 고소한 맛이 특징입니다. 고급스러운 한 끼를 즐기기에 완벽한 선택입니다.", "title": "트러플 피자", "url": "data/restaurant_menu.txt"}]}', name='search_menu_tool', id='49d40fe6-36a1-4649-b788-7fafe0b5a5c8', tool_call_id='call_3CiEDbieLdK74FrVWfggItM2'),
#   ToolMessage(content='{"result": "검색된 문서가 없습니다."}', name='search_wikipedia_korea', id='c14f39e2-7630-4164-b145-08f2f532783a', tool_call_id='call_troSgHfqAAj2rjXbjUgVAXH7'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 2352, 'total_tokens': 2390, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1664}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DzDZwgQJRCv2d70JFuFiDUMsp877Q', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f3fd8-6d6c-7ac1-8506-9142db19fa07-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '대표적인 파스타 종류 추천 인기 파스타 메뉴', 'search_depth': 'basic', 'topic': 'general'}, 'id': 'call_RBLD9gmv3RjrGqRKW3m1rmSi', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2352, 'output_tokens': 38, 'total_tokens': 2390, 'input_token_details': {'audio': 0, 'cache_read': 1664}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"query": "대표적인 파스타 종류 추천 인기 파스타 메뉴", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.valuetimes.co.kr/whatsnews?bmode=view&idx=19338431", "title": "한국인들이 가장 좋아하는 파스타는? | 밸류체인타임스", "content": "밀가루 식품, 파이 또는 생지도 파스타라고 불린다. 파스타의 면의 종류는 다양하다. 대표적인 파스타 면의 종류로는 마카로니, 스파게티, 푸실리, 지티", "score": 0.73846215, "raw_content": null}, {"url": "https://alldaynight-sensibility.tistory.com/4", "title": "파스타 종류, 한번에 정리해서 보기", "content": "- 소설 리뷰「불면의 밤」 (0). ### 파스타 종류, 한번에 정리해서 보기. 식전빵과 올리브오일, 스프, 샐러드, 파스타, 스테이크, 디저트 순서로 내는데, 파스타는 개인마다 취향 차이가 있다보니 (파스타 종류나 마더 소스 등) 어떤 소스와 어떤 파스타를 먹고 싶은지 물어본다. 그때마다 나는 조금 더 자세하게 설명해주고는 하는데, 오늘은 가장 기본적인 파스타 면부터 얘기해보도록 하자. 우리가 흔히들 ‘파스타!’ 라고 외치면 생각하는 면은 이 1.8~2.0mm의 두께를 가지고 있는 ‘스파게티’다. 뭐 어느 정도는 이해할 수밖에 없는 게, 국내에서 지금도 가장 많이 팔리고 있는 면일뿐더러, 오뚜기와 백설에서도 이 면을 자체적으로 생산한 뒤 마트에 내는 중이다. 하지만 엄연히 스파게티는 ‘파스타’라는 거대한 집합의 한 부분을 차지할 뿐이지, 이 둘이 동일선상에 놓여질 수 없다는 것을 명심하자. 씹는 식감이 좋고 면이 스파게티보다 넓은 편이기에 조개 외에 부재료가 많이 들어가지 않는 봉골레에 잘 쓰인다. #### 막 쓰기 좋은 파스타. 내게는 ‘펜네’만큼 막 쓰기 좋은 파스타가 없다. 잘생긴 셰프+잘 만들어진 토마토 소스+처음보는 신선한 파스타=국룰 (그날 하루종일 행복했지 아마). :   과니, 링귀니, 면, 바로알기, 스파게티, 양식, 요리, 종류, 파스타, 페투치네.", "score": 0.72254705, "raw_content": null}, {"url": "https://m.blog.naver.com/goforsweet/222047937334", "title": "파스타종류(누들) 16종 모음/집에서 해먹은 다양한 파스타 요리", "content": "1)Rigatoni 리가토니 · 2)Fusilli 푸실리 · 3)Rotini 로티니 · 4)Spaghetti 스파게티 · 5)Tagliatelle 탈리아텔레 · 6)Fettuccini 페투치니 · 7)Linguine 링귀니.", "score": 0.6768127, "raw_content": null}, {"url": "https://ricky-blog.tistory.com/6", "title": "꼭 먹어봐야 할 파스타 종류 별 레시피", "content": "## 꼭 먹어봐야 할 파스타 종류 별 레시피. * **재료**\xa0: 스파게티 면 200g, 다진 쇠고기 150g, 양파 1개, 토마토 소스 400g, 마늘, 올리브유, 소금, 후추. 2. 팬에 올리브유를 두르고 다진 양파와 마늘을 볶습니다. 4. 삶은 면과 함께 잘 섞은 후 소금과 후추로 간을 맞추어 서빙합니다. 1. 페투치니 면을 끓는 물에 8-10분 삶습니다. * **재료**\xa0: 라자냐 면 9장, 다진 쇠고기 200g, 토마토 소스 400g, 리코타 치즈 250g, 모짜렐라 치즈 200g, 양파, 마늘, 올리브유, 소금, 후추. * **재료**\xa0: 펜네 면 200g, 다진 토마토 400g, 마늘 2쪽, 올리브유, 소금, 후추, 고추. 4. 삶은 면을 넣고 가볍게 섞은 후 소금과 후추로 간을 맞춥니다. * **재료**\xa0: 파스타 면 200g, 생크림 200ml, 베이컨 100g, 양파, 마늘, 파르메산 치즈, 소금, 후추. * **재료**\xa0: 파스타 면 200g, 토마토 2개, 바질 잎, 올리브유, 소금, 후추. #파스타 #파스타추천 #추천 #파스타종류 #스파게티 볼로네제 #페투치니 알프레도 #라자냐 #펜네 아라비아타 #크림 파스타 #토마토 바질 파스타 #새우 알리오 올리오 #닭가슴살 파스타 #버섯 크림 파스타 #올리브 오일 파스타.", "score": 0.6690754, "raw_content": null}, {"url": "https://namu.wiki/w/%ED%8C%8C%EC%8A%A4%ED%83%80/%EC%A2%85%EB%A5%98", "title": "파스타/종류 - 나무위키", "content": "# 파스타/종류. 상위 문서 아이콘 \xa0 상위 문서: 파스타. \\") + 소스 또는 주방장이름, 지역명)의 형식을 가지고 있는 경우가 많다. 예를 들어 흔히 잘 알려진 미트소스 스파게티는 스파게티 알라 볼로네제(spaghetti alla bolognese)라고 한다. 두께가 2mm 정도 되는 스파게티, 까르보나라에 주로 쓰인다. 두께 1.6mm 정도인 스파게티. 두께 1.3mm~1.5mm 정도의 스파게티. 페투치네를 좀 더 얇게 만든 것. 탈리아텔레와는 반대로 페투치네를 좀 더 굵게 만든 것. 보통 숏 파스타는 복잡하거나 안쪽이 뚫린 모양, 혹은 작은 알갱이 형태가 된다. 이탈리아 요리에서 널리 사용되는 파스타 종류. 나비 모양 또는 리본 모양으로 생긴 파스타. 2021년 미국의 댄 패슈먼이 뉴욕 파스타 회사 스폴리니(Sfoglini)와 협력하여 소스를 더 효율적으로 담을 수 있게 개발한 작은 폭포 모양의 파스타. 넓은 판면으로 소스와 함께 층층이 쌓아 만든 파스타. 주로 치즈가 안에 들어있으며, 경우에 따라 돼지고기를 넣거나 야채가 단호박으로 만든 토르텔리니(Tortelli di Zucca)를 요리하는 곳으로 유명하다.\\")로 만들기도 한다. 허브+견과류(주로 잣)+단단한 치즈+마늘+올리브유+소금 등을 갈아서 만든 소스.은 허브의 신선함과 고유의 향을 해치기 때문에 넣지 않으며, 페스토는 기본적으로 \'갈아낸다\'는 개념이 아닌 \'빻아서\' 크림화하는 소스이다.", "score": 0.5837973, "raw_content": null}], "response_time": 0.67, "request_id": "1c9b439e-7a37-4721-b6b1-5c784a724283"}', name='tavily_search', id='ef9239fb-78d9-4589-a3b7-904f7ba511b9', tool_call_id='call_RBLD9gmv3RjrGqRKW3m1rmSi'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 4260, 'total_tokens': 4288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2176}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DzDZz0FTTj43IDY49lXTFDrBvh7LK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f3fd8-7664-7011-86c7-c535f861ff68-0', tool_calls=[{'name': 'search_wikipedia_korea', 'args': {'query': '파스타', 'max_result': 3}, 'id': 'call_LLEXILAyQ8bQhCuSHdfwdMkW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 4260, 'output_tokens': 28, 'total_tokens': 4288, 'input_token_details': {'audio': 0, 'cache_read': 2176}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"result": "검색된 문서가 없습니다."}', name='search_wikipedia_korea', id='7bcd11b7-7178-4b8f-87ef-80957cde1164', tool_call_id='call_LLEXILAyQ8bQhCuSHdfwdMkW'),
#   AIMessage(content='물론이죠! 파스타는 메뉴가 다양해서 취향에 따라 고르기 좋아요.  \n다만 제가 확인한 레스토랑 메뉴에는 **파스타 메뉴가 직접 보이지 않아서**, 일반적으로 많이 찾는 파스타 기준으로 추천드릴게요.\n\n### 추천 파스타\n1. **스파게티 볼로네제**\n   - **이유:** 진한 토마토 미트소스 맛이 익숙하고 누구나 무난하게 즐기기 좋아요.\n\n2. **까르보나라**\n   - **이유:** 크리미하고 고소한 맛이 강해서 부드러운 파스타를 좋아하시면 잘 맞아요.\n\n3. **알리오 올리오**\n   - **이유:** 마늘과 올리브오일의 깔끔한 맛이 특징이라, 느끼하지 않고 가볍게 먹기 좋아요.\n\n4. **봉골레**\n   - **이유:** 조개의 감칠맛과 오일소스가 잘 어우러져서 해산물 좋아하시면 추천해요.\n\n---\n\n### 파스타의 유래\n파스타는 **이탈리아를 대표하는 밀가루 반죽 음식**으로, 지역과 형태에 따라 아주 다양한 종류가 있습니다.  \n‘파스타’라는 말은 원래 **반죽(dough, paste)**을 뜻하는 의미에서 왔고, 오늘날에는 **면 요리 전체를 포함하는 넓은 개념**으로 쓰여요.\n\n일반적으로 파스타는 이탈리아에서 오랜 기간 발전해왔고,  \n- **건면(마른 파스타)**은 저장과 운반이 쉬워 널리 퍼졌고,\n- **생면(신선한 파스타)**은 지역 전통 요리로 다양하게 발전했습니다.\n\n즉, 파스타는 단순히 스파게티 하나를 뜻하는 게 아니라,  \n**스파게티, 펜네, 푸실리, 페투치네, 라자냐** 같은 여러 면과 요리를 아우르는 음식이에요.\n\n원하시면 제가 이어서  \n**“크림/토마토/오일 중 어떤 스타일이 좋은지”**에 맞춰 더 딱 맞는 파스타도 추천해드릴게요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 491, 'prompt_tokens': 4312, 'total_tokens': 4803, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 4224}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DzDa2D5Wr8YYNUg6Y2gvhfkytNwqk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f3fd8-8581-79a3-ac81-0591bdcc3d53-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4312, 'output_tokens': 491, 'total_tokens': 4803, 'input_token_details': {'audio': 0, 'cache_read': 4224}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
print(res['messages'][-1].content)
# Out:
# 물론이죠! 파스타는 메뉴가 다양해서 취향에 따라 고르기 좋아요.
# 다만 제가 확인한 레스토랑 메뉴에는 **파스타 메뉴가 직접 보이지 않아서**, 일반적으로 많이 찾는 파스타 기준으로 추천드릴게요.
#
# ### 추천 파스타
# 1. **스파게티 볼로네제**
#    - **이유:** 진한 토마토 미트소스 맛이 익숙하고 누구나 무난하게 즐기기 좋아요.
#
# 2. **까르보나라**
#    - **이유:** 크리미하고 고소한 맛이 강해서 부드러운 파스타를 좋아하시면 잘 맞아요.
#
# 3. **알리오 올리오**
#    - **이유:** 마늘과 올리브오일의 깔끔한 맛이 특징이라, 느끼하지 않고 가볍게 먹기 좋아요.
#
# 4. **봉골레**
#    - **이유:** 조개의 감칠맛과 오일소스가 잘 어우러져서 해산물 좋아하시면 추천해요.
#
# ---
#
# ### 파스타의 유래
# 파스타는 **이탈리아를 대표하는 밀가루 반죽 음식**으로, 지역과 형태에 따라 아주 다양한 종류가 있습니다.
# ‘파스타’라는 말은 원래 **반죽(dough, paste)**을 뜻하는 의미에서 왔고, 오늘날에는 **면 요리 전체를 포함하는 넓은 개념**으로 쓰여요.
#
# 일반적으로 파스타는 이탈리아에서 오랜 기간 발전해왔고,
# - **건면(마른 파스타)**은 저장과 운반이 쉬워 널리 퍼졌고,
# - **생면(신선한 파스타)**은 지역 전통 요리로 다양하게 발전했습니다.
#
# 즉, 파스타는 단순히 스파게티 하나를 뜻하는 게 아니라,
# **스파게티, 펜네, 푸실리, 페투치네, 라자냐** 같은 여러 면과 요리를 아우르는 음식이에요.
#
# 원하시면 제가 이어서
# **“크림/토마토/오일 중 어떤 스타일이 좋은지”**에 맞춰 더 딱 맞는 파스타도 추천해드릴게요!

# %% [markdown]
# # LangChain에서 MCP 연동
#
# ## MCP란
#
# - **MCP**(**Model Context Protocol**)는 Anthropic이 주도하여 2024년 말에 발표한 개방형 표준으로, LLM 애플리케이션이 외부 데이터 소스나 도구에 접근하는 방식을 표준화 하는 프로토콜이다.
#   - Agent가 이용할 수 있는 tool을 구현하는 방법은 framework 마다 다르기 때문에 서로 호환 되지 않는 문제가 있다.
#   - MCP는 이런 문제를 해결하기 위해 만든 표준 프로토콜이다.
#
# ## MCP 아키텍처 구성 요소
# - **MCP 호스트**
#   -  AI 애플리케이션(예: LLM 채팅 애플리케이션)으로 MCP 클라이언트를 통해 여러 서버에 연결한다.
#
# - **MCP 클라이언트**
#   -  각 MCP 서버와의 연결을 유지하는 구성요소로, 서버로부터 도구/리소스/프롬프트를 가져와 LLM 모델에게 전달한다.
#
# - **MCP 서버**
#   -  외부 데이터 소스나 Tool들을 제공하는 프로그램이다. 서버는 도구, 리소스, 프롬프트를 노출하고 클라이언트와 JSON‑RPC 2.0 메시지로 통신한다.
#   -  MCP는 서버 클라이언트 간의 **로컬 프로세스 간 통신을 위한 STDIO**와 **원격 서버 접속을 위한 Streamable HTTP** 두 가지 전송 방식을 지원한다
#   -  **MCP 서버가 제공하는 것**
#      -  **도구**(**Tools**): LLM이 호출할 수 있는 함수형 작업이다. 예를 들어 “queryDatabase”, “sendEmail” 등이 있으며 각 도구는 이름, 설명, 입력 스키마를 포함한다.
#      -  **리소스**(**Resources**): 읽기 전용 데이터 소스로, 검색 색인·파일시스템·데이터베이스 등에서 컨텍스트를 제공한다.
#      -  **프롬프트**(**Prompts**): LLM 프롬프트 템플릿이나 예시를 서버에서 제공해 AI 모델의 질의를 돕는다.
#
#
# ## 사용 가능한 MCP 서버 검색
#
# - MCP 생태계에는 수천 개의 툴 서버가 이미 공개되어 있으며, 원하는 기능의 툴을 검색하여 사용할 수 있다.
# - MCP 검색 및 서비스 사이트
#   - [PulseMCP](https://pulsemcp.com)
#   - [MCP 마켓](https://mcpmarket.com/ko)
#   - [MCP Servers](https://mcp.so/)
#   - [smithery](https://smithery.ai/servers)

# %% [markdown]
# ## LangChain에서 MCP 서버 연동하기
# - MCP 서버를 사용하기 위해서는 **Node.js**를 설치 해야 한다. # 자바스크립트 실행환경
#   - https://nodejs.org/ko/download
# - LangChain에서 MCP 서버와 연동하기 위해서는 Adapter lib 설치가 필요하다.
#   - `pip install langchain-mcp-adapters`
#
# ###  MultiServerMCPClient
# - **MCP 클라이언트 객체**로, LangChain에서 **하나 이상의 MCP 서버를 연결하고 Tool 목록을 가져오기 위해 사용**한다.
#     - 여러 개의 MCP 서버를 **동시에 등록하고 연결**할 수 있다.
#     - 서버 설정들을 **하나의 딕셔너리**(**Dictionary**)로 묶어 전달하며, **각 개별 서버 역시 Dictionary로 설정**한다.
#     - MCP 클라이언트에 등록된 모든 서버는 이후 `get_tools()` 호출을 통해 서버가 제공하는 tool들을 **LangChain의 Tool 객체로 자동 변환해 Agent가 호출**(**사용**)할 수있게 한다.
#
# #### 개별 서버 설정 Key 정의
# - **`dict[str: 서버 별칭, dict: 서버 설정]`**
#
# | 설정 Key        | 의미                                                                  | 사용 예                            |
# | --------------- | --------------------------------------------------------------------- | ---------------------------------- |
# | **`transport`** | 서버와 통신하는 방식                                                  | `"stdio"` 또는 `"streamable-http"` |
# | **`command`**   | MCP 서버를 실행할 프로그램(프로세스)                                  | `"python"` 또는 `"npx"`            |
# | **`args`**      | command에 전달할 세부 실행 인자를 **리스트(List)**에 문자열로 순서대로 배치 | `["-m", "mcp_server_time"]`  |
# | **`env`**       | MCP 서버 실행시 필요한 환경변수 설정. (API Key)                       | `{"FIRECRAWL_API_KEY": os.getenv("FIRECRAWL_API_KEY")}`|
#
# - **transport 값에 따른 동작 구분**
#     - `"stdio"`: 로컬에서 실행되는 서버 연결
#     - `"streamable-http"`: 원격 MCP 서버(서비스형) 연결
#
#     ```json
#         {
#             "time": {
#                 "transport": "stdio",
#                 "command": "python",
#                 "args": ["-m", "mcp_server_time"]
#             }
#
#             "github": {
#                 "transport": "streamable-http",
#                 "url": "https://server.smithery.ai/github",
#             }
#         }
#     ```
#
# #### command + args 와 실행 명령어 관계
#
# | 실제 실행 명령                    | 설정으로 표현되는 방식                                             |
# | --------------------------- | -------------------------------------------------------- |
# | `python -m mcp_server_time` | `"command": "python", "args": ["-m", "mcp_server_time"]` |
# | `npx -y @org/server`        | `"command": "npx", "args": ["-y", "@org/server"]`        |
#
# * **command는 실행 프로그램**, args는 **명령 뒤에 붙는 옵션을 순서 그대로 리스트에 나열**한다.

# %%
! uv pip install langchain-mcp-adapters
# Out:
# Resolved 51 packages in 1.54s
# Prepared 4 packages in 262ms
# Installed 4 packages in 116ms
#  + langchain-mcp-adapters==0.3.0
#  + mcp==1.28.1
#  + pyjwt==2.13.0
#  + sse-starlette==3.4.5

# %%
! uv pip install mcp-server-time
# python으로 만든 mcp-server-time 엠시피 서버를 설치(stdio)
# Out:
# Resolved 34 packages in 294ms
# Prepared 2 packages in 78ms
# Installed 2 packages in 300ms
#  + mcp-server-time==2026.6.4
#  + tzlocal==5.4.4

# %%
import nest_asyncio
nest_asyncio.apply() # 주피터 환경에서 비동기 실행을 위해서 (주피터 환경이 아니면 필요없음)

# %%
# %%writefile mcp_exam.py

from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from dotenv import load_dotenv
import os
import asyncio
load_dotenv()

async def main():
    # MultiServerMCPClient 객체 생성 -> MCP 서버와 연결 + MCP 툴들을 langchain tool로 변경
    # 연결할 MCP 서버들 설정. dict[str: 서버이름, dict]
    client = MultiServerMCPClient(
        {
            "time":{
                "transport":"stdio",
                "command":"python",
                "args":["-m","mcp_server_time"]
            },
            "filesystem": {
                "transport":"stdio",    
                "command": "npx",
                "args": [
                    "-y",
                    "@modelcontextprotocol/server-filesystem",
                    os.getcwd() # server-filesystem이 사용할 수 있는 디렉토리
                ]
            },
            "playwright": {
                "transport":"stdio",  
                "command": "npx",
                "args": [
                    "@playwright/mcp@latest"
                ]
            }
        }

    )
    # langchain too list로 변환
    tools = await client.get_tools()
    print("툴개수:", len(tools))
    # agent 생성
    agent = create_agent(
        model=ChatOpenAI(model="gpt-5.4-mini"),
        tools=tools,
        system_prompt="당신은 유능한 AI Assistant입니다. 필요한 경우 도구들을 이용해서 답변하세요."
    )
    print(">>> 종료하려면 !quit를 입력하세요.<<<")
    while True:
        query = input(">>>질문:")
        if query == '!quit':
            print(">>>종료<<<")
            break
        res = await agent.ainvoke({
            "messages":[
                ("human", query)
            ]
        })
        print("<<<답변:")
        print(res['messages'][-1].content)
        print("---")
if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Overwriting mcp_exam.py

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Playdata\\SKN\\SKN31\\10_AI_Agent'
