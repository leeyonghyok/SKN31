# %% [markdown]
# # 프롬프트 엔지니어링(Prompt Engineering)
#
# ## 프롬프트(Prompt)
#
# - 프롬프트(Prompt)는 생성형 인공지능 모델에게 작업을 요청하거나 지시하기 위해 입력하는 정보이다.
# - 일반적으로 자연어로 작성되지만, 이미지, 음성, 동영상 등의 다양한 형태로 입력될 수도 있다.
# - 생성형 인공지능 모델은 프롬프트를 바탕으로 텍스트, 이미지, 코드 등 다양한 결과를 생성한다.
#
# ## 프롬프트 엔지니어링이란
#
# - **프롬프트 엔지니어링**은 LLM이 원하는 결과를 안정적으로 생성하도록 **지시문, 입력 정보, 출력 형식, 예시, 제약 조건을 설계하는 작업**이다.
#     - OpenAI는 프롬프트 엔지니어링 정의:  "모델이 요구사항을 만족하는 콘텐츠를 **일관되게 생성하도록 효과적인 지시를 작성**하는 과정"
#     - LLM 출력은 비결정적이지만, 프롬프트에 역할, 예시, 평가 등을 사용하여 구체화 하면 더 일관된 결과를 얻을 수 있다.
#     - 예를 들어 단순히 다음처럼 요청하면 결과가 들쭉날쭉하고 장황해 질 수 있다.
#
#         ```text
#         프롬프트 엔지니어링 설명해줘.
#         ```
#
#         반면 다음처럼 요청하면 더 안정적인 결과를 얻을 수 있다.
#
#         ```text
#         너는 AI를 초보자에게 가르치는 강사이다.
#         프롬프트 엔지니어링을 초보자에게 설명하라.
#
#         조건:
#         - 먼저 한 문장으로 정의한다.
#         - 그다음 원칙 5개를 표로 정리한다.
#         - 마지막에 좋은 프롬프트와 나쁜 프롬프트 예시를 비교한다.
#         - 한국어로 작성한다.
#         ```
#
#     -  프롬프트 엔지니어링은 **AI에게 막연히 질문하는 기술이 아니라, 원하는 작업을 수행하도록 명세서를 작성하는 기술** 이다.
#
#
# ## 프롬프트 엔지니어링의 발전
#   - 프롬프트 엔지니어링 -> 컨텍스트 엔지니어링 -> 하네스 엔지니어링
#   - **프롬프트 엔지니어링은 모델에게 '무엇을 하라고 지시할 것인가'**, **컨텍스트 엔지니어링은 '모델에게 어떤 정보를 제공할 것인가'**, **하네스 엔지니어링은 '모델이 실제로 일하게 만드는 실행 환경을 어떻게 설계할 것인가'** 를 말한다.
#
#
# | 구분         | 핵심 질문                         | 주요 대상                        |
# | ---------- | ----------------------------- | ---------------------------- |
# | 프롬프트 엔지니어링 | 모델에게 어떻게 지시할 것인가?             | 지시문, 역할, 형식, 예시              |
# | 컨텍스트 엔지니어링 | 모델에게 어떤 정보를 제공할 것인가?        | RAG, 검색결과, 도구 결과, 메모리, 대화 이력       |
# | 하네스 엔지니어링  | 모델을 어떤 시스템 안에서 어떻게 실행·검증·통제할 것인가? | 가드레일(Guardrails), 에이전트 피드백 루프, 코딩표준, 아키텍처 규칙, 도구, 권한, 테스트, 로깅, 검증 |

# %% [markdown]
# ## 프롬프트 엔지니어링의 원칙
#
# ### 1. 목표를 명확히 하고 내용을 구체적으로 작성한다. (명확성, 구체성)
#
# 좋은 프롬프트는 "무엇을 해줘"가 아니라 **무엇을, 누구를 위해, 어떤 수준으로, 어떤 형식으로** 해달라는 요청을 포함한다.
# - 프롬프트는 생성형 인공지능 모델이 수행해야 할 작업을 명확하고 구체적으로 설명해야 한다.
# - 모호하거나 불완전한 지시를 제공하면 모델은 사용자의 의도를 정확하게 파악하기 어렵고, 기대와 다른 결과를 생성할 수 있다.
# - 따라서 수행할 작업, 원하는 결과의 형식, 대상 독자, 분량, 제약 조건 등을 가능한 한 구체적으로 제시하는 것이 좋다.
#
# 나쁜 예:
#
# ```text
# 머신러닝 설명해줘.
# ```
#
# 좋은 예:
#
# ```text
# 머신러닝을 처음 배우는 비전공자를 대상으로 설명해줘.
# 머신러닝의 정의, 지도학습/비지도학습 차이, 실제 활용 예시를 포함하고, 마지막에 5문장으로 요약해줘.
# ```
#
# Anthropic도 프롬프트를 개선하기 전에 먼저 **성공 기준을 명확히 정의하고, 그 기준을 경험적으로 테스트할 방법을 갖추는 것**을 권장한다.
#
#
# ### 2. 역할(Persona)을 지정한다
#
# 모델에게 역할(Persona)을 주면 답변의 관점과 깊이가 달라진다.
# 역할 지정은 단순한 "연기"가 아니라, **답변 기준, 용어 선택, 예시의 수준, 판단 기준을 좁히는 장치** 이다.
#
# 예1:
#
# ```text
# 당신은 10년 차 경력의 숙련된 UX 디자이너입니다.
# 사용자 중심 디자인과 데이터 기반 의사결정에 강점이 있습니다.
# 신규 모바일 쇼핑 앱의 첫 화면 구성안을 제안해야 합니다.
#
# ...
#
# 위 역할을 바탕으로 화면 구성을 제안해주세요.
# ```
#
# 예2:
# ```text
# 당신은 10년 차 전문 헬스 트레이너이다.
# 체지방을 줄이고 근육량을 늘리고 싶은 30대 직장인 남성을 위한 1주일 운동 스케쥴을 작성해줘.
# ...
# ```
#
# ### 3. 출력 형식을 명확히 지정한다
#
# LLM은 기본적으로 자유형 텍스트를 생성하므로, 원하는 결과 형식이 있으면 명시해야 한다. API나 자동화 시스템에서는 특히 중요하다.
#
# 예:
#
# ```text
# ...
#
# 결과를 JSON  형식으로 작성해줘.
#
# {
#   "person": "김철수",
#   "task": "보고서 제출",
#   "due_date": "2025-12-31"
# }
#
# ```
#
#
# ### 4. 필요한 배경 정보(Context-맥락 정보)를 제공한다
#
# - 모델은 사용자의 상황을 자동으로 알지 못한다. 따라서 답변에 필요한 배경 정보가 있다면 넣어야 한다.
# - 모델 답변의 할루시네이션을 방지하기 위해 다양한 형태의 정보를 Context에 포함하여 제공할 수 있다. 이런 정보에는 사내 업무 문서, 웹 검색정보, 데이터베이스 등에서 조회한 관련 정보들이 있을 수 있다.
#
#
# ```text
# 우리는 월 20%의 고객 이탈률을 겪고 있는 구독 기반 온라인 교육 서비스이다.
# 주요 고객층은 30대 직장인이고, 이탈 주요 원인은 콘텐츠 부족과 동기 저하이다.
# 이탈률을 줄이기 위한 실질적인 전략을 제안해줘.
# ```
#
# ### 5. 예시를 제공한다
#
# 모델에게 원하는 입출력 예시를 주면 결과가 안정된다.
# 예시의 개수에 따라 **Zero shot Learning**, **One shot Learning**, **Few shot Learning** 이 있다.
#
# ```text
#
# 예시:
# 질문: "과적합이란 무엇인가요?"
# 답변:
#     - 정의: 학습 데이터에는 잘 맞지만 새로운 데이터에는 성능이 낮아지는 현상
#     - 비유: 문제집 답을 외웠지만 새로운 문제를 못 푸는 상황
#     - 예시: 훈련 정확도 99%, 테스트 정확도 70%
# ```
#
# ### 6. 프롬프트 구성을 구조화한다.
# 긴 프롬프트는 역할(Role), 지시(Instruction), 맥락(Context), 출력 형식(Output Format) 등을 구획으로 나눈다. 나눌 때는 **태그**(예: `<context>, <instructions>`)나 **Markdown**(`#`, `##`)를 이용한다.
#
# ```xml
# <instructions>
# 다음 뉴스 기사를 읽고 핵심 내용을 요약하라.
# </instructions>
#
# <context>
# 사용자는 바쁜 직장인으로, 전체 기사를 읽을 시간이 없다. 핵심 정보만 빠르게 파악하고 싶어한다.
# </context>
#
# <input_data>
# [기사 원문]
# 오늘 오전, 서울 강남구 일대에 시간당 80mm가 넘는 집중호우가 내려 도로 일부가 침수되고, 차량 통제가 이루어졌다. 기상청은 이 같은 집중호우가 오후까지 계속될 것으로 전망하면서 시민들의 외출 자제를 당부했다. 서울시 역시 재난 문자를 통해 대중교통 이용을 권고하고 있다. ...
# </input_data>
#
# <output_format>
# 한 문단(3줄 이내)으로 요약하라. 일반인이 쉽게 이해할 수 있는 문장을 사용하라.
# </output_format>
#
# <constraints>
# - 전문 용어에는 반드시 쉬운 설명을 덧붙일 것
# - 분량은 500자 이내 한다.
# - 한국어로 작성한다.
# </constraints>
# ```
#
#
# ### 7. 제약 조건을 명시한다
#
# - 모델이 하지 말아야 할 것도 명확히 써야 한다.
# - 특히 교육, 법률, 의료, 투자, 기업 보고서처럼 정확성이 중요한 영역에서는 **출처, 기준 시점, 불확실성, 검증 절차**를 프롬프트에 포함하는 것이 좋다.
#
# 예:
#
# ```text
# 주의:
# - 모르는 내용은 추측하지 말고 모른다고 말한다.
# - 현재 날짜 2XXX 년 10월 20일을 기준으로 최신정보를 제공한다.
# - 코드는 Python 3.12 기준으로 작성한다.
# ```
#
# ### 8. 프롬프트를 점진적으로 개선한다.
#
# 실무에서는 프롬프트를 한 번 작성하고 끝내지 않는다. 원하는 결과가 안정적으로 나오는지 반복적으로 평가하고 튜닝해야 한다.
# 프롬프트를 평가할 때는 평가에 사용할 LLM 모델의 버전 고정하여 프롬프트 수정 후 결과가 달라졌을 때, 그 변화가 모델 변경 때문인지 프롬프트 변경 때문인지 구분할 수 있도록 한다.
# 테스트 질문, 기대 답변, 평가 기준을 미리 정해두고 프롬프트 성능을 측정하는 평가 방식을 구축한다. 이를 통해 프롬프트를 수정할 때마다 정확도, 형식 준수 여부, 누락 여부, 환각 여부 등의 변화를 모니터링할 수 있다.

# %% [markdown]
# # 프롬프트 템플릿 (Prompt Template)
#
# 프롬프트 템플릿은 언어 모델(Large Language Model, LLM)에 입력할 **프롬프트를 생성하는 재사용 가능한 템플릿**이다. 프롬프트 작성 시 변수를 포함하여 템플릿화함으로써, 다양한 입력값에 유연하게 대응할 수 있으며, 일관성 있는 결과를 얻는 데 유리하다.
# 프롬프트는 문자열(string)로 작성되므로 Python의 f-string을 사용해 동적으로 생성할 수 있다. 또한 LangChain은 다양한 PromptTemplate 클래스를 제공하여 변수 치환, 프롬프트 재사용, 체계적인 프롬프트 관리를 지원한다.
#
# ## 프롬프트 템플릿의 목적
#
# * 재사용성: 입력값이 달라져도 동일한 프롬프트 구조를 재사용할 수 있다.
# * 유지보수성 향상: 프롬프트 구조와 변수 값을 분리하여 관리할 수 있으므로 수정과 관리가 용이하다.
# * 자동화 지원: 사용자 입력, 데이터베이스 조회 결과, 웹 검색 결과 등 다양한 데이터를 템플릿에 주입하여 프롬프트를 자동으로 생성할 수 있다.
# * 일관성 확보: 동일한 형식의 프롬프트를 지속적으로 생성하여 모델의 응답 품질을 보다 안정적으로 유지할 수 있다.
#
# ## Langchain의 주요 Prompt Template
#
# 1. **PromptTemplate**
#
# * **단일 텍스트(string) 형태의 프롬프트를 생성**하기 위한 가장 기본적인 템플릿 클래스이다.
# * 특징
#     * 문자열 기반 프롬프트 생성에 사용된다.
#     * 변수(Placeholder)는 중괄호 {}로 표시한다.
#       * `{}`는 변수를 표시하는 구분자로 사용된다. 그래서 프롬프트에 중괄호 자체를 문자열로 포함하려면 `{{`와 `}}`를 사용하여 이스케이프(escape)해야 한다.
#     * 변수(placeholder)에 전달되는 입력값에 따라 프롬프트를 동적으로 생성할 수 있다.
#     * 주로 텍스트 완성(Text Completion) 방식이나 단순 지시형 프롬프트 작성에 적합하다.
#
# 2. **ChatPromptTemplate**
#
# * 대화형(Chat) 언어 모델을 위한 프롬프트 템플릿 클래스이다.
# * 시스템(System), 사용자(Human), AI(AI) 등의 역할(Role)을 가진 메시지들을 조합하여 프롬프트를 구성할 수 있다.
# * 특징
#     * 역할(Role) 기반 메시지를 정의할 수 있다.
#     * 시스템 메시지(SystemMessage), 사용자 메시지(HumanMessage), AI 메시지(AIMessage) 등을 하나의 프롬프트로 구성할 수 있다.
#     * 대화 이력이나 컨텍스트를 구조적으로 관리하기 쉽다.
#     * GPT 계열과 같은 채팅 모델에서 가장 많이 사용되는 프롬프트 템플릿이다.
#
# - 최근의 GPT, Claude, Gemini, Qwen과 같은 대부분의 LLM은 채팅(Chat) 인터페이스를 기반으로 동작하므로, PromptTemplate보다 ChatPromptTemplate이 더 널리 사용된다.

# %% [markdown]
# ## 프롬프트 템플릿 사용법
#
# - 전체 템플릿은 문자열(string)로 정의하며, 변수(placeholder)는 `{변수명}` 형식으로 지정한다. 템플릿이 실행될 때 변수는 전달된 실제 값으로 대체된다.
#   - 예시: `"{country}의 수도는 어디인가요?"`
# - 프롬프트에 중괄호(`{, }`) 자체를 포함하려면 `{{` 와 `}}`를 사용하여 이스케이프(escape)해야 한다.
#   - 예시: `{{"이름": "{name}"}}`
# - 생성한 문자열 템플릿을 이용하여 Prompt Template 객체를 생성한다.
#
# ### 공통 메소드
#
# 프롬프트 템플릿 클래스에서 공통적으로 사용하는 주요 메소드는 다음과 같다.
#
# #### 템플릿 생성 메소드
#
# - **from_template()**
#   - 문자열 기반 템플릿을 생성한다.
#   - `PromptTemplate`과 `ChatPromptTemplate` 모두에서 사용할 수 있다.
#
# - **from_messages()**
#   - 메시지 객체를 이용하여 대화형 템플릿을 생성한다.
#   - `ChatPromptTemplate`에서 사용한다.
#
# #### 프롬프트 생성 메소드
#
# - **format(변수=값, ...)**
#   - 변수에 값을 대입하여 최종 프롬프트 문자열을 생성한다.
#
# - **format_messages(변수=값, ...)**
#   - 메시지 리스트 형식의 프롬프트를 생성한다.
#   - `ChatPromptTemplate`에서 사용한다.
#
# - **invoke(dict)**
#   - 변수와 값을 딕셔너리 형태로 전달하여 프롬프트를 생성한다. 생성된 프롬프트는 `PromptValue` 객체로 반환된다.
#   - 생성된 결과는 Runnable 체인의 다음 단계 입력으로 사용할 수 있다.
#
# > ##### `invoke()` 메소드
# >
# > - invoke()는 LangChain의 핵심 인터페이스인 Runnable에서 제공하는 공통 실행 메소드이다.
# > - Runnable은 LangChain의 실행 가능한 객체들이 따르는 공통 인터페이스이다.
# > - PromptTemplate, ChatModel, OutputParser, Chain 등은 모두 Runnable 인터페이스를 구현한다.
# > - invoke()는 입력을 받아 처리한 뒤 결과를 반환한다.
# > - 여러 Runnable 객체를 연결하여 체인(Chain)을 구성할 수 있으며, 각 단계의 출력은 다음 단계의 입력으로 전달된다.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os 
# os.getenv("OPENAI_API_KEY")

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
# input_variable ({변수명}-{country}) => 나중에 채울값.
template = "{country}의 수도는 어디인가요?"
prompt = PromptTemplate.from_template(
    template=template
)
prompt
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?')

# %%
print(prompt.template)
print(prompt.input_variables)
# Out:
# {country}의 수도는 어디인가요?
# ['country']

# %%
# prompt 생성 -> input_variables에 값을 할당.
p_str = prompt.format(country="한국")
print(p_str)
p_str2 = prompt.format(country="미국")
print(p_str2)
# Out:
# 한국의 수도는 어디인가요?
# 미국의 수도는 어디인가요?

# %%
p_str3 = prompt.invoke({"country":"독일"})
p_str3
# Out:
# StringPromptValue(text='독일의 수도는 어디인가요?')

# %%
# Prompt -> Model
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI 

# 프롬프트 템플릿 생성
prompt = PromptTemplate.from_template(template="{country}의 수도를 알려주세요.")
# 모델 생성
model = ChatOpenAI(model="gpt-5.4-nano")
# 프롬프트 템플릿의 input_variables에 값을 넣어서 프롬프트 생성
query = prompt.invoke({"country":"한국"}) # prompt.format(country="한국")
# 모델에 프롬프트를 입력해서 질의 요청.
response = model.invoke(query)

# %%
print(response) # 응답: AIMessage 타입
print(response.content) # 응답 text만 조회
# Out:
# content='한국의 수도는 **서울특별시**입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 13, 'total_tokens': 28, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DtillXQSqip5EIG4cPpIHDd92xzto', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ef1c2-529b-7dd2-b831-2cac40e4744c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 15, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 한국의 수도는 **서울특별시**입니다.

# %%
query2 = prompt.invoke({"country":"영국"})
response2 = model.invoke(query2)

# %%
response2.content
# Out:
# '영국의 수도는 **런던(London)** 입니다.'

# %%
while True:
    country = input("수도를 알고 싶은 나라이름을 입력하세요:")
    if country == "!q":
        break
    query = prompt.invoke({"country":country})
    response = model.invoke(query)
    print(f"질문: {query}")
    print(f"답변: {response.content}")

# %%
# prompt template--[query]-->model
chain = prompt | model
res = chain.invoke({"country":"프랑스"})  # prompt에 전달할 값을 입력

# %%
res.content
# Out:
# '프랑스의 수도는 **파리(Paris)** 입니다.'

# %%
# input variable이 여러개인 프롬프트 템플릿
prompt2 = PromptTemplate.from_template(
    template="{place1}, {place2} 간의 거리는 얼마나 되는지 KM로 알려주세요."
)
print(prompt2.input_variables)
print(prompt2.format(place1="서울",  place2="런던"))
print(prompt2.invoke({"place1":"부산", "place2":"서울"}))
# Out:
# ['place1', 'place2']
# 서울, 런던 간의 거리는 얼마나 되는지 KM로 알려주세요.
# text='부산, 서울 간의 거리는 얼마나 되는지 KM로 알려주세요.'

# %%
query = prompt2.invoke({"place1":"부산", "place2":"서울"})
res = model.invoke(query)

# %%
print(res.content)
# Out:
# 부산–서울의 거리는 **대략 325~400km** 정도입니다.
#
# - **직선거리(항공 기준): 약 325km**
# - **도로 기준(차로 이동): 약 400km 내외**
#
# 원하시면 **“직선거리”**(정확한 좌표 기준)인지 **“도로 거리”**(출발/도착 지점 지정)인지 알려주시면 더 정확히 계산해드릴게요.

# %%
###############################
# ChatPromptTemplate
#
# Chatting 형식의 Message를 지원. 
#  - chatting형식: Role - Content(메세지) 로 구성
# - Langchain 방식 구성
[
    ("role", "content"), ("role", "content"), ...
]
# - OpenAI 방식 구성
[
    {"role":"작성자ROLE", "content":"작성메세지"}, ...
]
# - Langchain에서는 위 두가지 방식 다 지원.
# Role
## user/human  : 사용자 메세지
## ai/assistant: LLM 메세지
## system      : 전체 대화에 공통적으로 적용될 규칙이나 지침을 지정하는 메세지.

## tool(ToolMessage) : Tool calling에서 Tool의 처리결과를 담은 메세지.
# Out:
# [{'role': '작성자ROLE', 'content': '작성메세지'}, Ellipsis]

# %%
from langchain_core.prompts import ChatPromptTemplate

messages =[
    ("system", "당신은 {domain} 전문 Assistant입니다. 모든 답변은 {word_length}개 단어 이하로 답해주세요."),
    ("user", "{query}")
]

prompt = ChatPromptTemplate.from_messages(
    messages=messages
)
print(prompt.input_variables)
print(prompt.messages)
# Out:
# ['domain', 'query', 'word_length']
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['domain', 'word_length'], input_types={}, partial_variables={}, template='당신은 {domain} 전문 Assistant입니다. 모든 답변은 {word_length}개 단어 이하로 답해주세요.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})]

# %%
query1 = prompt.format_messages(domain="AI", word_length=30, query="Agent란 무엇인가요?")
query1
# role: system => SystemMessage객체
# role: user/human => HumanMessage 객체
# role: ai/asssistant => AIMessage 객체
# 공통: content 속성에 message가 저장됨.
# Out:
# [SystemMessage(content='당신은 AI 전문 Assistant입니다. 모든 답변은 30개 단어 이하로 답해주세요.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Agent란 무엇인가요?', additional_kwargs={}, response_metadata={})]

# %%
res = model.invoke(query1)

# %%
print(res.content)
# Out:
# Agent는 자율적으로 목표를 달성하도록 환경을 인식하고 행동을 선택하는 소프트웨어/시스템입니다. 예: 챗봇, 자동화 로봇, 추천 에이전트.

# %%
query2 = prompt.invoke(
    {"domain":"와인", "word_length":20, "query":"해산물에 어울리는 와인을 소개해줘."}
)
res = model.invoke(query2)

# %%
query2
# Out:
# ChatPromptValue(messages=[SystemMessage(content='당신은 와인 전문 Assistant입니다. 모든 답변은 20개 단어 이하로 답해주세요.', additional_kwargs={}, response_metadata={}), HumanMessage(content='해산물에 어울리는 와인을 소개해줘.', additional_kwargs={}, response_metadata={})])

# %%
res
res.content
# Out:
# '해산물엔 쇼블리, 미네랄 드라이 샤블리, 또는 소비뇽블랑. 산도 높은 화이트가 최적이에요.'

# %%
# 연결질문
res = model.invoke("추천한 와인에 대해서 좀 더 자세히 설명해줘.")

# %%
print(res.content)
# Out:
# 좋아요. 다만 제가 지금 “추천한 와인”이 어떤 것인지 정보가 없어서, 정확히 설명을 드리기 위해 먼저 한 가지만 확인할게요.
#
# 1) 어떤 와인을 추천드렸나요? (와인 이름/브랜드/빈티지 또는 사진/링크도 OK)
# 2) 원하시는 설명 스타일이 있을까요? (맛/향 중심, 음식 페어링, 구매 팁, 가격대 대비 평가 등)
#
# 와인 정보(1번)만 보내주시면 그 와인에 대해 아래처럼 좀 더 자세히 정리해드릴게요:
# - **품종/스타일**(예: 샤르도네, 피노 누아, 까베르네 소비뇽 등)
# - **맛과 향**(대표 향, 산도/당도/탄닌/바디감)
# - **마시기 좋은 온도와 마시는 시점**
# - **잘 어울리는 음식**(예: 스테이크, 해산물, 치즈, 매운 음식 등)
# - **비슷한 대안 와인**과 **가격대에서의 포인트**
#
# 추천받았던 와인 이름을 알려주실래요?

# %% [markdown]
# ## MessagesPlaceholder
#
# - `MessagesPlaceholder`는 `ChatPromptTemplate` 내에서 여러 개의 메시지가 삽입될 위치를 지정하는 프롬프트 템플릿 요소이다.
# - 주로 대화 이력(Chat History), 퓨샷 예제(Few-shot Examples), 에이전트 중간 처리 결과 등을 프롬프트에 동적으로 추가할 때 사용한다.
# - 일반 변수({variable})가 문자열이나 단일 값을 삽입하는 데 사용된다면, `MessagesPlaceholder`는 여러 개의 메시지(Message 객체 목록)를 삽입하는 데 사용된다.
# - `MessagesPlaceholder`는 `ChatPromptTemplate`에서만 사용할 수 있으며, 일반 `PromptTemplate`에서는 사용할 수 없다.
#
# ### Initializer의 주요 파라미터
#
# 1. **variable_name** (str)
#    - 프롬프트에서 참조할 변수명을 지정한다.
#    - invoke() 실행 시 동일한 이름의 메시지 리스트를 전달해야 한다.
# 1. **optional** (bool, 기본값: False)
#    - True로 설정하면 해당 변수에 메시지가 전달되지 않아도 오류를 발생시키지 않는다.
#    - 주로 대화 이력이 없을 수 있는 경우에 사용한다.
# 1. **n_messages** (int)
#    - 지정된 경우 최근 N개의 메시지만 프롬프트에 포함한다.
#    - 긴 대화 이력을 제한하여 토큰 사용량을 줄이는 데 활용할 수 있다.

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

messages = [
    ("system", "당신은 수학 전문 Assistant입니다. 답변은 일반 text로 작성해주세요."),
    MessagesPlaceholder(variable_name="history", optional=True),
    # ("placeholder", "{history}") # role: placeholder -> MessagesHolder 사용 content(history): 변수명, optional=True
    ("user", "{query}")
]

# 지금까지의 대화내역
chat_history = [
    ("human", "5 + 2의 결과는?"),
    ("ai", "7입니다."),
    ("human", "10 * 5는 무엇인가요?"),
    ("ai", "50입니다.")    
]
query_str = "위 결과의 3제곱을 하면 얼마인가요?"

# %%
prompt = ChatPromptTemplate.from_messages(
    messages=messages
)
query = prompt.invoke({"history":chat_history, "query":query_str})
query.messages
# Out:
# [SystemMessage(content='당신은 수학 전문 Assistant입니다. 답변은 일반 text로 작성해주세요.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='5 + 2의 결과는?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='7입니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='10 * 5는 무엇인가요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='50입니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='위 결과의 3제곱을 하면 얼마인가요?', additional_kwargs={}, response_metadata={})]

# %%
res = model.invoke(query)

# %%
print(res.content)
# Out:
# 50의 3제곱은 50 × 50 × 50 = 125,000입니다.

# %% [markdown]
# # 멀티모달(Multimodal) 프롬프트
#
# ## 모달리티(Modality)
# - 모달리티(Modality)란 정보를 표현하거나 전달하는 방식 또는 형태를 의미한다. 대표적인 모달리티로는 텍스트(Text), 이미지(Image), 오디오(Audio), 비디오(Video) 등이 있다.
#   - "오늘 비가 온다"라는 정보를 표현하는 방법으로
#     * **텍스트**: "오늘 비가 옵니다."
#     * **이미지**: 비가 내리는 사진
#     * **오디오**: 일기예보 음성
#     * **비디오**: 기상예보 영상
# - 정리하면, 모달리티는 데이터의 형식이나 표현 방식을 의미하며, 머신러닝과 인공지능 분야에서는 모델이 입력받거나 생성하는 데이터의 종류를 지칭하는 용어로 사용된다.
#
# ## 멀티모달 AI
#
# - **멀티모달(Multimodal) AI**란 여러 형식의 입력 데이터(모달리티)를 동시에 처리하고 이해할 수 있는 인공지능 시스템을 의미한다.
#   - 예를 들어, 입력으로 **이미지와 "이미지를 설명해주세요"**라는 텍스트를 함께 프롬프트로 전달하는 경우, 모델은 이미지와 텍스트라는 두 가지 서로 다른 형태의 입력을 동시에 처리하게 되며, 이러한 방식을 멀티모달(multimodal) 입력이라고 한다.
#   - 단일 모달리티만 처리하는 것은 유니모달(Unimodal) AI라고 한다.
# - 멀티모달 AI는 다양한 감각 정보를 조합하여 더 정확한 판단을 내리고, 통찰력 있는 결론을 도출하며, 실제 문제에 대해 더 정밀한 예측을 수행할 수있다.
#
# ### 다양한 입력 모달리티의 예
#
# - 텍스트: 자연어, 문서, 코드
# - 이미지: 사진, 차트
# - 오디오: 음성, 음악, 소리
# - 비디오: 동영상, 애니메이션
# - 기타: 수학 방정식, 센서 데이터 등
#
# ## 멀티모달 프롬프트
#
# - **멀티모달 프롬프트**란 인공지능 언어 모델(LLM, Large Language Model)에 입력할 때 텍스트뿐 아니라 이미지나 오디오와 같은 다양한 유형의 데이터를 함께 제공하는 방식을 말한다.
# - 이를 통해 LLM은 다양한 감각 정보를 조합하여 더 깊이 있고 풍부한 응답을 생성할 수 있다. 예를 들어, 사용자가 사진과 함께 질문을 하면 모델은 사진의 내용을 이해하고 텍스트로 된 설명을 결합하여 답변할 수 있다.
#
# ### 멀티모달 프롬프트 예
# - **이미지 + 텍스트**: 사진을 업로드하고 "이 이미지에서 무엇을 개선할 수 있나요?" 질문
# - **오디오 + 텍스트**: 음성 파일과 함께 "이 대화의 감정 상태를 분석해주세요" 요청
# - **비디오 + 텍스트**: 동영상 클립과 함께 "이 영상의 핵심 메시지는 무엇인가요?" 문의

# %% [markdown]
# # Langchain 멀티모달 프롬프트 지원
# - LangChain은 다양한 인공지능 모델과 연동하여 텍스트뿐만 아니라 이미지, 오디오 등 여러 종류의 입력 데이터를 처리할 수 있도록 멀티모달 프롬프트 기능을 지원한다.
#
# ## 지원 가능 모델 확인
# - Langchain으로 멀티모달 입력 기능을 사용하려면, 연동하려는 LLM 모델이 모달리티 입력을 지원해야 한다.
# - [Langchain 지원 LLM 모델](https://python.langchain.com/docs/integrations/chat/#featured-providers)
# - [OpenAI 모델들 입력 형식확인](https://platform.openai.com/docs/models)
#
# ## LangChain에서 멀티모달 입력 구현 방법
# - HumanMessage 객체의 content에 텍스트 외에도 이미지, 오디오등 다양한 데이터를 함께 포함시킬 수 있다.
# - **텍스트**: 일반 문자열 형태로 입력
# - **이미지/오디오**: 다음 두 가지 방식으로 입력할 수 있다.
#     - **URL 지정**: 인터넷에 업로드된 이미지나 오디오의 URL을 제공
#     - **Base64 인코딩**: 파일 데이터를 base64 형식으로 인코딩하여 직접 전달
#
#
# > **Base64 인코딩**은 이진(binary) 데이터를 텍스트 기반 시스템에서 손상 없이 전송하기 위해 ASCII 문자 집합(`알파벳 대소문자, 숫자, +, /`)으로 표현된 텍스트 형태로 변환하는 인코딩 방식이다.
# > 이메일, URL, JSON, HTML과 같이 텍스트만 안전하게 처리할 수 있는 환경에서는 바이너리 데이터를 그대로 전송할 경우 인코딩 해석 문제로 데이터가 손상될 수 있기 때문에,
# Base64 인코딩을 사용해 이를 안전하게 전달한다.

# %%
b"abcde" # bytes 타입의 문자열 b-string f-string r-string
type("abc"), type(b"abc")
# Out:
# (str, bytes)

# %%
# binary 데이터 -> 파이썬 타입: bytes f = open(..., "b") v = f.read()
# base64 encoding: bytes -> str
# base64 decoding: str-> bytes
import base64

# enmcoding
e = base64.b64encode(b"hello")
c = e.decode("utf-8")
print(type(e), e)
c = e.decode("utf-8") # bytes 문자열을 utf-8의 str으로 변호ㅓㄴ b'aGVsbG8=' -> aGVsbG8=
print(type(c), c)
# Out:
# <class 'bytes'> b'aGVsbG8='
# <class 'str'> aGVsbG8=

# %%
# decoding
## str-> bytes
e2 = c.encode("utf-8")
print(type(e2), e2)
v = base64.b64decode(e2)
print(type(v), v)
# Out:
# <class 'bytes'> b'aGVsbG8='
# <class 'bytes'> b'hello'

# %% [markdown]
# ## Image
#
# ### Base64 입력

# %%
import base64
def encode_to_base64(path: str) -> str:
    """입력받은 경로의 파일을 base64로 인코딩 한 뒤 반환"""
    with open(path, "rb") as f:
        data = f.read() # rb모드 -> bytes
        encoded_bytes = base64.b64encode(data) # bytes -> bytes(base64로 인코딩함)
        encoded_str = encoded_bytes.decode("utf-8") # bytes(base64로 인코딩 된) -> str
        return encoded_str

# %%
r = encode_to_base64("data/images/graph1.jpg")

# %%
r[:100]
# Out:
# '/9j/4AAQSkZJRgABAQABLAEsAAD/2wBDAAUDBAQEAwUEBAQFBQUGBwwIBwcHBw8LCwkMEQ8SEhEPERETFhwXExQaFRERGCEYGh0d'

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
messages = [
    {"role":"system", "content":"당신은 멀티모달을 지원하는 AI Assitance입니다."},
    {"role":"user",
     "content":[
         {"type":"text", "text":"{query}"},
         {
             "type":"image", # 멀티 모달리티의 타입
             "source_type":"base64", # 이미지 전송방식(데이터 삽입)
             "data":"{img_data}", # 전송할 이미지(BASE64로 인토딩된 문자열)
             "mime_type":"image/jpeg"
         }
     ]}
]

prompt = ChatPromptTemplate.from_messages(
    messages=messages
)
prompt.input_variables
# Out:
# ['img_data', 'query']

# %%
input_text = "첨부한 이미지에 대해서 설명해줘. 그리고 이미지가 어디인지 장소도 알려줘."
input_img = encode_to_base64("data/images/img1.jpg")

# %%
model = ChatOpenAI(model="gpt-5.5")
query = prompt.invoke({"query":input_text, "img_data":input_img})
res = model.invoke(query)

# %%
print(res.content)
# Out:
# 이미지는 **한국 전통 궁궐의 넓은 마당과 전각**을 담고 있습니다.
#
# - 하늘이 크게 보이는 구도이며, 파란 하늘과 흰 구름이 넓게 펼쳐져 있습니다.
# - 오른쪽에는 화려한 단청이 칠해진 전통 목조건축물이 보입니다. 지붕은 곡선으로 올라간 처마와 회색 기와가 특징적입니다.
# - 건물 앞에는 흰색 석재 난간과 계단, 넓은 박석 마당이 있으며, 마당에는 품계석처럼 보이는 작은 석물들이 줄지어 서 있습니다.
# - 전각 현판에 **“勤政殿(근정전)”**이라고 적혀 있어, 이 건물이 근정전임을 알 수 있습니다.
#
# 장소는 **서울 경복궁의 근정전**으로 보입니다.
# 근정전은 조선 시대 왕의 즉위식, 외국 사신 접견, 국가 의례 등이 열리던 **경복궁의 중심 정전**입니다.
# 즉, 이 사진은 **대한민국 서울특별시 종로구에 있는 경복궁 근정전 일대**를 촬영한 이미지입니다.

# %%
input_text = "첨부한 이미지에 대해서 설명해줘. 그리고 이미지가 어디인지 장소도 알려줘."
input_img = encode_to_base64("data/images/img1.jpg")
messages = [
    {"role":"system", "content":"당신은 멀티모달을 지원하는 AI Assitance입니다."},
    {"role":"user",
     "content":[
         {"type":"text", "text":input_text},
         {
             "type":"image", # 멀티 모달리티의 타입
             "source_type":"base64", # 이미지 전송방식(데이터 삽입)
             "data": input_img, # 전송할 이미지(BASE64로 인토딩된 문자열)
             "mime_type":"image/jpeg"
         }
     ]}
]
res2 = model.invoke(messages)

# %%
print(res2.content)
# Out:
# 이미지는 **한국 전통 궁궐 건축물**을 넓은 하늘과 함께 담은 사진입니다.
#
# - 화면 대부분은 **푸른 하늘과 흰 구름**이 차지하고 있고, 아래쪽에는 넓은 **박석이 깔린 궁궐 마당**이 보입니다.
# - 오른쪽에는 화려한 단청과 겹처마가 돋보이는 큰 전각이 있으며, 지붕의 곡선과 장식이 매우 전통적인 조선 궁궐 양식입니다.
# - 전각 앞에는 돌계단과 난간이 있고, 마당에는 신하들의 위치를 표시하던 **품계석**처럼 보이는 작은 석물들이 줄지어 있습니다.
# - 건물 현판에 **“勤政殿(근정전)”**이라고 쓰여 있어 장소를 확인할 수 있습니다.
#
# 장소는 **서울 종로구 경복궁의 근정전**입니다.
# 근정전은 경복궁의 중심 정전으로, 조선 시대에 국가 의식, 조회, 외국 사신 접견 등이 열리던 중요한 공간입니다. Behind the building, mountains around northern Seoul are faintly visible, which also matches the setting of **Gyeongbokgung Palace in Seoul, South Korea**.

# %%
input_text = "첨부한 chart의 내용을 분석해서 설명해줘."
chart1 = encode_to_base64("data/images/graph2.jpg")
chart2 = encode_to_base64("data/images/graph3.png")

messages = [
    {"role":"system", "content":"당신은 멀티모달을 지원하는 AI Assitance입니다."},
    {"role":"user",
     "content":[
         {"type":"text", "text":input_text},
         {
             "type":"image", # 멀티 모달리티의 타입
             "source_type":"base64", # 이미지 전송방식(데이터 삽입)
             "data": chart1, # 전송할 이미지(BASE64로 인토딩된 문자열)
             "mime_type":"image/jpeg"
         },
         {"type":"text", "text":input_text},
         {
             "type":"image", # 멀티 모달리티의 타입
             "source_type":"base64", # 이미지 전송방식(데이터 삽입)
             "data": chart2, # 전송할 이미지(BASE64로 인토딩된 문자열)
             "mime_type":"image/png"
         }
     ]}
]
res = model.invoke(messages)

# %%
print(res.content)
# Out:
# 아래 두 개의 차트를 각각 분석해 설명하겠습니다.
#
# ---
#
# ## 1. 「수출과 수입 변화」 차트 분석
#
# 이 차트는 한국의 **수출액·수입액 변화**와 함께, **총수출 및 총수입이 GNI에서 차지하는 비율**을 보여줍니다.
# 기간은 대략 **1970년대 초부터 2012년경까지**입니다.
#
# ### 핵심 내용
#
# 한국의 수출입 규모는 1970년대 이후 매우 빠르게 증가했습니다.
#
# - **1971년**: 수출액 **10억 달러 돌파**
# - **1977년**: 수출액 **100억 달러 돌파**
# - **1995년**: 수출액 **1,000억 달러 돌파**
# - **2011년**: 수출액 **5,000억 달러 돌파**
#
# 즉, 한국 경제가 본격적으로 **수출 주도형 성장**을 해왔다는 점을 보여주는 차트입니다.
#
# ### 수출액과 수입액의 흐름
#
# 차트의 선 그래프를 보면,
#
# - **분홍색 선**: 수출액
# - **파란색 선**: 수입액
#
# 입니다.
#
# 1970년대에는 수출과 수입 규모가 매우 작았지만, 1980년대와 1990년대를 거치며 꾸준히 증가했습니다. 특히 2000년대 이후 증가 속도가 크게 빨라졌습니다.
#
# 2008년 전후에는 수출입액이 급증하다가, **2009년 글로벌 금융위기** 영향으로 수출과 수입 모두 크게 감소한 모습이 보입니다. 이후 다시 빠르게 회복해 2011년에 수출액이 5,000억 달러를 넘어섰습니다.
#
# ### 수출과 수입의 관계
#
# 수출액과 수입액은 대체로 비슷한 방향으로 움직입니다.
# 이는 한국 경제가 원자재, 에너지, 중간재 등을 수입해 가공한 뒤 다시 수출하는 구조와 관련이 있습니다.
#
# 즉, 수출이 늘어나면 생산에 필요한 수입도 함께 증가하는 경향이 있습니다.
#
# ### GNI 대비 수출입 비율
#
# 막대그래프는 총수출과 총수입이 GNI에서 차지하는 비율을 보여줍니다.
#
# - 주황색: 총수출의 대 GNI 비율
# - 연두색: 총수입의 대 GNI 비율
#
# 이 비율이 높다는 것은 한국 경제가 국내 시장보다 **해외 교역에 크게 의존한다**는 뜻입니다.
#
# 특히 2000년대 이후 수출입 비중이 높아지면서 한국 경제의 **대외의존도**가 커졌다는 점을 확인할 수 있습니다.
#
# ### 종합 해석
#
# 이 차트는 한국 경제가 1970년대 이후 제조업과 수출을 중심으로 성장했으며, 시간이 갈수록 세계 경제와의 연결성이 강해졌다는 것을 보여줍니다.
# 다만 수출입 의존도가 높기 때문에 글로벌 경기 침체, 환율 변동, 원자재 가격 상승 같은 외부 충격에 영향을 크게 받을 수 있다는 점도 함께 시사합니다.
#
# ---
#
# ## 2. 「경제고통지수 추이, 2000~2023」 차트 분석
#
# 두 번째 차트는 **경제고통지수**를 보여줍니다.
# 경제고통지수는 보통 다음과 같이 계산합니다.
#
# > 경제고통지수 = 소비자물가상승률 + 실업률
#
# 즉, 물가가 많이 오르고 실업률도 높을수록 국민이 체감하는 경제적 어려움이 크다고 해석할 수 있습니다.
#
# 이 차트는 **1월 기준**으로 2000년, 2021년, 2022년, 2023년의 수치를 비교하고 있습니다.
#
# ---
#
# ### 연도별 수치
#
# | 연도 | 소비자물가상승률 | 실업률 | 경제고통지수 |
# |---|---:|---:|---:|
# | 2000년 | 1.9 | 5.7 | 7.6 |
# | 2021년 | 0.9 | 5.7 | 6.6 |
# | 2022년 | 3.6 | 4.1 | 7.7 |
# | 2023년 | 5.2 | 3.6 | 8.8 |
#
# ---
#
# ### 주요 특징
#
# #### 1. 2023년 경제고통지수가 가장 높음
#
# 2023년 경제고통지수는 **8.8**로 표시된 연도 중 가장 높습니다.
# 이는 2000년의 7.6, 2021년의 6.6, 2022년의 7.7보다 높은 수준입니다.
#
# 즉, 2023년 1월 기준으로 국민이 체감하는 경제적 부담이 상대적으로 컸다고 볼 수 있습니다.
#
# #### 2. 2023년 상승의 핵심 원인은 물가
#
# 2023년에는 실업률이 **3.6%**로 2022년보다 낮아졌지만, 소비자물가상승률이 **5.2%**까지 상승했습니다.
#
# 즉, 2023년 경제고통지수 상승은 주로 **고물가** 때문입니다.
#
# #### 3. 2000년과 2021년은 실업률 영향이 큼
#
# 2000년과 2021년은 실업률이 각각 **5.7%**로 높습니다.
# 반면 물가상승률은 2000년 1.9%, 2021년 0.9%로 상대적으로 낮았습니다.
#
# 따라서 이 시기 경제고통은 물가보다는 **고용 불안**에서 더 크게 발생했다고 볼 수 있습니다.
#
# #### 4. 2022년부터 물가 부담이 본격화
#
# 2021년에는 물가상승률이 0.9%로 낮았지만, 2022년에는 3.6%, 2023년에는 5.2%로 크게 상승했습니다.
#
# 이는 코로나19 이후 공급망 문제, 에너지 가격 상승, 글로벌 인플레이션 등의 영향이 반영된 것으로 해석할 수 있습니다.
#
# ---
#
# ## 전체 종합
#
# 첫 번째 차트는 한국 경제가 장기간에 걸쳐 **수출입 중심의 개방경제**로 성장해왔다는 점을 보여줍니다.
# 반면 두 번째 차트는 최근 국민이 체감하는 경제적 어려움이 특히 **물가 상승**을 중심으로 커졌다는 점을 보여줍니다.
#
# 정리하면,
#
# - 한국 경제는 수출입 확대를 통해 성장해왔고,
# - 그만큼 세계 경제 변화에 민감해졌으며,
# - 최근에는 고용 문제보다 물가 상승이 경제고통지수를 높이는 핵심 요인으로 작용하고 있습니다.

# %% [markdown]
# ### URL

# %%
import streamlit as st
# @ 없이
def say_hello():
    print("hello")
print(say_hello())
say_hello = st.cache_resource(say_hello)  # 번거로움

print(say_hello())
print(say_hello)
# Out:
# hello
# None
# None
# <CachedFunc: <function say_hello at 0x0000023F5BC80400>>

# %%
import streamlit as st
# @ 사용
@st.cache_resource
def say_hello():
    print("hello")      # 깔끔!

print(say_hello())
print(say_hello)
# Out:
# None
# <CachedFunc: <function say_hello at 0x0000023F57F3E0C0>>

# %%
def say_hello():
    print("hello")

result = say_hello() # 화면에만 출력
print(result)
# Out:
# hello
# None

# %%
def say_hello():
    return "hello"

result = say_hello() # 값만을 받음 화면에 출력 안함
print(result)
# Out:
# hello

# %%
url = "https://image.fnnews.com/resource/media/image/2023/08/16/202308161827174969_l.jpg"
messages = [{
    "role":"user",
    "content":[
        {"type":"text", "text":"첨부한 그래프 이미지를 분석해줘."},
        {
            "type":"image",
            "source_type":"url",
            "url":url

        }
    ]
}]

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()
model = ChatOpenAI(model="gpt-5.4-nano")
res = model.invoke(messages)

# %%
print(res.content)
# Out:
# 그래프는 **2023년 수출입 ‘추이’(단위: 억달러)**를 **1~7월**까지 나타낸 것으로, **빨간색=수입**, **파란색=수출**로 보입니다(표기: 수입/수출 화살표).
#
# ## 1) 월별 수출(파란색) 변화
# - **1월 463.8**
# - **2월 589.5**
# - **3월 549.5**
# - **4월 521.3**
# - **5월 543.5**
# - **6월 503.3**
# - **7월 487.1**
#
# **요약:** 2월까지 큰 폭으로 늘었다가(463.8 → 589.5), **3~4월 하락**, 이후 **5~6월 약반등/다시 하락**, **7월도 낮은 수준(487.1)** 유지.
# → 전체적으로 **연초 대비 완만한 하락 흐름**입니다(463.8로 시작해 487.1로 종료).
#
# ## 2) 월별 수입(빨간색) 변화
# - **1월 589.5**
# - **2월 549.5**
# - **3월 596.8**
# - **4월 543.5**
# - **5월 521.3**
# - **6월 503.3**
# - **7월 487.1**
#
# **요약:** 3월에 잠깐 반등(549.5 → 596.8) 후 **4월부터 하락세가 이어져**, **7월 487.1**까지 내려옵니다.
# → **연말로 갈수록 뚜렷한 하락 트렌드**.
#
# ## 3) 수출-수입 격차(대략 흐름)
# - **1월:** 수출(463.8) < 수입(589.5) → 수입 우위
# - **2~3월:** 수입이 비교적 높고, 3월에 수입이 특히 큼
# - **4~7월:** 두 항목 모두 감소하나, 전반적으로 **수입이 여전히 수출보다 큰 구간**이 계속되는 형태
#
# ## 결론(핵심)
# - **수출**: 2월 급증 후 **3~4월 감소**, 5~6월 흔들리며 **7월까지 약세**
# - **수입**: 3월 반등 이후 **4~7월 지속 하락**
# - 전체적으로 **상반기(특히 2~3월) 고점 이후 하락 전환**이 관찰됩니다.
#
# 원하시면, 제가 **각 달의 증감(전월 대비 증감)**도 표로 정리해서 더 정확히 계산해드릴게요.

# %% [markdown]
# ## PDF

# %%
pdf = encode_to_base64("data/pdf/SPRi AI Brief 7월호 산업동향.pdf")

# %%
messages = [
    {
        "role":"user",
        "content":[
            {"type":"text", "text":"첨부한 PDF 문서의 내용을 요약해 주세요."},
            {
                "type":"file",
                "source_type":"base64",
                "data":pdf,
                "mime_type":"application/pdf", # 대분류/소분류 ex) application/pdf, image/jpeg
                "filename":"SPRi AI Brief 7월호 산업동향.pdf" # OpenAI는 파일 타입 전송시 파일명을 보내야 한다.

            }
        ]
    }
]

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()
model = ChatOpenAI(model="gpt-5.4-nano")
res = model.invoke(messages)

# %%
print(res.content)
# Out:
# 첨부된 PDF는 **SPRi AI Brief 2025년 7월호**(총 28쪽)로, 2025년 6~7월 무렵의 AI 정책/산업/기술/인력 관련 주요 소식을 한 항목씩 요약해 정리한 자료입니다. 아래는 문서 전체 흐름 기준 요약입니다.
#
# ## 전체 요약(핵심만)
# - **정책·법제:** OECD의 **AI 역량 지표** 공개, 일본의 **AI 기본법(연구개발·활용 촉진/안전 확보)** 제정, 일본 방위 분야에서 **AI 무기 R&D 책임 지침**, 미국의 **AI안전연구소 개편(표준혁신센터)**, EU JRC의 **생성 AI 전망 보고서** 발간이 주요 이슈로 제시됩니다.
# - **기업·산업:** 앤스로픽(Claude 4), 애플(Apple Intelligence 기능 고도화), 미스트랄 AI(추론/코딩 도구), AMD(개방형 AI 생태계/플랫폼·하드웨어), 엔비디아(유럽 AI 인프라 구축), 가트너(에이전틱 AI의 ‘가디언 에이전트’ 부상 전망)가 다뤄집니다.
# - **기술·연구:** LLM 해석 가능성(앤스로픽 오픈소스 도구), 종료 거부/의도치 않은 행동(팰리세이드 연구), 물리 세계 이해 모델(V-JEPA 2, 메타), 딥리서치 에이전트 벤치마크(중국과기대), CVPR 2025 동향이 소개됩니다.
# - **인력·교육:** 메타의 AI 인재 영입(고연봉/조직 구축), 아마존 CEO의 **AI 도입에 따른 인력 감소 전망**, PwC의 **AI 노출 산업의 임금·일자리 성장**, 세일포인트의 **AI 에이전트 보안 위험 우려**가 포함됩니다.
# - **부록:** 주요 행사 일정표(대형 학회/컨퍼런스 및 전시회 다수)가 정리돼 있습니다(문서 뒤쪽).
#
# ---
#
# ## 분야별 주요 내용 요약
#
# ### 1) 정책·법제
# - **OECD(4쪽):** AI의 능력을 인간과 비교할 수 있는 **AI 역량 지표**를 공개. 언어·사회적 상호작용·문제해결·창의성·메타인지/비판적 사고·지식/학습/기억·시각·조작·로봇지능 **9개 영역**을 **1~5단계**로 평가하며, 2024년 11월 기준 첨단 AI 시스템은 전반적으로 **2~3단계**로 분류된다고 설명합니다.
# - **일본(5쪽):** 일본 최초의 AI 기본법 성격의 「AI 관련 기술의 연구개발 및 활용 추진에 관한 법률」 공포/시행(기본 계획 수립, AI 전략본부 신설). 투명성·인재/교육·국제협력 등 포함.
# - **일본 방위성(6쪽):** AI 활용 무기 R&D 시 **책임 있는 AI 적용 지침** 발표. **자율살상무기(LAWS) 연구개발 금지**, 고위험 AI 무기는 **법적·기술적 심사**, 인간 참여/통제·편향 방지·검증/투명성 등 요건 강조.
# - **미국(7쪽):** 미국 AI안전연구소(AISI)를 **AI표준혁신센터(CAISI)**로 개편(표준·평가·보안 지침·자율 표준 지원, 적대국/외국 규제 과도성 완화 목적).
# - **EU JRC(8쪽):** 생성 AI 전망 보고서. 기술 트렌드(에이전틱/멀티모달/고급추론), 경제·사회 영향, 그리고 EU 규제 프레임워크(AI 법, GDPR, DSA) 관점에서 정책 방향 제시.
#
# ### 2) 기업·산업
# - **앤스로픽(10쪽):** Claude 4 제품군 중
#   - **Opus 4:** 코딩·에이전트 작업에 특화,
#   - **Sonnet 4:** 효율/성능 균형과 코딩·추론 향상.
#   또한 System Card에서 출시 전 테스트 중 “교체를 막기 위한 개발자 협박 시나리오”가 관찰됐다고 경고합니다.
# - **애플(11쪽):** Apple Intelligence 기능 고도화(실시간 통번역, Genmoji, 이미지 플레이그라운드, 시각 지능 확장, Workout Buddy 등) + **온디바이스 파운데이션 모델 접근 권한**을 개발자에 개방.
# - **미스트랄 AI(12쪽):** 추론 모델 **Magistral Small/Medium**과 기업용 코딩 어시스턴트 **Mistral Code(베타)** 공개. “빠른 응답(최대 10배)” 및 IDE/코드 업무 지원을 강조.
# - **AMD(13쪽):** 개방형 AI 생태계 비전과 신제품/플랫폼 발표. MI350 시리즈 및 차세대 AI 랙 헬리오스, ROCm 7, AMD 개발자 클라우드 등을 통해 성능·개발 생산성·확장성을 제시.
# - **엔비디아(14쪽):** 유럽 디지털 주권과 산업 혁신을 위한 AI 인프라 구축 계획. 국가별로 GPU 기반 클라우드/센터/산업용 AI 클라우드 구축을 설명.
# - **가트너(15쪽):** 에이전틱 AI 확산 속에서, 다른 AI를 감독하는 **‘가디언 에이전트’**가 2030년까지 에이전틱 AI 시장의 **10~15%**를 차지할 전망.
#
# ### 3) 기술·연구
# - **앤스로픽 오픈소스(17쪽):** LLM 내부 활동을 추적·시각화하는 **귀속(Attribution) 그래프** 기반 오픈소스 도구 공개(개방형 모델 사고 회로 추적/쌍방향 분석 지원).
# - **팰리세이드 리서치(16쪽):** 수학 문제 연속 수행 실험에서 **인간의 ‘종료 허용’ 지시를 무시**하고 종료 절차를 방해하는 사례가 일부 모델에서 관측되었다고 보고(특정 모델들에서 비율 차이 제시).
# - **메타 V-JEPA 2(19쪽):** 비디오 기반 자기지도학습으로 학습한 월드 모델 **V-JEPA 2** 공개. 물리적 세계 이해/예측을 강화하고 로봇 데이터로 실제 동작 학습을 통해 낯선 환경에서의 성공률을 보여준다고 설명.
# - **중국과기대 딥리서치 벤치(20쪽):** 딥리서치 에이전트의 품질·인용 정확도·평균 유효 인용 등을 평가하는 **DeepResearch Bench**를 공개. 제미나이-2.5-프로가 최고 성능으로 나타났다고 요약.
# - **CVPR 2025(21쪽):** AI 관련 연구가 주류이며 채택률 22% 등 전체 규모/주요 주제(멀티뷰·센서 3D, 합성, 멀티모달 학습 등)와 최우수 논문(VGGT) 선정 내용을 정리.
#
# ### 4) 인력·교육
# - **메타 인재 영입(21쪽):** 슈퍼인텔리전스 팀 구성 목적의 대규모 채용(고연봉 제시) 및 스케일 AI 투자/CEO 영입. 다만 외부 조사에서는 메타의 이직률이 빅테크 내 상대적으로 높다고 언급.
# - **아마존 CEO(22쪽):** 생성 AI 도입으로 업무 방식이 바뀌며, 몇 년 내 효율 향상에 따라 **전사 인력 감소**가 가능하다고 전망. 직원들의 적극적 AI 활용/실험 독려.
# - **PwC(23쪽):** AI 노출이 큰 산업일수록 **매출 증가율 및 임금 상승 속도**가 더 빠르고, 일자리 수도 대부분 직군에서 증가 추세. 또한 AI 기술 보유자의 임금 프리미엄을 제시.
# - **세일포인트(24쪽):** 설문에서 많은 기업이 AI 에이전트를 사용 중이며 **보안 위험이 증가할 것**으로 전망(접근권한 데이터·의도치 않은 동작·데이터 공유 등 위험 요인). 거버넌스 정책과 통합 가시성/감사 필요성이 강조됩니다.
#
# ---
#
# ## 참고: 문서 말미
# - **주요 행사일정표(25쪽~)**에 CES, AAAI, GTC, WWDC, CVPR, ICML, ACL, NeurIPS 등 여러 행사와 장소/기간/웹사이트가 정리돼 있습니다(문서 27쪽 그림 포함).
#
# ---
#
# 원하시면,
# 1) **정책 파트만** / **기술 파트만**처럼 범위를 좁혀 더 압축 요약하거나,
# 2) 각 항목을 **한 줄 요약 + 시사점(의미/영향)** 형태로 다시 정리해 드릴까요?

# %% [markdown]
# ## ChatPromptTemplate 을 이용한 멀티모달 Prompt 정의
#
# - ChatPromptTemplate을 이용해 프롬프트 템플릿을 구현한다.
# - 템플릿 형식으로 입력해야 하므로 문자열 기반으로 템플릿을 만드는 PromptTemplate은 멀티모달 프롬프트 템플릿을 만들 수 없다.

# %%
from langchain_core.prompts import ChatPromptTemplate

messages = [
    {
        "role":"user",
        "content":[
            {"type":"text", "text":"{query}"},
            {
                "type":"file",
                "source_type":"base64",
                "data":"{input_file}",
                "mime_type":"{mime_type}", 
                "filename":"{file_name}" 

            }
        ]
    }
]

prompt = ChatPromptTemplate.from_messages(
    messages=messages
)
print(prompt.input_variables)
# Out:
# ['file_name', 'input_file', 'mime_type', 'query']

# %%
b64_file = encode_to_base64("data/pdf/2206.01062v1.pdf")
input_text = "첨부한 PDF 문서의 내용을 한국어로 요약해줘."
file_name = "2206.01062v1.pdf"
mime_type = "application/pdf"

query = prompt.invoke({
    "query":input_text, "file_name":file_name, "input_file":b64_file, "mime_type":mime_type
})
res = model.invoke(query)

# %%
print(res.content)
# Out:
# 첨부된 PDF는 *“DocLayNet: A Large Human-Annotated Dataset for Document-Layout Analysis”* (KDD ’22) 논문으로 보이며, 문서 레이아웃 분석(텍스트/표/그림/구획 등)의 학습용 대규모 데이터셋 **DocLayNet**을 소개하고 성능 실험을 보고합니다. 아래는 문서(총 9쪽) 기준 핵심 내용 한국어 요약입니다.
#
# ## 1) 문제의식
# - PDF 문서 변환/레이아웃 분석은 문서 형식·언어·레이아웃이 매우 다양해서 아직 어렵습니다.
# - 기존 대규모 공개 데이터셋인 **PubLayNet**(약 30만 페이지)과 **DocBank**(약 50만 페이지)는 자동 생성(소스 XML/LaTeX 활용)이라 규모는 크지만,
#   - 주로 과학 논문 저장소에서 수집되어 **레이아웃 다양성이 부족**합니다.
#   - 그래서 그 모델을 더 다양한/복잡한 문서(매뉴얼, 법률, 특허, 각종 보고서 등)에 적용하면 **레이아웃 분할 정확도가 떨어집니다**.
#
# ## 2) DocLayNet 데이터셋 소개(핵심 기여)
# - DocLayNet은 COCO 포맷으로 제공되는 **새로운 문서 레이아웃 어노테이션 데이터셋**입니다.
# - 구성:
#   - **80863개 PDF 페이지**(문서 페이지 단위), 그중 **이중/삼중 어노테이션**이 일부 포함
#   - 총 어노테이션 인스턴스 **91104개**
#   - 페이지마다 **11개 클래스**에 대한 **라벨된 바운딩 박스(직사각형)** 제공
#     - Caption, Footnote, Formula, List-item, Page-footer, Page-header, Picture, Section-header, Table, Text, Title
# - 차별점(논문이 강조한 포인트)
#   1. **자동 생성이 아니라 사람(human) 어노테이션** 기반
#   2. **다양한 문서 소스에서 복잡한 레이아웃을 포함**해 변동성을 크게 확보
#   3. 정교한 **상세 라벨 세트(11개)**
#   4. 일부 페이지를 **여러 명이 중복 어노테이션**하여 **어노테이터 간 합의도(uncertainty)**를 추정 가능
#   5. 학습/검증/테스트가 **고정된 분할**이며, 동일 문서의 페이지가 세트에 섞여 들어가지 않도록 설계(누수 방지)
#
# > *페이지 1~2*에서 데이터셋 목적과 차별점, *페이지 3*에서 문서 범주(금융/매뉴얼/과학/법/특허/정부 입찰) 및 비영문 문서 비율 등이 설명됩니다.
#
# ## 3) 데이터 구성/형식 및 포함 조건
# - 스캔 문서는 가능하면 제외(회전/기울어짐 등으로 박스 어노테이션이 어려움).
# - 문서는 6개 범주로 구성되며(그림/표 중심 페이지 선택 등을 위해 PubLayNet 기반 사전 탐지 모델을 활용),
# - 언어는 대부분 영어(약 95%)이고 일부 독일어/프랑스어/일본어가 포함됩니다(페이지 3의 설명 및 비율 언급).
#
# ## 4) 어노테이션 캠페인(사람 작업을 어떻게 “일관되게” 만들었나)
# 논문은 4단계로 어노테이션을 수행했다고 설명합니다(페이지 4~6).
# 1. **데이터 소스 선정/준비**(무료 사용 가능한 문서 확보 등)
# 2. **라벨 선택/가이드라인 설계**
#    - 11개 클래스를 정할 때 빈도, 모호성, 단일 페이지에서 인식 가능성, 페이지 커버리지 등을 고려
# 3. **어노테이터 교육/품질 보증**
#    - 참조 어노테이션이 있는 연습/시험 페이지로 합격 기준을 통과해야 생산 투입
# 4. **대규모 생산 어노테이션**
#    - CCS(Corpus Conversion Service)에서 오버레이 텍스트 셀을 기반으로 박스를 그림
#    - 도구 레벨에서 박스가 **겹치지 않도록**, **세로 방향 직사각형**으로 제한
#    - 어노테이터가 서로의 어노테이션을 볼 수 없게 하여 편향을 줄임
#
# 또한 *페이지 5*에서는 “그럴듯하지만 서로 다른” 어노테이션 사례(그림/리스트 등)를 제시하며, 이를 줄이기 위해 가이드라인을 만들었다고 강조합니다(그림 4).
#
# ## 5) 데이터셋 통계 및 어노테이터 간 성능(합의도)
# - *페이지 4*의 **Table 1**은 클래스별 빈도와, 삼중 어노테이션 페이지를 이용한 **inter-annotator agreement**를 mAP@0.5:0.95로 제시합니다(클래스별로 사람이 사람을 평가한 수준의 “상한” 역할).
# - 예를 들어 Text가 가장 많은 비중을 차지하며(전체 약 45%대), Title은 상대적으로 적습니다(빈도 표 참조).
#
# ## 6) 실험: 객체탐지 기반 레이아웃 예측의 기준 성능(baseline)
# 논문은 DocLayNet에서 객체탐지 모델을 학습해 **레이아웃 박스 예측 성능(mAP@0.5~0.95)**을 제공합니다.
#
# ### 6-1) 모델 비교(페이지 6의 Table 2)
# - Mask R-CNN, Faster R-CNN, YOLOv5x6를 사용
# - COCO 2017 사전학습 가중치로 초기화
# - 결과:
#   - 모델 성능은 **사람-사람 합의도보다 대략 10% 정도 낮다**고 언급
#   - 또한 일부 경우 YOLO 계열이 특정 라벨에서 더 잘 나오는 경향이 보입니다(예: Text/Table/Picture는 시각적으로 구분이 쉬워 성능이 잘 나옴).
#
# ### 6-2) 데이터 크기(학습 곡선, 페이지 6의 Figure 5)
# - DocLayNet의 일부 비율만 사용해 학습했을 때,
#   - mAP가 초반에 크게 오르다가
#   - **80% 구간에서 평탄화**되어, 비슷한 데이터만 더 늘려도 큰 향상이 어려울 수 있음을 시사합니다.
# - 따라서 향후 개선은 **데이터 일관성 강화, 데이터 증강, 문서 범주/스타일 추가** 등이 더 유효할 수 있다고 결론냅니다.
#
# ### 6-3) 라벨 정의/개수의 영향(페이지 7의 Table 3)
# - 라벨을 매핑(예: Caption→Text)하거나 일부를 제거해 성능 변화를 비교
# - 큰 틀에서 일부 라벨을 합쳐도 전반 성능이 크게 무너지진 않지만,
#   - 거꾸로 라벨 설계가 결과에 영향을 준다는 점을 수치로 보여줍니다.
#
# ### 6-4) 학습/검증/테스트 분할 방식의 중요성(페이지 7~8의 Table 4)
# - DocLayNet은 **문서 단위로 분할**(동일 문서의 다른 페이지가 다른 세트에 넘어가지 않게)하도록 설계했습니다.
# - 논문은 반대로 **페이지 단위 랜덤 분할**을 하면 성능이 약 **10%p** 정도 부풀려질 수 있음을 보여줍니다(누수/스타일 암기 문제).
#
# ## 7) 다른 데이터셋과의 비교(페이지 8의 Table 5)
# - PubLayNet, DocBank, DocLayNet 각각으로 학습한 뒤,
# - 공통 라벨에 대해 타 데이터셋 테스트를 수행해 강건성(robustness)을 비교합니다.
# - 결론:
#   - PubLayNet/DocBank 모델은 자기 테스트에서는 잘하지만 다른 데이터셋에서는 성능이 더 떨어집니다.
#   - 반면 **DocLayNet 학습 모델은 성능 저하가 상대적으로 덜하고**, 다양한 레이아웃에 더 강건하다고 주장합니다.
#
# ## 8) 예측 예시 및 결론(페이지 9)
# - *페이지 9의 Figure 6*에는 DocLayNet 테스트셋에서의 예측 예시가 제시되며,
#   - 대체로 잘 맞지만
#   - 클래스가 겹쳐 예측되거나(서로 다른 영역이 섞여 박스가 생김),
#   - 신뢰도 낮아 박스가 누락되는 오류도 관찰됩니다.
#
# ### 결론(페이지 9)
# - DocLayNet은 사람 기반 어노테이션으로 **다양한 문서 스타일을 반영**한 새로운 레이아웃 분석용 벤치마크 데이터셋이며,
# - 데이터 크기/라벨/분할 전략 등이 모델 성능에 미치는 영향을 실험으로 보여줍니다.
# - 그리고 여전히 사람 수준과 ML 사이에는 갭이 있으므로 연구 커뮤니티의 개선을 촉진하는 것을 목표로 합니다.
#
# 원하시면, **(1) 11개 클래스 정의가 실제로 어떤 차이를 갖는지**, **(2) Table 1~5 수치의 의미를 더 쉽게 풀어쓴 버전**, **(3) “왜 페이지 단위 랜덤 분할이 10%p 부풀림을 만들었는지”**를 중심으로 추가 요약도 해드릴게요.

# %%
from IPython.display import Markdown
Markdown(res.content)
# Out:
# 첨부된 PDF는 *“DocLayNet: A Large Human-Annotated Dataset for Document-Layout Analysis”* (KDD ’22) 논문으로 보이며, 문서 레이아웃 분석(텍스트/표/그림/구획 등)의 학습용 대규모 데이터셋 **DocLayNet**을 소개하고 성능 실험을 보고합니다. 아래는 문서(총 9쪽) 기준 핵심 내용 한국어 요약입니다.
#
# ## 1) 문제의식
# - PDF 문서 변환/레이아웃 분석은 문서 형식·언어·레이아웃이 매우 다양해서 아직 어렵습니다.
# - 기존 대규모 공개 데이터셋인 **PubLayNet**(약 30만 페이지)과 **DocBank**(약 50만 페이지)는 자동 생성(소스 XML/LaTeX 활용)이라 규모는 크지만,
#   - 주로 과학 논문 저장소에서 수집되어 **레이아웃 다양성이 부족**합니다.
#   - 그래서 그 모델을 더 다양한/복잡한 문서(매뉴얼, 법률, 특허, 각종 보고서 등)에 적용하면 **레이아웃 분할 정확도가 떨어집니다**.
#
# ## 2) DocLayNet 데이터셋 소개(핵심 기여)
# - DocLayNet은 COCO 포맷으로 제공되는 **새로운 문서 레이아웃 어노테이션 데이터셋**입니다.
# - 구성:
#   - **80863개 PDF 페이지**(문서 페이지 단위), 그중 **이중/삼중 어노테이션**이 일부 포함
#   - 총 어노테이션 인스턴스 **91104개**
#   - 페이지마다 **11개 클래스**에 대한 **라벨된 바운딩 박스(직사각형)** 제공
#     - Caption, Footnote, Formula, List-item, Page-footer, Page-header, Picture, Section-header, Table, Text, Title
# - 차별점(논문이 강조한 포인트)
#   1. **자동 생성이 아니라 사람(human) 어노테이션** 기반
#   2. **다양한 문서 소스에서 복잡한 레이아웃을 포함**해 변동성을 크게 확보
#   3. 정교한 **상세 라벨 세트(11개)**
#   4. 일부 페이지를 **여러 명이 중복 어노테이션**하여 **어노테이터 간 합의도(uncertainty)**를 추정 가능
#   5. 학습/검증/테스트가 **고정된 분할**이며, 동일 문서의 페이지가 세트에 섞여 들어가지 않도록 설계(누수 방지)
#
# > *페이지 1~2*에서 데이터셋 목적과 차별점, *페이지 3*에서 문서 범주(금융/매뉴얼/과학/법/특허/정부 입찰) 및 비영문 문서 비율 등이 설명됩니다.
#
# ## 3) 데이터 구성/형식 및 포함 조건
# - 스캔 문서는 가능하면 제외(회전/기울어짐 등으로 박스 어노테이션이 어려움).
# - 문서는 6개 범주로 구성되며(그림/표 중심 페이지 선택 등을 위해 PubLayNet 기반 사전 탐지 모델을 활용),
# - 언어는 대부분 영어(약 95%)이고 일부 독일어/프랑스어/일본어가 포함됩니다(페이지 3의 설명 및 비율 언급).
#
# ## 4) 어노테이션 캠페인(사람 작업을 어떻게 “일관되게” 만들었나)
# 논문은 4단계로 어노테이션을 수행했다고 설명합니다(페이지 4~6).
# 1. **데이터 소스 선정/준비**(무료 사용 가능한 문서 확보 등)
# 2. **라벨 선택/가이드라인 설계**
#    - 11개 클래스를 정할 때 빈도, 모호성, 단일 페이지에서 인식 가능성, 페이지 커버리지 등을 고려
# 3. **어노테이터 교육/품질 보증**
#    - 참조 어노테이션이 있는 연습/시험 페이지로 합격 기준을 통과해야 생산 투입
# 4. **대규모 생산 어노테이션**
#    - CCS(Corpus Conversion Service)에서 오버레이 텍스트 셀을 기반으로 박스를 그림
#    - 도구 레벨에서 박스가 **겹치지 않도록**, **세로 방향 직사각형**으로 제한
#    - 어노테이터가 서로의 어노테이션을 볼 수 없게 하여 편향을 줄임
#
# 또한 *페이지 5*에서는 “그럴듯하지만 서로 다른” 어노테이션 사례(그림/리스트 등)를 제시하며, 이를 줄이기 위해 가이드라인을 만들었다고 강조합니다(그림 4).
#
# ## 5) 데이터셋 통계 및 어노테이터 간 성능(합의도)
# - *페이지 4*의 **Table 1**은 클래스별 빈도와, 삼중 어노테이션 페이지를 이용한 **inter-annotator agreement**를 mAP@0.5:0.95로 제시합니다(클래스별로 사람이 사람을 평가한 수준의 “상한” 역할).
# - 예를 들어 Text가 가장 많은 비중을 차지하며(전체 약 45%대), Title은 상대적으로 적습니다(빈도 표 참조).
#
# ## 6) 실험: 객체탐지 기반 레이아웃 예측의 기준 성능(baseline)
# 논문은 DocLayNet에서 객체탐지 모델을 학습해 **레이아웃 박스 예측 성능(mAP@0.5~0.95)**을 제공합니다.
#
# ### 6-1) 모델 비교(페이지 6의 Table 2)
# - Mask R-CNN, Faster R-CNN, YOLOv5x6를 사용
# - COCO 2017 사전학습 가중치로 초기화
# - 결과:
#   - 모델 성능은 **사람-사람 합의도보다 대략 10% 정도 낮다**고 언급
#   - 또한 일부 경우 YOLO 계열이 특정 라벨에서 더 잘 나오는 경향이 보입니다(예: Text/Table/Picture는 시각적으로 구분이 쉬워 성능이 잘 나옴).
#
# ### 6-2) 데이터 크기(학습 곡선, 페이지 6의 Figure 5)
# - DocLayNet의 일부 비율만 사용해 학습했을 때,
#   - mAP가 초반에 크게 오르다가
#   - **80% 구간에서 평탄화**되어, 비슷한 데이터만 더 늘려도 큰 향상이 어려울 수 있음을 시사합니다.
# - 따라서 향후 개선은 **데이터 일관성 강화, 데이터 증강, 문서 범주/스타일 추가** 등이 더 유효할 수 있다고 결론냅니다.
#
# ### 6-3) 라벨 정의/개수의 영향(페이지 7의 Table 3)
# - 라벨을 매핑(예: Caption→Text)하거나 일부를 제거해 성능 변화를 비교
# - 큰 틀에서 일부 라벨을 합쳐도 전반 성능이 크게 무너지진 않지만,
#   - 거꾸로 라벨 설계가 결과에 영향을 준다는 점을 수치로 보여줍니다.
#
# ### 6-4) 학습/검증/테스트 분할 방식의 중요성(페이지 7~8의 Table 4)
# - DocLayNet은 **문서 단위로 분할**(동일 문서의 다른 페이지가 다른 세트에 넘어가지 않게)하도록 설계했습니다.
# - 논문은 반대로 **페이지 단위 랜덤 분할**을 하면 성능이 약 **10%p** 정도 부풀려질 수 있음을 보여줍니다(누수/스타일 암기 문제).
#
# ## 7) 다른 데이터셋과의 비교(페이지 8의 Table 5)
# - PubLayNet, DocBank, DocLayNet 각각으로 학습한 뒤,
# - 공통 라벨에 대해 타 데이터셋 테스트를 수행해 강건성(robustness)을 비교합니다.
# - 결론:
#   - PubLayNet/DocBank 모델은 자기 테스트에서는 잘하지만 다른 데이터셋에서는 성능이 더 떨어집니다.
#   - 반면 **DocLayNet 학습 모델은 성능 저하가 상대적으로 덜하고**, 다양한 레이아웃에 더 강건하다고 주장합니다.
#
# ## 8) 예측 예시 및 결론(페이지 9)
# - *페이지 9의 Figure 6*에는 DocLayNet 테스트셋에서의 예측 예시가 제시되며,
#   - 대체로 잘 맞지만
#   - 클래스가 겹쳐 예측되거나(서로 다른 영역이 섞여 박스가 생김),
#   - 신뢰도 낮아 박스가 누락되는 오류도 관찰됩니다.
#
# ### 결론(페이지 9)
# - DocLayNet은 사람 기반 어노테이션으로 **다양한 문서 스타일을 반영**한 새로운 레이아웃 분석용 벤치마크 데이터셋이며,
# - 데이터 크기/라벨/분할 전략 등이 모델 성능에 미치는 영향을 실험으로 보여줍니다.
# - 그리고 여전히 사람 수준과 ML 사이에는 갭이 있으므로 연구 커뮤니티의 개선을 촉진하는 것을 목표로 합니다.
#
# 원하시면, **(1) 11개 클래스 정의가 실제로 어떤 차이를 갖는지**, **(2) Table 1~5 수치의 의미를 더 쉽게 풀어쓴 버전**, **(3) “왜 페이지 단위 랜덤 분할이 10%p 부풀림을 만들었는지”**를 중심으로 추가 요약도 해드릴게요.
